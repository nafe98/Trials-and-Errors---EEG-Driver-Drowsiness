# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('Train Test Dataset/X_train.npy')
X_test = np.load('Train Test Dataset/X_test.npy')
y_train = np.load('Train Test Dataset/y_train.npy')
y_test = np.load('Train Test Dataset/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - GRU</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for LSTM

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (5, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
gru_model = Sequential([
    
    GRU(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1),
    GRU(256, activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 5, 512)            791040
#
#  dropout (Dropout)           (None, 5, 512)            0
#
#  gru_1 (GRU)                 (None, 256)               591360
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,382,657
# Trainable params: 1,382,657
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
gru_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Integrating Callbacks</h2>
#
# </div>

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/GRU_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = gru_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping], 
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6463 - accuracy: 0.6221
# Epoch 1: val_loss improved from inf to 0.63408, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 244s 299ms/step - loss: 0.6463 - accuracy: 0.6221 - val_loss: 0.6341 - val_accuracy: 0.6330
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6246 - accuracy: 0.6409
# Epoch 2: val_loss improved from 0.63408 to 0.61766, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.6246 - accuracy: 0.6409 - val_loss: 0.6177 - val_accuracy: 0.6466
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6115 - accuracy: 0.6492
# Epoch 3: val_loss improved from 0.61766 to 0.60420, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.6115 - accuracy: 0.6492 - val_loss: 0.6042 - val_accuracy: 0.6567
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6000 - accuracy: 0.6582
# Epoch 4: val_loss improved from 0.60420 to 0.59199, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.6000 - accuracy: 0.6582 - val_loss: 0.5920 - val_accuracy: 0.6635
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5881 - accuracy: 0.6664
# Epoch 5: val_loss improved from 0.59199 to 0.58327, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.5881 - accuracy: 0.6664 - val_loss: 0.5833 - val_accuracy: 0.6708
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5756 - accuracy: 0.6760
# Epoch 6: val_loss improved from 0.58327 to 0.56896, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.5756 - accuracy: 0.6760 - val_loss: 0.5690 - val_accuracy: 0.6783
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5640 - accuracy: 0.6846
# Epoch 7: val_loss improved from 0.56896 to 0.55530, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.5640 - accuracy: 0.6846 - val_loss: 0.5553 - val_accuracy: 0.6896
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5512 - accuracy: 0.6935
# Epoch 8: val_loss improved from 0.55530 to 0.54636, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.5512 - accuracy: 0.6935 - val_loss: 0.5464 - val_accuracy: 0.6970
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5399 - accuracy: 0.7029
# Epoch 9: val_loss improved from 0.54636 to 0.53642, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.5399 - accuracy: 0.7029 - val_loss: 0.5364 - val_accuracy: 0.7042
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5295 - accuracy: 0.7100
# Epoch 10: val_loss improved from 0.53642 to 0.52402, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.5295 - accuracy: 0.7100 - val_loss: 0.5240 - val_accuracy: 0.7162
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5202 - accuracy: 0.7175
# Epoch 11: val_loss improved from 0.52402 to 0.51114, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.5202 - accuracy: 0.7175 - val_loss: 0.5111 - val_accuracy: 0.7233
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.7243
# Epoch 12: val_loss improved from 0.51114 to 0.50475, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.5098 - accuracy: 0.7243 - val_loss: 0.5047 - val_accuracy: 0.7291
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5021 - accuracy: 0.7297
# Epoch 13: val_loss improved from 0.50475 to 0.49791, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.5021 - accuracy: 0.7297 - val_loss: 0.4979 - val_accuracy: 0.7337
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.7359
# Epoch 14: val_loss improved from 0.49791 to 0.49061, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4936 - accuracy: 0.7359 - val_loss: 0.4906 - val_accuracy: 0.7395
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4859 - accuracy: 0.7413
# Epoch 15: val_loss improved from 0.49061 to 0.48375, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4859 - accuracy: 0.7413 - val_loss: 0.4838 - val_accuracy: 0.7450
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4779 - accuracy: 0.7464
# Epoch 16: val_loss improved from 0.48375 to 0.47396, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4779 - accuracy: 0.7464 - val_loss: 0.4740 - val_accuracy: 0.7527
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4711 - accuracy: 0.7516
# Epoch 17: val_loss improved from 0.47396 to 0.46887, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4711 - accuracy: 0.7516 - val_loss: 0.4689 - val_accuracy: 0.7539
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4651 - accuracy: 0.7557
# Epoch 18: val_loss improved from 0.46887 to 0.46105, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4651 - accuracy: 0.7557 - val_loss: 0.4611 - val_accuracy: 0.7576
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4575 - accuracy: 0.7603
# Epoch 19: val_loss improved from 0.46105 to 0.45377, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4575 - accuracy: 0.7603 - val_loss: 0.4538 - val_accuracy: 0.7637
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4517 - accuracy: 0.7651
# Epoch 20: val_loss improved from 0.45377 to 0.45139, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4517 - accuracy: 0.7651 - val_loss: 0.4514 - val_accuracy: 0.7670
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4461 - accuracy: 0.7679
# Epoch 21: val_loss improved from 0.45139 to 0.44563, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4461 - accuracy: 0.7679 - val_loss: 0.4456 - val_accuracy: 0.7699
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4404 - accuracy: 0.7723
# Epoch 22: val_loss improved from 0.44563 to 0.44140, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4404 - accuracy: 0.7723 - val_loss: 0.4414 - val_accuracy: 0.7729
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4351 - accuracy: 0.7756
# Epoch 23: val_loss improved from 0.44140 to 0.43861, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4351 - accuracy: 0.7756 - val_loss: 0.4386 - val_accuracy: 0.7745
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4294 - accuracy: 0.7802
# Epoch 24: val_loss improved from 0.43861 to 0.42975, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4294 - accuracy: 0.7802 - val_loss: 0.4297 - val_accuracy: 0.7804
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4249 - accuracy: 0.7834
# Epoch 25: val_loss improved from 0.42975 to 0.42941, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4249 - accuracy: 0.7834 - val_loss: 0.4294 - val_accuracy: 0.7804
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4202 - accuracy: 0.7862
# Epoch 26: val_loss improved from 0.42941 to 0.42300, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4202 - accuracy: 0.7862 - val_loss: 0.4230 - val_accuracy: 0.7842
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4166 - accuracy: 0.7888
# Epoch 27: val_loss improved from 0.42300 to 0.42061, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4166 - accuracy: 0.7888 - val_loss: 0.4206 - val_accuracy: 0.7882
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4117 - accuracy: 0.7919
# Epoch 28: val_loss improved from 0.42061 to 0.41992, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4117 - accuracy: 0.7919 - val_loss: 0.4199 - val_accuracy: 0.7882
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4060 - accuracy: 0.7948
# Epoch 29: val_loss improved from 0.41992 to 0.41247, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.4060 - accuracy: 0.7948 - val_loss: 0.4125 - val_accuracy: 0.7920
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4026 - accuracy: 0.7972
# Epoch 30: val_loss improved from 0.41247 to 0.40718, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.4026 - accuracy: 0.7972 - val_loss: 0.4072 - val_accuracy: 0.7961
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3986 - accuracy: 0.8002
# Epoch 31: val_loss improved from 0.40718 to 0.40481, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3986 - accuracy: 0.8002 - val_loss: 0.4048 - val_accuracy: 0.7978
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3936 - accuracy: 0.8021
# Epoch 32: val_loss improved from 0.40481 to 0.40455, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3936 - accuracy: 0.8021 - val_loss: 0.4046 - val_accuracy: 0.7975
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3900 - accuracy: 0.8051
# Epoch 33: val_loss improved from 0.40455 to 0.40382, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3900 - accuracy: 0.8051 - val_loss: 0.4038 - val_accuracy: 0.7993
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.8069
# Epoch 34: val_loss improved from 0.40382 to 0.39741, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 293ms/step - loss: 0.3882 - accuracy: 0.8069 - val_loss: 0.3974 - val_accuracy: 0.8021
# Epoch 35/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3827 - accuracy: 0.8096
# Epoch 35: val_loss improved from 0.39741 to 0.39394, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.3827 - accuracy: 0.8096 - val_loss: 0.3939 - val_accuracy: 0.8044
# Epoch 36/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3807 - accuracy: 0.8111
# Epoch 36: val_loss improved from 0.39394 to 0.39250, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.3807 - accuracy: 0.8111 - val_loss: 0.3925 - val_accuracy: 0.8047
# Epoch 37/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3763 - accuracy: 0.8140
# Epoch 37: val_loss improved from 0.39250 to 0.38911, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.3763 - accuracy: 0.8140 - val_loss: 0.3891 - val_accuracy: 0.8072
# Epoch 38/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3732 - accuracy: 0.8152
# Epoch 38: val_loss improved from 0.38911 to 0.38757, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3732 - accuracy: 0.8152 - val_loss: 0.3876 - val_accuracy: 0.8091
# Epoch 39/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.8183
# Epoch 39: val_loss did not improve from 0.38757
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3696 - accuracy: 0.8183 - val_loss: 0.3885 - val_accuracy: 0.8083
# Epoch 40/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3675 - accuracy: 0.8192
# Epoch 40: val_loss improved from 0.38757 to 0.37960, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.3675 - accuracy: 0.8192 - val_loss: 0.3796 - val_accuracy: 0.8142
# Epoch 41/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3641 - accuracy: 0.8211
# Epoch 41: val_loss did not improve from 0.37960
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3641 - accuracy: 0.8211 - val_loss: 0.3818 - val_accuracy: 0.8112
# Epoch 42/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3596 - accuracy: 0.8232
# Epoch 42: val_loss improved from 0.37960 to 0.37922, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3596 - accuracy: 0.8232 - val_loss: 0.3792 - val_accuracy: 0.8156
# Epoch 43/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3563 - accuracy: 0.8260
# Epoch 43: val_loss improved from 0.37922 to 0.37510, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3563 - accuracy: 0.8260 - val_loss: 0.3751 - val_accuracy: 0.8166
# Epoch 44/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3549 - accuracy: 0.8267
# Epoch 44: val_loss did not improve from 0.37510
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3549 - accuracy: 0.8267 - val_loss: 0.3781 - val_accuracy: 0.8147
# Epoch 45/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3521 - accuracy: 0.8282
# Epoch 45: val_loss improved from 0.37510 to 0.37337, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.3521 - accuracy: 0.8282 - val_loss: 0.3734 - val_accuracy: 0.8186
# Epoch 46/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3490 - accuracy: 0.8301
# Epoch 46: val_loss improved from 0.37337 to 0.36856, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3490 - accuracy: 0.8301 - val_loss: 0.3686 - val_accuracy: 0.8202
# Epoch 47/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3470 - accuracy: 0.8319
# Epoch 47: val_loss did not improve from 0.36856
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3470 - accuracy: 0.8319 - val_loss: 0.3697 - val_accuracy: 0.8193
# Epoch 48/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3437 - accuracy: 0.8334
# Epoch 48: val_loss improved from 0.36856 to 0.36522, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3437 - accuracy: 0.8334 - val_loss: 0.3652 - val_accuracy: 0.8244
# Epoch 49/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3419 - accuracy: 0.8344
# Epoch 49: val_loss improved from 0.36522 to 0.36128, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3419 - accuracy: 0.8344 - val_loss: 0.3613 - val_accuracy: 0.8265
# Epoch 50/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3388 - accuracy: 0.8368
# Epoch 50: val_loss did not improve from 0.36128
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3388 - accuracy: 0.8368 - val_loss: 0.3631 - val_accuracy: 0.8253
# Epoch 51/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3352 - accuracy: 0.8381
# Epoch 51: val_loss improved from 0.36128 to 0.35776, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3352 - accuracy: 0.8381 - val_loss: 0.3578 - val_accuracy: 0.8274
# Epoch 52/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3342 - accuracy: 0.8392
# Epoch 52: val_loss did not improve from 0.35776
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3342 - accuracy: 0.8392 - val_loss: 0.3580 - val_accuracy: 0.8297
# Epoch 53/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.8407
# Epoch 53: val_loss improved from 0.35776 to 0.35722, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3317 - accuracy: 0.8407 - val_loss: 0.3572 - val_accuracy: 0.8294
# Epoch 54/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.8407
# Epoch 54: val_loss improved from 0.35722 to 0.35475, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3317 - accuracy: 0.8407 - val_loss: 0.3547 - val_accuracy: 0.8297
# Epoch 55/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3273 - accuracy: 0.8431
# Epoch 55: val_loss did not improve from 0.35475
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3273 - accuracy: 0.8431 - val_loss: 0.3552 - val_accuracy: 0.8308
# Epoch 56/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3246 - accuracy: 0.8444
# Epoch 56: val_loss did not improve from 0.35475
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3246 - accuracy: 0.8444 - val_loss: 0.3560 - val_accuracy: 0.8300
# Epoch 57/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3217 - accuracy: 0.8461
# Epoch 57: val_loss improved from 0.35475 to 0.35289, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3217 - accuracy: 0.8461 - val_loss: 0.3529 - val_accuracy: 0.8330
# Epoch 58/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3199 - accuracy: 0.8468
# Epoch 58: val_loss improved from 0.35289 to 0.34952, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3199 - accuracy: 0.8468 - val_loss: 0.3495 - val_accuracy: 0.8347
# Epoch 59/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3203 - accuracy: 0.8479
# Epoch 59: val_loss improved from 0.34952 to 0.34826, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3203 - accuracy: 0.8479 - val_loss: 0.3483 - val_accuracy: 0.8364
# Epoch 60/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3156 - accuracy: 0.8502
# Epoch 60: val_loss did not improve from 0.34826
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3156 - accuracy: 0.8502 - val_loss: 0.3484 - val_accuracy: 0.8349
# Epoch 61/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3129 - accuracy: 0.8512
# Epoch 61: val_loss did not improve from 0.34826
# 799/799 [==============================] - 234s 292ms/step - loss: 0.3129 - accuracy: 0.8512 - val_loss: 0.3489 - val_accuracy: 0.8344
# Epoch 62/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3134 - accuracy: 0.8514
# Epoch 62: val_loss improved from 0.34826 to 0.34341, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.3134 - accuracy: 0.8514 - val_loss: 0.3434 - val_accuracy: 0.8380
# Epoch 63/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3115 - accuracy: 0.8522
# Epoch 63: val_loss did not improve from 0.34341
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3115 - accuracy: 0.8522 - val_loss: 0.3483 - val_accuracy: 0.8355
# Epoch 64/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3077 - accuracy: 0.8541
# Epoch 64: val_loss improved from 0.34341 to 0.34160, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3077 - accuracy: 0.8541 - val_loss: 0.3416 - val_accuracy: 0.8405
# Epoch 65/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3072 - accuracy: 0.8547
# Epoch 65: val_loss did not improve from 0.34160
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3072 - accuracy: 0.8547 - val_loss: 0.3460 - val_accuracy: 0.8381
# Epoch 66/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3050 - accuracy: 0.8563
# Epoch 66: val_loss improved from 0.34160 to 0.33947, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3050 - accuracy: 0.8563 - val_loss: 0.3395 - val_accuracy: 0.8425
# Epoch 67/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3021 - accuracy: 0.8572
# Epoch 67: val_loss did not improve from 0.33947
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3021 - accuracy: 0.8572 - val_loss: 0.3408 - val_accuracy: 0.8417
# Epoch 68/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.8584
# Epoch 68: val_loss improved from 0.33947 to 0.33745, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.3011 - accuracy: 0.8584 - val_loss: 0.3374 - val_accuracy: 0.8454
# Epoch 69/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2986 - accuracy: 0.8596
# Epoch 69: val_loss did not improve from 0.33745
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2986 - accuracy: 0.8596 - val_loss: 0.3390 - val_accuracy: 0.8430
# Epoch 70/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2977 - accuracy: 0.8600
# Epoch 70: val_loss improved from 0.33745 to 0.33708, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2977 - accuracy: 0.8600 - val_loss: 0.3371 - val_accuracy: 0.8429
# Epoch 71/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8601
# Epoch 71: val_loss improved from 0.33708 to 0.33347, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2985 - accuracy: 0.8601 - val_loss: 0.3335 - val_accuracy: 0.8463
# Epoch 72/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2933 - accuracy: 0.8622
# Epoch 72: val_loss did not improve from 0.33347
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2933 - accuracy: 0.8622 - val_loss: 0.3363 - val_accuracy: 0.8441
# Epoch 73/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.8631
# Epoch 73: val_loss did not improve from 0.33347
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2920 - accuracy: 0.8631 - val_loss: 0.3341 - val_accuracy: 0.8453
# Epoch 74/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2901 - accuracy: 0.8641
# Epoch 74: val_loss did not improve from 0.33347
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2901 - accuracy: 0.8641 - val_loss: 0.3338 - val_accuracy: 0.8467
# Epoch 75/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.8655
# Epoch 75: val_loss improved from 0.33347 to 0.33097, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2889 - accuracy: 0.8655 - val_loss: 0.3310 - val_accuracy: 0.8474
# Epoch 76/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2878 - accuracy: 0.8660
# Epoch 76: val_loss improved from 0.33097 to 0.33056, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2878 - accuracy: 0.8660 - val_loss: 0.3306 - val_accuracy: 0.8493
# Epoch 77/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2857 - accuracy: 0.8670
# Epoch 77: val_loss did not improve from 0.33056
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2857 - accuracy: 0.8670 - val_loss: 0.3318 - val_accuracy: 0.8477
# Epoch 78/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2863 - accuracy: 0.8670
# Epoch 78: val_loss improved from 0.33056 to 0.32640, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2863 - accuracy: 0.8670 - val_loss: 0.3264 - val_accuracy: 0.8503
# Epoch 79/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2843 - accuracy: 0.8678
# Epoch 79: val_loss did not improve from 0.32640
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2843 - accuracy: 0.8678 - val_loss: 0.3293 - val_accuracy: 0.8504
# Epoch 80/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.8693
# Epoch 80: val_loss did not improve from 0.32640
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2810 - accuracy: 0.8693 - val_loss: 0.3286 - val_accuracy: 0.8510
# Epoch 81/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2815 - accuracy: 0.8696
# Epoch 81: val_loss did not improve from 0.32640
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2815 - accuracy: 0.8696 - val_loss: 0.3315 - val_accuracy: 0.8496
# Epoch 82/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2798 - accuracy: 0.8706
# Epoch 82: val_loss improved from 0.32640 to 0.32522, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2798 - accuracy: 0.8706 - val_loss: 0.3252 - val_accuracy: 0.8519
# Epoch 83/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.8715
# Epoch 83: val_loss did not improve from 0.32522
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2767 - accuracy: 0.8715 - val_loss: 0.3253 - val_accuracy: 0.8521
# Epoch 84/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2771 - accuracy: 0.8719
# Epoch 84: val_loss did not improve from 0.32522
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2771 - accuracy: 0.8719 - val_loss: 0.3270 - val_accuracy: 0.8502
# Epoch 85/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.8723
# Epoch 85: val_loss did not improve from 0.32522
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2761 - accuracy: 0.8723 - val_loss: 0.3262 - val_accuracy: 0.8521
# Epoch 86/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2723 - accuracy: 0.8744
# Epoch 86: val_loss did not improve from 0.32522
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2723 - accuracy: 0.8744 - val_loss: 0.3283 - val_accuracy: 0.8506
# Epoch 87/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2711 - accuracy: 0.8748
# Epoch 87: val_loss did not improve from 0.32522
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2711 - accuracy: 0.8748 - val_loss: 0.3258 - val_accuracy: 0.8534
# Epoch 88/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2709 - accuracy: 0.8752
# Epoch 88: val_loss improved from 0.32522 to 0.32419, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2709 - accuracy: 0.8752 - val_loss: 0.3242 - val_accuracy: 0.8540
# Epoch 89/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.8768
# Epoch 89: val_loss improved from 0.32419 to 0.32074, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2677 - accuracy: 0.8768 - val_loss: 0.3207 - val_accuracy: 0.8562
# Epoch 90/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2672 - accuracy: 0.8774
# Epoch 90: val_loss did not improve from 0.32074
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2672 - accuracy: 0.8774 - val_loss: 0.3234 - val_accuracy: 0.8550
# Epoch 91/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.8771
# Epoch 91: val_loss did not improve from 0.32074
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2676 - accuracy: 0.8771 - val_loss: 0.3229 - val_accuracy: 0.8557
# Epoch 92/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 0.8783
# Epoch 92: val_loss did not improve from 0.32074
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2655 - accuracy: 0.8783 - val_loss: 0.3218 - val_accuracy: 0.8572
# Epoch 93/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2645 - accuracy: 0.8788
# Epoch 93: val_loss improved from 0.32074 to 0.31659, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2645 - accuracy: 0.8788 - val_loss: 0.3166 - val_accuracy: 0.8584
# Epoch 94/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.8805
# Epoch 94: val_loss did not improve from 0.31659
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2627 - accuracy: 0.8805 - val_loss: 0.3214 - val_accuracy: 0.8574
# Epoch 95/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.8795
# Epoch 95: val_loss did not improve from 0.31659
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2634 - accuracy: 0.8795 - val_loss: 0.3202 - val_accuracy: 0.8572
# Epoch 96/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2606 - accuracy: 0.8810
# Epoch 96: val_loss did not improve from 0.31659
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2606 - accuracy: 0.8810 - val_loss: 0.3205 - val_accuracy: 0.8570
# Epoch 97/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2604 - accuracy: 0.8814
# Epoch 97: val_loss did not improve from 0.31659
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2604 - accuracy: 0.8814 - val_loss: 0.3195 - val_accuracy: 0.8575
# Epoch 98/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2566 - accuracy: 0.8828
# Epoch 98: val_loss did not improve from 0.31659
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2566 - accuracy: 0.8828 - val_loss: 0.3187 - val_accuracy: 0.8588
# Epoch 99/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.8833
# Epoch 99: val_loss did not improve from 0.31659
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2562 - accuracy: 0.8833 - val_loss: 0.3245 - val_accuracy: 0.8573
# Epoch 100/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.8833
# Epoch 100: val_loss did not improve from 0.31659
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2562 - accuracy: 0.8833 - val_loss: 0.3187 - val_accuracy: 0.8590
# Epoch 101/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2551 - accuracy: 0.8839
# Epoch 101: val_loss did not improve from 0.31659
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2551 - accuracy: 0.8839 - val_loss: 0.3183 - val_accuracy: 0.8599
# Epoch 102/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2526 - accuracy: 0.8849
# Epoch 102: val_loss did not improve from 0.31659
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2526 - accuracy: 0.8849 - val_loss: 0.3196 - val_accuracy: 0.8585
# Epoch 103/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.8852
# Epoch 103: val_loss improved from 0.31659 to 0.31553, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2525 - accuracy: 0.8852 - val_loss: 0.3155 - val_accuracy: 0.8628
# Epoch 104/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2530 - accuracy: 0.8850
# Epoch 104: val_loss improved from 0.31553 to 0.31552, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2530 - accuracy: 0.8850 - val_loss: 0.3155 - val_accuracy: 0.8596
# Epoch 105/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2498 - accuracy: 0.8866
# Epoch 105: val_loss did not improve from 0.31552
# 799/799 [==============================] - 235s 293ms/step - loss: 0.2498 - accuracy: 0.8866 - val_loss: 0.3174 - val_accuracy: 0.8606
# Epoch 106/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2495 - accuracy: 0.8864
# Epoch 106: val_loss did not improve from 0.31552
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2495 - accuracy: 0.8864 - val_loss: 0.3162 - val_accuracy: 0.8618
# Epoch 107/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2461 - accuracy: 0.8886
# Epoch 107: val_loss improved from 0.31552 to 0.31468, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2461 - accuracy: 0.8886 - val_loss: 0.3147 - val_accuracy: 0.8616
# Epoch 108/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2462 - accuracy: 0.8882
# Epoch 108: val_loss did not improve from 0.31468
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2462 - accuracy: 0.8882 - val_loss: 0.3177 - val_accuracy: 0.8600
# Epoch 109/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2491 - accuracy: 0.8876
# Epoch 109: val_loss did not improve from 0.31468
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2491 - accuracy: 0.8876 - val_loss: 0.3188 - val_accuracy: 0.8614
# Epoch 110/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.8894
# Epoch 110: val_loss improved from 0.31468 to 0.31168, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2447 - accuracy: 0.8894 - val_loss: 0.3117 - val_accuracy: 0.8626
# Epoch 111/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2425 - accuracy: 0.8909
# Epoch 111: val_loss improved from 0.31168 to 0.31087, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2425 - accuracy: 0.8909 - val_loss: 0.3109 - val_accuracy: 0.8649
# Epoch 112/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.8905
# Epoch 112: val_loss did not improve from 0.31087
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2426 - accuracy: 0.8905 - val_loss: 0.3118 - val_accuracy: 0.8643
# Epoch 113/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2419 - accuracy: 0.8911
# Epoch 113: val_loss did not improve from 0.31087
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2419 - accuracy: 0.8911 - val_loss: 0.3138 - val_accuracy: 0.8648
# Epoch 114/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2407 - accuracy: 0.8920
# Epoch 114: val_loss did not improve from 0.31087
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2407 - accuracy: 0.8920 - val_loss: 0.3117 - val_accuracy: 0.8651
# Epoch 115/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2397 - accuracy: 0.8918
# Epoch 115: val_loss did not improve from 0.31087
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2397 - accuracy: 0.8918 - val_loss: 0.3136 - val_accuracy: 0.8639
# Epoch 116/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2386 - accuracy: 0.8923
# Epoch 116: val_loss did not improve from 0.31087
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2386 - accuracy: 0.8923 - val_loss: 0.3127 - val_accuracy: 0.8646
# Epoch 117/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2375 - accuracy: 0.8933
# Epoch 117: val_loss did not improve from 0.31087
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2375 - accuracy: 0.8933 - val_loss: 0.3155 - val_accuracy: 0.8646
# Epoch 118/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2402 - accuracy: 0.8925
# Epoch 118: val_loss did not improve from 0.31087
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2402 - accuracy: 0.8925 - val_loss: 0.3126 - val_accuracy: 0.8654
# Epoch 119/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.8928
# Epoch 119: val_loss improved from 0.31087 to 0.31083, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2384 - accuracy: 0.8928 - val_loss: 0.3108 - val_accuracy: 0.8651
# Epoch 120/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.8946
# Epoch 120: val_loss did not improve from 0.31083
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2347 - accuracy: 0.8946 - val_loss: 0.3114 - val_accuracy: 0.8649
# Epoch 121/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2331 - accuracy: 0.8950
# Epoch 121: val_loss did not improve from 0.31083
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2331 - accuracy: 0.8950 - val_loss: 0.3130 - val_accuracy: 0.8651
# Epoch 122/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2343 - accuracy: 0.8951
# Epoch 122: val_loss did not improve from 0.31083
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2343 - accuracy: 0.8951 - val_loss: 0.3153 - val_accuracy: 0.8638
# Epoch 123/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2331 - accuracy: 0.8956
# Epoch 123: val_loss improved from 0.31083 to 0.31010, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2331 - accuracy: 0.8956 - val_loss: 0.3101 - val_accuracy: 0.8671
# Epoch 124/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2306 - accuracy: 0.8967
# Epoch 124: val_loss improved from 0.31010 to 0.31003, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2306 - accuracy: 0.8967 - val_loss: 0.3100 - val_accuracy: 0.8678
# Epoch 125/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2302 - accuracy: 0.8972
# Epoch 125: val_loss did not improve from 0.31003
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2302 - accuracy: 0.8972 - val_loss: 0.3102 - val_accuracy: 0.8689
# Epoch 126/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2300 - accuracy: 0.8971
# Epoch 126: val_loss did not improve from 0.31003
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2300 - accuracy: 0.8971 - val_loss: 0.3127 - val_accuracy: 0.8656
# Epoch 127/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.8970
# Epoch 127: val_loss did not improve from 0.31003
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2307 - accuracy: 0.8970 - val_loss: 0.3111 - val_accuracy: 0.8681
# Epoch 128/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.8976
# Epoch 128: val_loss did not improve from 0.31003
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2296 - accuracy: 0.8976 - val_loss: 0.3115 - val_accuracy: 0.8673
# Epoch 129/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2279 - accuracy: 0.8981
# Epoch 129: val_loss did not improve from 0.31003
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2279 - accuracy: 0.8981 - val_loss: 0.3105 - val_accuracy: 0.8669
# Epoch 130/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2259 - accuracy: 0.8992
# Epoch 130: val_loss did not improve from 0.31003
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2259 - accuracy: 0.8992 - val_loss: 0.3119 - val_accuracy: 0.8668
# Epoch 131/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.8992
# Epoch 131: val_loss did not improve from 0.31003
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2261 - accuracy: 0.8992 - val_loss: 0.3108 - val_accuracy: 0.8690
# Epoch 132/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2255 - accuracy: 0.9000
# Epoch 132: val_loss improved from 0.31003 to 0.30738, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2255 - accuracy: 0.9000 - val_loss: 0.3074 - val_accuracy: 0.8686
# Epoch 133/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.9008
# Epoch 133: val_loss did not improve from 0.30738
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2228 - accuracy: 0.9008 - val_loss: 0.3107 - val_accuracy: 0.8696
# Epoch 134/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2250 - accuracy: 0.9002
# Epoch 134: val_loss improved from 0.30738 to 0.30584, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2250 - accuracy: 0.9002 - val_loss: 0.3058 - val_accuracy: 0.8705
# Epoch 135/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2221 - accuracy: 0.9013
# Epoch 135: val_loss did not improve from 0.30584
# 799/799 [==============================] - 234s 293ms/step - loss: 0.2221 - accuracy: 0.9013 - val_loss: 0.3085 - val_accuracy: 0.8687
# Epoch 136/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2251 - accuracy: 0.9006
# Epoch 136: val_loss did not improve from 0.30584
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2251 - accuracy: 0.9006 - val_loss: 0.3077 - val_accuracy: 0.8690
# Epoch 137/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2211 - accuracy: 0.9017
# Epoch 137: val_loss did not improve from 0.30584
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2211 - accuracy: 0.9017 - val_loss: 0.3065 - val_accuracy: 0.8699
# Epoch 138/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2212 - accuracy: 0.9022
# Epoch 138: val_loss did not improve from 0.30584
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2212 - accuracy: 0.9022 - val_loss: 0.3105 - val_accuracy: 0.8680
# Epoch 139/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9011
# Epoch 139: val_loss did not improve from 0.30584
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2238 - accuracy: 0.9011 - val_loss: 0.3134 - val_accuracy: 0.8682
# Epoch 140/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2211 - accuracy: 0.9026
# Epoch 140: val_loss improved from 0.30584 to 0.30337, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2211 - accuracy: 0.9026 - val_loss: 0.3034 - val_accuracy: 0.8719
# Epoch 141/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.9037
# Epoch 141: val_loss did not improve from 0.30337
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2173 - accuracy: 0.9037 - val_loss: 0.3083 - val_accuracy: 0.8689
# Epoch 142/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2151 - accuracy: 0.9049
# Epoch 142: val_loss did not improve from 0.30337
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2151 - accuracy: 0.9049 - val_loss: 0.3090 - val_accuracy: 0.8711
# Epoch 143/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2170 - accuracy: 0.9039
# Epoch 143: val_loss did not improve from 0.30337
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2170 - accuracy: 0.9039 - val_loss: 0.3086 - val_accuracy: 0.8710
# Epoch 144/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9018
# Epoch 144: val_loss did not improve from 0.30337
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2238 - accuracy: 0.9018 - val_loss: 0.3067 - val_accuracy: 0.8708
# Epoch 145/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9020
# Epoch 145: val_loss did not improve from 0.30337
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2241 - accuracy: 0.9020 - val_loss: 0.3092 - val_accuracy: 0.8703
# Epoch 146/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2185 - accuracy: 0.9041
# Epoch 146: val_loss did not improve from 0.30337
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2185 - accuracy: 0.9041 - val_loss: 0.3053 - val_accuracy: 0.8716
# Epoch 147/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2146 - accuracy: 0.9055
# Epoch 147: val_loss did not improve from 0.30337
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2146 - accuracy: 0.9055 - val_loss: 0.3084 - val_accuracy: 0.8715
# Epoch 148/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2125 - accuracy: 0.9068
# Epoch 148: val_loss did not improve from 0.30337
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2125 - accuracy: 0.9068 - val_loss: 0.3074 - val_accuracy: 0.8727
# Epoch 149/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2125 - accuracy: 0.9062
# Epoch 149: val_loss did not improve from 0.30337
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2125 - accuracy: 0.9062 - val_loss: 0.3092 - val_accuracy: 0.8712
# Epoch 150/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.9064
# Epoch 150: val_loss did not improve from 0.30337
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2137 - accuracy: 0.9064 - val_loss: 0.3105 - val_accuracy: 0.8707
# Epoch 151/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9069
# Epoch 151: val_loss did not improve from 0.30337
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2117 - accuracy: 0.9069 - val_loss: 0.3036 - val_accuracy: 0.8729
# Epoch 152/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.9067
# Epoch 152: val_loss improved from 0.30337 to 0.30320, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 235s 295ms/step - loss: 0.2118 - accuracy: 0.9067 - val_loss: 0.3032 - val_accuracy: 0.8738
# Epoch 153/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9077
# Epoch 153: val_loss did not improve from 0.30320
# 799/799 [==============================] - 235s 294ms/step - loss: 0.2104 - accuracy: 0.9077 - val_loss: 0.3100 - val_accuracy: 0.8701
# Epoch 154/500
# ...
# Epoch 165/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9115
# Epoch 165: val_loss did not improve from 0.30320
# 799/799 [==============================] - 235s 295ms/step - loss: 0.2025 - accuracy: 0.9115 - val_loss: 0.3042 - val_accuracy: 0.8744
# Epoch 166/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2013 - accuracy: 0.9119
# Epoch 166: val_loss improved from 0.30320 to 0.30140, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 236s 295ms/step - loss: 0.2013 - accuracy: 0.9119 - val_loss: 0.3014 - val_accuracy: 0.8763
# Epoch 167/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2034 - accuracy: 0.9117
# Epoch 167: val_loss did not improve from 0.30140
# 799/799 [==============================] - 236s 295ms/step - loss: 0.2034 - accuracy: 0.9117 - val_loss: 0.3086 - val_accuracy: 0.8737
# Epoch 168/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2003 - accuracy: 0.9128
# Epoch 168: val_loss did not improve from 0.30140
# 799/799 [==============================] - 236s 295ms/step - loss: 0.2003 - accuracy: 0.9128 - val_loss: 0.3072 - val_accuracy: 0.8734
# Epoch 169/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2010 - accuracy: 0.9122
# Epoch 169: val_loss did not improve from 0.30140
# 799/799 [==============================] - 236s 295ms/step - loss: 0.2010 - accuracy: 0.9122 - val_loss: 0.3037 - val_accuracy: 0.8757
# Epoch 170/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1990 - accuracy: 0.9134
# Epoch 170: val_loss did not improve from 0.30140
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1990 - accuracy: 0.9134 - val_loss: 0.3100 - val_accuracy: 0.8752
# Epoch 171/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2008 - accuracy: 0.9125
# Epoch 171: val_loss did not improve from 0.30140
# 799/799 [==============================] - 236s 295ms/step - loss: 0.2008 - accuracy: 0.9125 - val_loss: 0.3063 - val_accuracy: 0.8764
# Epoch 172/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9135
# Epoch 172: val_loss improved from 0.30140 to 0.30015, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1984 - accuracy: 0.9135 - val_loss: 0.3002 - val_accuracy: 0.8772
# Epoch 173/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1985 - accuracy: 0.9138
# Epoch 173: val_loss did not improve from 0.30015
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1985 - accuracy: 0.9138 - val_loss: 0.3045 - val_accuracy: 0.8757
# Epoch 174/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9141
# Epoch 174: val_loss did not improve from 0.30015
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1971 - accuracy: 0.9141 - val_loss: 0.3142 - val_accuracy: 0.8711
# Epoch 175/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9139
# Epoch 175: val_loss did not improve from 0.30015
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1987 - accuracy: 0.9139 - val_loss: 0.3051 - val_accuracy: 0.8740
# Epoch 176/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1962 - accuracy: 0.9148
# Epoch 176: val_loss improved from 0.30015 to 0.29986, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1962 - accuracy: 0.9148 - val_loss: 0.2999 - val_accuracy: 0.8769
# Epoch 177/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1947 - accuracy: 0.9158
# Epoch 177: val_loss did not improve from 0.29986
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1947 - accuracy: 0.9158 - val_loss: 0.3042 - val_accuracy: 0.8757
# Epoch 178/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1947 - accuracy: 0.9154
# Epoch 178: val_loss did not improve from 0.29986
# 799/799 [==============================] - 235s 295ms/step - loss: 0.1947 - accuracy: 0.9154 - val_loss: 0.3060 - val_accuracy: 0.8765
# Epoch 179/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1966 - accuracy: 0.9145
# Epoch 179: val_loss did not improve from 0.29986
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1966 - accuracy: 0.9145 - val_loss: 0.3050 - val_accuracy: 0.8777
# Epoch 180/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1944 - accuracy: 0.9161
# Epoch 180: val_loss did not improve from 0.29986
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1944 - accuracy: 0.9161 - val_loss: 0.3052 - val_accuracy: 0.8756
# Epoch 181/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1924 - accuracy: 0.9166
# Epoch 181: val_loss improved from 0.29986 to 0.29958, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1924 - accuracy: 0.9166 - val_loss: 0.2996 - val_accuracy: 0.8780
# Epoch 182/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1960 - accuracy: 0.9151
# Epoch 182: val_loss did not improve from 0.29958
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1960 - accuracy: 0.9151 - val_loss: 0.3077 - val_accuracy: 0.8761
# Epoch 183/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1912 - accuracy: 0.9170
# Epoch 183: val_loss did not improve from 0.29958
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1912 - accuracy: 0.9170 - val_loss: 0.3033 - val_accuracy: 0.8777
# Epoch 184/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9155
# Epoch 184: val_loss did not improve from 0.29958
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1952 - accuracy: 0.9155 - val_loss: 0.3038 - val_accuracy: 0.8776
# Epoch 185/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1906 - accuracy: 0.9176
# Epoch 185: val_loss did not improve from 0.29958
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1906 - accuracy: 0.9176 - val_loss: 0.3043 - val_accuracy: 0.8778
# Epoch 186/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9186
# Epoch 186: val_loss did not improve from 0.29958
# 799/799 [==============================] - 235s 294ms/step - loss: 0.1883 - accuracy: 0.9186 - val_loss: 0.3055 - val_accuracy: 0.8784
# Epoch 187/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1895 - accuracy: 0.9176
# Epoch 187: val_loss did not improve from 0.29958
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1895 - accuracy: 0.9176 - val_loss: 0.3068 - val_accuracy: 0.8781
# Epoch 188/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1890 - accuracy: 0.9183
# Epoch 188: val_loss did not improve from 0.29958
# 799/799 [==============================] - 235s 295ms/step - loss: 0.1890 - accuracy: 0.9183 - val_loss: 0.3042 - val_accuracy: 0.8785
# Epoch 189/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1890 - accuracy: 0.9182
# Epoch 189: val_loss improved from 0.29958 to 0.29880, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1890 - accuracy: 0.9182 - val_loss: 0.2988 - val_accuracy: 0.8786
# Epoch 190/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1884 - accuracy: 0.9187
# Epoch 190: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1884 - accuracy: 0.9187 - val_loss: 0.3053 - val_accuracy: 0.8794
# Epoch 191/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1903 - accuracy: 0.9183
# Epoch 191: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1903 - accuracy: 0.9183 - val_loss: 0.3033 - val_accuracy: 0.8798
# Epoch 192/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1875 - accuracy: 0.9191
# Epoch 192: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1875 - accuracy: 0.9191 - val_loss: 0.3056 - val_accuracy: 0.8778
# Epoch 193/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9189
# Epoch 193: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1878 - accuracy: 0.9189 - val_loss: 0.3074 - val_accuracy: 0.8772
# Epoch 194/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1955 - accuracy: 0.9170
# Epoch 194: val_loss did not improve from 0.29880
# 799/799 [==============================] - 235s 295ms/step - loss: 0.1955 - accuracy: 0.9170 - val_loss: 0.3037 - val_accuracy: 0.8773
# Epoch 195/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1888 - accuracy: 0.9187
# Epoch 195: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1888 - accuracy: 0.9187 - val_loss: 0.3038 - val_accuracy: 0.8781
# Epoch 196/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1864 - accuracy: 0.9196
# Epoch 196: val_loss did not improve from 0.29880
# 799/799 [==============================] - 235s 295ms/step - loss: 0.1864 - accuracy: 0.9196 - val_loss: 0.3060 - val_accuracy: 0.8780
# Epoch 197/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1854 - accuracy: 0.9202
# Epoch 197: val_loss did not improve from 0.29880
# 799/799 [==============================] - 235s 295ms/step - loss: 0.1854 - accuracy: 0.9202 - val_loss: 0.2997 - val_accuracy: 0.8814
# Epoch 198/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9208
# Epoch 198: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1837 - accuracy: 0.9208 - val_loss: 0.3058 - val_accuracy: 0.8790
# Epoch 199/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1839 - accuracy: 0.9209
# Epoch 199: val_loss did not improve from 0.29880
# 799/799 [==============================] - 235s 295ms/step - loss: 0.1839 - accuracy: 0.9209 - val_loss: 0.3038 - val_accuracy: 0.8786
# Epoch 200/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1851 - accuracy: 0.9204
# Epoch 200: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1851 - accuracy: 0.9204 - val_loss: 0.3038 - val_accuracy: 0.8793
# Epoch 201/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9207
# Epoch 201: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1842 - accuracy: 0.9207 - val_loss: 0.3061 - val_accuracy: 0.8790
# Epoch 202/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1829 - accuracy: 0.9212
# Epoch 202: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1829 - accuracy: 0.9212 - val_loss: 0.3068 - val_accuracy: 0.8800
# Epoch 203/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1836 - accuracy: 0.9211
# Epoch 203: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1836 - accuracy: 0.9211 - val_loss: 0.3040 - val_accuracy: 0.8804
# Epoch 204/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1817 - accuracy: 0.9223
# Epoch 204: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1817 - accuracy: 0.9223 - val_loss: 0.3090 - val_accuracy: 0.8798
# Epoch 205/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9196
# Epoch 205: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1881 - accuracy: 0.9196 - val_loss: 0.3068 - val_accuracy: 0.8784
# Epoch 206/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9225
# Epoch 206: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1802 - accuracy: 0.9225 - val_loss: 0.3041 - val_accuracy: 0.8811
# Epoch 207/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1806 - accuracy: 0.9228
# Epoch 207: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1806 - accuracy: 0.9228 - val_loss: 0.3046 - val_accuracy: 0.8801
# Epoch 208/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1800 - accuracy: 0.9231
# Epoch 208: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1800 - accuracy: 0.9231 - val_loss: 0.3089 - val_accuracy: 0.8790
# Epoch 209/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9237
# Epoch 209: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1783 - accuracy: 0.9237 - val_loss: 0.3113 - val_accuracy: 0.8797
# Epoch 210/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1799 - accuracy: 0.9229
# Epoch 210: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1799 - accuracy: 0.9229 - val_loss: 0.3022 - val_accuracy: 0.8813
# Epoch 211/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9236
# Epoch 211: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1786 - accuracy: 0.9236 - val_loss: 0.3056 - val_accuracy: 0.8820
# Epoch 212/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1787 - accuracy: 0.9236
# Epoch 212: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1787 - accuracy: 0.9236 - val_loss: 0.3034 - val_accuracy: 0.8820
# Epoch 213/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9238
# Epoch 213: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 296ms/step - loss: 0.1778 - accuracy: 0.9238 - val_loss: 0.3061 - val_accuracy: 0.8816
# Epoch 214/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1761 - accuracy: 0.9242
# Epoch 214: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1761 - accuracy: 0.9242 - val_loss: 0.3032 - val_accuracy: 0.8822
# Epoch 215/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1765 - accuracy: 0.9244
# Epoch 215: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1765 - accuracy: 0.9244 - val_loss: 0.3081 - val_accuracy: 0.8805
# Epoch 216/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1763 - accuracy: 0.9250
# Epoch 216: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1763 - accuracy: 0.9250 - val_loss: 0.3030 - val_accuracy: 0.8843
# Epoch 217/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1740 - accuracy: 0.9255
# Epoch 217: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1740 - accuracy: 0.9255 - val_loss: 0.3052 - val_accuracy: 0.8809
# Epoch 218/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1752 - accuracy: 0.9245
# Epoch 218: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 296ms/step - loss: 0.1752 - accuracy: 0.9245 - val_loss: 0.3096 - val_accuracy: 0.8799
# Epoch 219/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9257
# Epoch 219: val_loss did not improve from 0.29880
# 799/799 [==============================] - 236s 295ms/step - loss: 0.1742 - accuracy: 0.9257 - val_loss: 0.3072 - val_accuracy: 0.8823
# Training Time:  51456.179268836975 seconds

# %% [markdown]
# # Saving the model and training history

# %%
gru_model.save('EEG_Driver_Drowsiness_GRU_Architecture.h5')
np.save('EEG_Driver_Drowsiness_GRU_history.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of LSTM Neural Network', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of LSTM Neural Network', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for LSTM Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ 0.46349357],
#         [ 0.36358773],
#         [ 3.37428511],
#         [ 2.21070338],
#         [-0.53335855]],
#
#        [[-3.12902325],
#         [-2.41096786],
#         [-4.83420457],
#         [-4.38417685],
#         [ 1.45759665]],
#
#        [[ 1.56338732],
#         [ 1.49249955],
#         [ 1.91877559],
#         [ 1.81817072],
#         [ 1.62761275]],
#
#        ...,
#
#        [[ 0.69592067],
#         [ 0.84838968],
#         [-0.60272074],
#         [-0.04577766],
#         [-0.3113151 ]],
#
#        [[ 2.17107007],
#         [ 2.96016373],
#         [ 3.46610892],
#         [ 2.54044544],
#         [ 0.99792245]],
#
#        [[ 0.16525652],
#         [-0.05828783],
#         [-0.23818711],
#         [-0.50661368],
#         [-0.80537552]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = gru_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 56s 11ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = gru_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.88, Test loss: 0.31

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88     77676
#            1       0.88      0.87      0.88     77614
#
#     accuracy                           0.88    155290
#    macro avg       0.88      0.88      0.88    155290
# weighted avg       0.88      0.88      0.88    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.8776031940240839
# Precision: 0.8820683990247337
# Recall: 0.8716468678331228
# F1-score: 0.8768266682219673
# AUC-ROC: 0.9508877179484596

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['LSTM Model'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()
