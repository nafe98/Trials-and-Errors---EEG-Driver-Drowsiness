# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 22/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 22/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 22/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 22/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - LSTM</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
from keras.layers import LSTM
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for LSTM

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (22, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
lstm_model = Sequential([
    
    LSTM(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1), 
    LSTM(256, activation='relu'),
    Dropout(0.1),  
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 22, 512)           1052672
#
#  dropout (Dropout)           (None, 22, 512)           0
#
#  lstm_1 (LSTM)               (None, 256)               787456
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,840,385
# Trainable params: 1,840,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
lstm_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/LSTM_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = lstm_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6511 - accuracy: 0.6246
# Epoch 1: val_loss improved from inf to 0.66096, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 908s 1s/step - loss: 0.6511 - accuracy: 0.6246 - val_loss: 0.6610 - val_accuracy: 0.6308
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6312 - accuracy: 0.6429
# Epoch 2: val_loss improved from 0.66096 to 0.61250, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 903s 1s/step - loss: 0.6312 - accuracy: 0.6429 - val_loss: 0.6125 - val_accuracy: 0.6571
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6007 - accuracy: 0.6668
# Epoch 3: val_loss improved from 0.61250 to 0.58219, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 902s 1s/step - loss: 0.6007 - accuracy: 0.6668 - val_loss: 0.5822 - val_accuracy: 0.6805
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5692 - accuracy: 0.6905
# Epoch 4: val_loss improved from 0.58219 to 0.55475, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 903s 1s/step - loss: 0.5692 - accuracy: 0.6905 - val_loss: 0.5548 - val_accuracy: 0.6999
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5342 - accuracy: 0.7161
# Epoch 5: val_loss improved from 0.55475 to 0.50555, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 903s 1s/step - loss: 0.5342 - accuracy: 0.7161 - val_loss: 0.5056 - val_accuracy: 0.7346
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4860 - accuracy: 0.7488
# Epoch 6: val_loss improved from 0.50555 to 0.45667, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 902s 1s/step - loss: 0.4860 - accuracy: 0.7488 - val_loss: 0.4567 - val_accuracy: 0.7684
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4315 - accuracy: 0.7843
# Epoch 7: val_loss improved from 0.45667 to 0.40258, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 903s 1s/step - loss: 0.4315 - accuracy: 0.7843 - val_loss: 0.4026 - val_accuracy: 0.8020
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.8352 - accuracy: 0.6132
# Epoch 8: val_loss did not improve from 0.40258
# 799/799 [==============================] - 903s 1s/step - loss: 0.8352 - accuracy: 0.6132 - val_loss: 0.6627 - val_accuracy: 0.6065
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6647 - accuracy: 0.6048
# Epoch 9: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6647 - accuracy: 0.6048 - val_loss: 0.6568 - val_accuracy: 0.6106
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6573 - accuracy: 0.6131
# Epoch 10: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6573 - accuracy: 0.6131 - val_loss: 0.6507 - val_accuracy: 0.6201
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6523 - accuracy: 0.6182
# Epoch 11: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6523 - accuracy: 0.6182 - val_loss: 0.6493 - val_accuracy: 0.6196
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6486 - accuracy: 0.6224
# Epoch 12: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6486 - accuracy: 0.6224 - val_loss: 0.6445 - val_accuracy: 0.6248
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6438 - accuracy: 0.6270
# Epoch 13: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6438 - accuracy: 0.6270 - val_loss: 0.6388 - val_accuracy: 0.6304
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.6311
# Epoch 14: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6400 - accuracy: 0.6311 - val_loss: 0.6349 - val_accuracy: 0.6337
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6358 - accuracy: 0.6345
# Epoch 15: val_loss did not improve from 0.40258
# 799/799 [==============================] - 901s 1s/step - loss: 0.6358 - accuracy: 0.6345 - val_loss: 0.6278 - val_accuracy: 0.6400
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6358 - accuracy: 0.6347
# Epoch 16: val_loss did not improve from 0.40258
# 799/799 [==============================] - 901s 1s/step - loss: 0.6358 - accuracy: 0.6347 - val_loss: 0.6340 - val_accuracy: 0.6348
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6342 - accuracy: 0.6357
# Epoch 17: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6342 - accuracy: 0.6357 - val_loss: 0.6266 - val_accuracy: 0.6383
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6237 - accuracy: 0.6444
# Epoch 18: val_loss did not improve from 0.40258
# 799/799 [==============================] - 901s 1s/step - loss: 0.6237 - accuracy: 0.6444 - val_loss: 0.6114 - val_accuracy: 0.6509
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6127 - accuracy: 0.6549
# Epoch 19: val_loss did not improve from 0.40258
# 799/799 [==============================] - 901s 1s/step - loss: 0.6127 - accuracy: 0.6549 - val_loss: 0.5989 - val_accuracy: 0.6659
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5957 - accuracy: 0.6709
# Epoch 20: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.5957 - accuracy: 0.6709 - val_loss: 0.5839 - val_accuracy: 0.6808
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.6267
# Epoch 21: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.7055 - accuracy: 0.6267 - val_loss: 0.6452 - val_accuracy: 0.6267
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.6312
# Epoch 22: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6400 - accuracy: 0.6312 - val_loss: 0.6274 - val_accuracy: 0.6437
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.8922 - accuracy: 0.6453
# Epoch 23: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.8922 - accuracy: 0.6453 - val_loss: 17.3424 - val_accuracy: 0.5488
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 1.4793 - accuracy: 0.5948
# Epoch 24: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 1.4793 - accuracy: 0.5948 - val_loss: 0.6575 - val_accuracy: 0.6133
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6572 - accuracy: 0.6164
# Epoch 25: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6572 - accuracy: 0.6164 - val_loss: 0.6490 - val_accuracy: 0.6218
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.6242
# Epoch 26: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6615 - accuracy: 0.6242 - val_loss: 0.6439 - val_accuracy: 0.6267
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6473 - accuracy: 0.6266
# Epoch 27: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6473 - accuracy: 0.6266 - val_loss: 0.6352 - val_accuracy: 0.6334
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6393 - accuracy: 0.6341
# Epoch 28: val_loss did not improve from 0.40258
# 799/799 [==============================] - 901s 1s/step - loss: 0.6393 - accuracy: 0.6341 - val_loss: 0.6283 - val_accuracy: 0.6397
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6341 - accuracy: 0.6398
# Epoch 29: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6341 - accuracy: 0.6398 - val_loss: 0.6302 - val_accuracy: 0.6392
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6307 - accuracy: 0.6466
# Epoch 30: val_loss did not improve from 0.40258
# 799/799 [==============================] - 901s 1s/step - loss: 0.6307 - accuracy: 0.6466 - val_loss: 0.6328 - val_accuracy: 0.6383
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6283 - accuracy: 0.6465
# Epoch 31: val_loss did not improve from 0.40258
# 799/799 [==============================] - 901s 1s/step - loss: 0.6283 - accuracy: 0.6465 - val_loss: 0.6646 - val_accuracy: 0.6057
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6569 - accuracy: 0.6164
# Epoch 32: val_loss did not improve from 0.40258
# 799/799 [==============================] - 901s 1s/step - loss: 0.6569 - accuracy: 0.6164 - val_loss: 0.6430 - val_accuracy: 0.6274
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6392 - accuracy: 0.6298
# Epoch 33: val_loss did not improve from 0.40258
# 799/799 [==============================] - 900s 1s/step - loss: 0.6392 - accuracy: 0.6298 - val_loss: 0.6255 - val_accuracy: 0.6435
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6207 - accuracy: 0.6501
# Epoch 34: val_loss did not improve from 0.40258
# 799/799 [==============================] - 902s 1s/step - loss: 0.6207 - accuracy: 0.6501 - val_loss: 0.6122 - val_accuracy: 0.6535
# Epoch 35/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6259 - accuracy: 0.6458
# Epoch 35: val_loss did not improve from 0.40258
# 799/799 [==============================] - 901s 1s/step - loss: 0.6259 - accuracy: 0.6458 - val_loss: 0.6105 - val_accuracy: 0.6616
# Epoch 36/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6265 - accuracy: 0.6490
# Epoch 36: val_loss did not improve from 0.40258
# 799/799 [==============================] - 901s 1s/step - loss: 0.6265 - accuracy: 0.6490 - val_loss: 0.6187 - val_accuracy: 0.6526
# Epoch 37/500
# 799/799 [==============================] - ETA: 0s - loss: 1.2236 - accuracy: 0.6097
# Epoch 37: val_loss did not improve from 0.40258
# 799/799 [==============================] - 901s 1s/step - loss: 1.2236 - accuracy: 0.6097 - val_loss: 0.6538 - val_accuracy: 0.6140
# Training Time:  33376.968181848526 seconds

# %% [markdown]
# # Saving the model and training history

# %%
lstm_model.save('LSTM_Architecture_22_Features.h5')
np.save('LSTM_history_22_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of LSTM Neural Network - 22 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of LSTM Neural Network - 22 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for LSTM Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ 0.46349357],
#         [ 0.36358773],
#         [ 3.37428511],
#         ...,
#         [ 0.5406654 ],
#         [ 0.35930914],
#         [ 0.48380596]],
#
#        [[-3.12902325],
#         [-2.41096786],
#         [-4.83420457],
#         ...,
#         [-0.4309879 ],
#         [ 0.20291455],
#         [-2.43979349]],
#
#        [[ 1.56338732],
#         [ 1.49249955],
#         [ 1.91877559],
#         ...,
#         [-0.30380594],
#         [ 1.17644483],
#         [ 1.54412212]],
#
#        ...,
#
#        [[ 0.69592067],
#         [ 0.84838968],
#         [-0.60272074],
#         ...,
#         [ 0.7656335 ],
#         [ 1.76657455],
#         [ 0.71739809]],
#
#        [[ 2.17107007],
#         [ 2.96016373],
#         [ 3.46610892],
#         ...,
#         [ 1.43503375],
#         [ 1.77492278],
#         [ 2.3559806 ]],
#
#        [[ 0.16525652],
#         [-0.05828783],
#         [-0.23818711],
#         ...,
#         [ 1.36947515],
#         [ 0.76639629],
#         [ 0.08409431]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = lstm_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 183s 38ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = lstm_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.80, Test loss: 0.40

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81     77676
#            1       0.84      0.74      0.79     77614
#
#     accuracy                           0.80    155290
#    macro avg       0.81      0.80      0.80    155290
# weighted avg       0.81      0.80      0.80    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix LSTM - 22 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.8029493206259257
# Precision: 0.8447481887777549
# Recall: 0.742134151055222
# F1-score: 0.7901234567901234
# AUC-ROC: 0.8940367485739815

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['LSTM - 22'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()
