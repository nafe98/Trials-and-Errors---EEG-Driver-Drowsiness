# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 22/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 22/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 22/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 22/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - GRU</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for GRU

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (22, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
gru_model = Sequential([
    
    GRU(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1),
    GRU(256, activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 22, 512)           791040
#
#  dropout (Dropout)           (None, 22, 512)           0
#
#  gru_1 (GRU)                 (None, 256)               591360
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,382,657
# Trainable params: 1,382,657
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
gru_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Integrating Callbacks</h2>
#
# </div>

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/GRU_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = gru_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping], 
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6342 - accuracy: 0.6315
# Epoch 1: val_loss improved from inf to 0.61034, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 962s 1s/step - loss: 0.6342 - accuracy: 0.6315 - val_loss: 0.6103 - val_accuracy: 0.6544
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5773 - accuracy: 0.6839
# Epoch 2: val_loss improved from 0.61034 to 0.55145, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 952s 1s/step - loss: 0.5773 - accuracy: 0.6839 - val_loss: 0.5514 - val_accuracy: 0.7012
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5057 - accuracy: 0.7370
# Epoch 3: val_loss improved from 0.55145 to 0.45605, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 951s 1s/step - loss: 0.5057 - accuracy: 0.7370 - val_loss: 0.4560 - val_accuracy: 0.7689
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6056 - accuracy: 0.6703
# Epoch 4: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6056 - accuracy: 0.6703 - val_loss: 0.6385 - val_accuracy: 0.6331
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6320 - accuracy: 0.6396
# Epoch 5: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6320 - accuracy: 0.6396 - val_loss: 0.6176 - val_accuracy: 0.6527
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6372 - accuracy: 0.6376
# Epoch 6: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6372 - accuracy: 0.6376 - val_loss: 0.6237 - val_accuracy: 0.6447
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6170 - accuracy: 0.6566
# Epoch 7: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6170 - accuracy: 0.6566 - val_loss: 0.5979 - val_accuracy: 0.6704
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6108 - accuracy: 0.6622
# Epoch 8: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6108 - accuracy: 0.6622 - val_loss: 0.6015 - val_accuracy: 0.6699
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7822 - accuracy: 0.6373
# Epoch 9: val_loss did not improve from 0.45605
# 799/799 [==============================] - 950s 1s/step - loss: 0.7822 - accuracy: 0.6373 - val_loss: 0.6496 - val_accuracy: 0.6194
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6514 - accuracy: 0.6225
# Epoch 10: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6514 - accuracy: 0.6225 - val_loss: 0.6393 - val_accuracy: 0.6343
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6371 - accuracy: 0.6360
# Epoch 11: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6371 - accuracy: 0.6360 - val_loss: 0.6276 - val_accuracy: 0.6434
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6219 - accuracy: 0.6488
# Epoch 12: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6219 - accuracy: 0.6488 - val_loss: 0.6110 - val_accuracy: 0.6602
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5948 - accuracy: 0.6736
# Epoch 13: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.5948 - accuracy: 0.6736 - val_loss: 0.5693 - val_accuracy: 0.6944
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5641 - accuracy: 0.7001
# Epoch 14: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.5641 - accuracy: 0.7001 - val_loss: 0.5380 - val_accuracy: 0.7201
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5698 - accuracy: 0.7018
# Epoch 15: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.5698 - accuracy: 0.7018 - val_loss: 0.6828 - val_accuracy: 0.5981
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6565 - accuracy: 0.6195
# Epoch 16: val_loss did not improve from 0.45605
# 799/799 [==============================] - 952s 1s/step - loss: 0.6565 - accuracy: 0.6195 - val_loss: 0.6345 - val_accuracy: 0.6383
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6262 - accuracy: 0.6476
# Epoch 17: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6262 - accuracy: 0.6476 - val_loss: 0.6049 - val_accuracy: 0.6631
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6206 - accuracy: 0.6587
# Epoch 18: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6206 - accuracy: 0.6587 - val_loss: 0.6406 - val_accuracy: 0.6463
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6720 - accuracy: 0.6397
# Epoch 19: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6720 - accuracy: 0.6397 - val_loss: 1.3901 - val_accuracy: 0.5089
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7263 - accuracy: 0.6027
# Epoch 20: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.7263 - accuracy: 0.6027 - val_loss: 0.6534 - val_accuracy: 0.6222
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6473 - accuracy: 0.6297
# Epoch 21: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6473 - accuracy: 0.6297 - val_loss: 0.6317 - val_accuracy: 0.6423
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6527 - accuracy: 0.6255
# Epoch 22: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6527 - accuracy: 0.6255 - val_loss: 0.6326 - val_accuracy: 0.6399
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6291 - accuracy: 0.6476
# Epoch 23: val_loss did not improve from 0.45605
# 799/799 [==============================] - 950s 1s/step - loss: 0.6291 - accuracy: 0.6476 - val_loss: 0.6047 - val_accuracy: 0.6655
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6024 - accuracy: 0.6703
# Epoch 24: val_loss did not improve from 0.45605
# 799/799 [==============================] - 950s 1s/step - loss: 0.6024 - accuracy: 0.6703 - val_loss: 0.6299 - val_accuracy: 0.6389
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6138 - accuracy: 0.6595
# Epoch 25: val_loss did not improve from 0.45605
# 799/799 [==============================] - 950s 1s/step - loss: 0.6138 - accuracy: 0.6595 - val_loss: 0.5870 - val_accuracy: 0.6803
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6013 - accuracy: 0.6715
# Epoch 26: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6013 - accuracy: 0.6715 - val_loss: 0.5759 - val_accuracy: 0.6897
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6174 - accuracy: 0.6668
# Epoch 27: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.6174 - accuracy: 0.6668 - val_loss: 0.6671 - val_accuracy: 0.6411
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5994 - accuracy: 0.6724
# Epoch 28: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.5994 - accuracy: 0.6724 - val_loss: 0.5662 - val_accuracy: 0.6986
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5632 - accuracy: 0.7009
# Epoch 29: val_loss did not improve from 0.45605
# 799/799 [==============================] - 950s 1s/step - loss: 0.5632 - accuracy: 0.7009 - val_loss: 0.5341 - val_accuracy: 0.7212
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5382 - accuracy: 0.7206
# Epoch 30: val_loss did not improve from 0.45605
# 799/799 [==============================] - 950s 1s/step - loss: 0.5382 - accuracy: 0.7206 - val_loss: 0.5163 - val_accuracy: 0.7371
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5885 - accuracy: 0.6913
# Epoch 31: val_loss did not improve from 0.45605
# 799/799 [==============================] - 951s 1s/step - loss: 0.5885 - accuracy: 0.6913 - val_loss: 0.5678 - val_accuracy: 0.6929
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5633 - accuracy: 0.6961
# Epoch 32: val_loss did not improve from 0.45605
# 799/799 [==============================] - 950s 1s/step - loss: 0.5633 - accuracy: 0.6961 - val_loss: 0.5257 - val_accuracy: 0.7251
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5166 - accuracy: 0.7323
# Epoch 33: val_loss did not improve from 0.45605
# 799/799 [==============================] - 950s 1s/step - loss: 0.5166 - accuracy: 0.7323 - val_loss: 0.4874 - val_accuracy: 0.7502
# Training Time:  31387.674800395966 seconds

# %% [markdown]
# # Saving the model and training history

# %%
gru_model.save('GRU_Architecture_22_Features.h5')
np.save('GRU_history_22_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of GRU Network - 22 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of GRU Network - 22 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for GRU Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ 0.46349357],
#         [ 0.36358773],
#         [ 3.37428511],
#         ...,
#         [ 0.5406654 ],
#         [ 0.35930914],
#         [ 0.48380596]],
#
#        [[-3.12902325],
#         [-2.41096786],
#         [-4.83420457],
#         ...,
#         [-0.4309879 ],
#         [ 0.20291455],
#         [-2.43979349]],
#
#        [[ 1.56338732],
#         [ 1.49249955],
#         [ 1.91877559],
#         ...,
#         [-0.30380594],
#         [ 1.17644483],
#         [ 1.54412212]],
#
#        ...,
#
#        [[ 0.69592067],
#         [ 0.84838968],
#         [-0.60272074],
#         ...,
#         [ 0.7656335 ],
#         [ 1.76657455],
#         [ 0.71739809]],
#
#        [[ 2.17107007],
#         [ 2.96016373],
#         [ 3.46610892],
#         ...,
#         [ 1.43503375],
#         [ 1.77492278],
#         [ 2.3559806 ]],
#
#        [[ 0.16525652],
#         [-0.05828783],
#         [-0.23818711],
#         ...,
#         [ 1.36947515],
#         [ 0.76639629],
#         [ 0.08409431]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = gru_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 188s 39ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = gru_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.77, Test loss: 0.46

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.77     77676
#            1       0.78      0.75      0.76     77614
#
#     accuracy                           0.77    155290
#    macro avg       0.77      0.77      0.77    155290
# weighted avg       0.77      0.77      0.77    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix GRU - 22 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.7676154291969863
# Precision: 0.7789630664642421
# Recall: 0.7470172906949777
# F1-score: 0.7626557926929527
# AUC-ROC: 0.8591246915429364

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['GRU - 22'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()
