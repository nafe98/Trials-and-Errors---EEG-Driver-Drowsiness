# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 5/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 5/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 5/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 5/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - LSTM</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
from keras.layers import LSTM
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for LSTM

# %%
X_train_array = X_train
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (5, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# # 2. Define Architecture

# %%
lstm_model = Sequential([
    
    LSTM(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1), 
    LSTM(256, activation='relu'),
    Dropout(0.1),  
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 512)            1052672
#
#  dropout (Dropout)           (None, 5, 512)            0
#
#  lstm_1 (LSTM)               (None, 256)               787456
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,840,385
# Trainable params: 1,840,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
lstm_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/LSTM_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = lstm_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6525 - accuracy: 0.6150
# Epoch 1: val_loss improved from inf to 0.64224, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 229s 283ms/step - loss: 0.6525 - accuracy: 0.6150 - val_loss: 0.6422 - val_accuracy: 0.6266
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6358 - accuracy: 0.6319
# Epoch 2: val_loss improved from 0.64224 to 0.62977, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.6358 - accuracy: 0.6319 - val_loss: 0.6298 - val_accuracy: 0.6368
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6242 - accuracy: 0.6404
# Epoch 3: val_loss improved from 0.62977 to 0.62019, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 283ms/step - loss: 0.6242 - accuracy: 0.6404 - val_loss: 0.6202 - val_accuracy: 0.6456
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6146 - accuracy: 0.6471
# Epoch 4: val_loss improved from 0.62019 to 0.60986, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6146 - accuracy: 0.6471 - val_loss: 0.6099 - val_accuracy: 0.6500
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6062 - accuracy: 0.6534
# Epoch 5: val_loss improved from 0.60986 to 0.60119, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6062 - accuracy: 0.6534 - val_loss: 0.6012 - val_accuracy: 0.6564
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5973 - accuracy: 0.6596
# Epoch 6: val_loss improved from 0.60119 to 0.59325, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.5973 - accuracy: 0.6596 - val_loss: 0.5933 - val_accuracy: 0.6618
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5886 - accuracy: 0.6662
# Epoch 7: val_loss improved from 0.59325 to 0.58383, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.5886 - accuracy: 0.6662 - val_loss: 0.5838 - val_accuracy: 0.6684
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5795 - accuracy: 0.6721
# Epoch 8: val_loss improved from 0.58383 to 0.57532, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.5795 - accuracy: 0.6721 - val_loss: 0.5753 - val_accuracy: 0.6760
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5711 - accuracy: 0.6785
# Epoch 9: val_loss improved from 0.57532 to 0.56698, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.5711 - accuracy: 0.6785 - val_loss: 0.5670 - val_accuracy: 0.6811
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5622 - accuracy: 0.6850
# Epoch 10: val_loss improved from 0.56698 to 0.55876, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.5622 - accuracy: 0.6850 - val_loss: 0.5588 - val_accuracy: 0.6883
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5534 - accuracy: 0.6919
# Epoch 11: val_loss improved from 0.55876 to 0.54858, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.5534 - accuracy: 0.6919 - val_loss: 0.5486 - val_accuracy: 0.6961
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5456 - accuracy: 0.6976
# Epoch 12: val_loss improved from 0.54858 to 0.54173, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.5456 - accuracy: 0.6976 - val_loss: 0.5417 - val_accuracy: 0.6999
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5363 - accuracy: 0.7038
# Epoch 13: val_loss improved from 0.54173 to 0.53359, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.5363 - accuracy: 0.7038 - val_loss: 0.5336 - val_accuracy: 0.7078
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5292 - accuracy: 0.7099
# Epoch 14: val_loss improved from 0.53359 to 0.52521, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.5292 - accuracy: 0.7099 - val_loss: 0.5252 - val_accuracy: 0.7144
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5197 - accuracy: 0.7167
# Epoch 15: val_loss improved from 0.52521 to 0.51524, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.5197 - accuracy: 0.7167 - val_loss: 0.5152 - val_accuracy: 0.7217
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5121 - accuracy: 0.7211
# Epoch 16: val_loss improved from 0.51524 to 0.50959, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.5121 - accuracy: 0.7211 - val_loss: 0.5096 - val_accuracy: 0.7251
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5043 - accuracy: 0.7270
# Epoch 17: val_loss improved from 0.50959 to 0.50451, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 240s 300ms/step - loss: 0.5043 - accuracy: 0.7270 - val_loss: 0.5045 - val_accuracy: 0.7310
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4971 - accuracy: 0.7323
# Epoch 18: val_loss improved from 0.50451 to 0.49263, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 243s 304ms/step - loss: 0.4971 - accuracy: 0.7323 - val_loss: 0.4926 - val_accuracy: 0.7361
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4906 - accuracy: 0.7370
# Epoch 19: val_loss improved from 0.49263 to 0.48757, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.4906 - accuracy: 0.7370 - val_loss: 0.4876 - val_accuracy: 0.7421
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4835 - accuracy: 0.7422
# Epoch 20: val_loss improved from 0.48757 to 0.48378, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4835 - accuracy: 0.7422 - val_loss: 0.4838 - val_accuracy: 0.7425
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4770 - accuracy: 0.7462
# Epoch 21: val_loss improved from 0.48378 to 0.47782, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.4770 - accuracy: 0.7462 - val_loss: 0.4778 - val_accuracy: 0.7477
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4716 - accuracy: 0.7507
# Epoch 22: val_loss improved from 0.47782 to 0.47091, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 283ms/step - loss: 0.4716 - accuracy: 0.7507 - val_loss: 0.4709 - val_accuracy: 0.7530
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4643 - accuracy: 0.7549
# Epoch 23: val_loss improved from 0.47091 to 0.46499, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4643 - accuracy: 0.7549 - val_loss: 0.4650 - val_accuracy: 0.7585
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4584 - accuracy: 0.7590
# Epoch 24: val_loss improved from 0.46499 to 0.45981, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4584 - accuracy: 0.7590 - val_loss: 0.4598 - val_accuracy: 0.7601
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4518 - accuracy: 0.7637
# Epoch 25: val_loss improved from 0.45981 to 0.45202, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4518 - accuracy: 0.7637 - val_loss: 0.4520 - val_accuracy: 0.7652
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4474 - accuracy: 0.7670
# Epoch 26: val_loss improved from 0.45202 to 0.44879, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4474 - accuracy: 0.7670 - val_loss: 0.4488 - val_accuracy: 0.7673
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4420 - accuracy: 0.7705
# Epoch 27: val_loss improved from 0.44879 to 0.44345, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4420 - accuracy: 0.7705 - val_loss: 0.4434 - val_accuracy: 0.7724
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4354 - accuracy: 0.7747
# Epoch 28: val_loss improved from 0.44345 to 0.43848, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4354 - accuracy: 0.7747 - val_loss: 0.4385 - val_accuracy: 0.7766
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4309 - accuracy: 0.7774
# Epoch 29: val_loss improved from 0.43848 to 0.43311, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4309 - accuracy: 0.7774 - val_loss: 0.4331 - val_accuracy: 0.7782
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4267 - accuracy: 0.7802
# Epoch 30: val_loss improved from 0.43311 to 0.42982, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4267 - accuracy: 0.7802 - val_loss: 0.4298 - val_accuracy: 0.7803
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4200 - accuracy: 0.7837
# Epoch 31: val_loss improved from 0.42982 to 0.42508, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4200 - accuracy: 0.7837 - val_loss: 0.4251 - val_accuracy: 0.7854
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4157 - accuracy: 0.7867
# Epoch 32: val_loss improved from 0.42508 to 0.42102, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4157 - accuracy: 0.7867 - val_loss: 0.4210 - val_accuracy: 0.7860
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4110 - accuracy: 0.7904
# Epoch 33: val_loss improved from 0.42102 to 0.41755, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4110 - accuracy: 0.7904 - val_loss: 0.4176 - val_accuracy: 0.7880
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4066 - accuracy: 0.7933
# Epoch 34: val_loss improved from 0.41755 to 0.41353, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4066 - accuracy: 0.7933 - val_loss: 0.4135 - val_accuracy: 0.7905
# Epoch 35/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4012 - accuracy: 0.7961
# Epoch 35: val_loss improved from 0.41353 to 0.40930, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.4012 - accuracy: 0.7961 - val_loss: 0.4093 - val_accuracy: 0.7930
# Epoch 36/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3981 - accuracy: 0.7988
# Epoch 36: val_loss improved from 0.40930 to 0.40572, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3981 - accuracy: 0.7988 - val_loss: 0.4057 - val_accuracy: 0.7964
# Epoch 37/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3959 - accuracy: 0.8006
# Epoch 37: val_loss improved from 0.40572 to 0.40483, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3959 - accuracy: 0.8006 - val_loss: 0.4048 - val_accuracy: 0.7977
# Epoch 38/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3887 - accuracy: 0.8038
# Epoch 38: val_loss improved from 0.40483 to 0.40113, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3887 - accuracy: 0.8038 - val_loss: 0.4011 - val_accuracy: 0.7995
# Epoch 39/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3846 - accuracy: 0.8068
# Epoch 39: val_loss improved from 0.40113 to 0.39570, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3846 - accuracy: 0.8068 - val_loss: 0.3957 - val_accuracy: 0.8018
# Epoch 40/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3812 - accuracy: 0.8089
# Epoch 40: val_loss improved from 0.39570 to 0.39247, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 283ms/step - loss: 0.3812 - accuracy: 0.8089 - val_loss: 0.3925 - val_accuracy: 0.8041
# Epoch 41/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3768 - accuracy: 0.8117
# Epoch 41: val_loss improved from 0.39247 to 0.38863, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3768 - accuracy: 0.8117 - val_loss: 0.3886 - val_accuracy: 0.8080
# Epoch 42/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3736 - accuracy: 0.8137
# Epoch 42: val_loss improved from 0.38863 to 0.38625, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3736 - accuracy: 0.8137 - val_loss: 0.3862 - val_accuracy: 0.8100
# Epoch 43/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3708 - accuracy: 0.8157
# Epoch 43: val_loss did not improve from 0.38625
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3708 - accuracy: 0.8157 - val_loss: 0.3875 - val_accuracy: 0.8093
# Epoch 44/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3678 - accuracy: 0.8178
# Epoch 44: val_loss improved from 0.38625 to 0.38494, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3678 - accuracy: 0.8178 - val_loss: 0.3849 - val_accuracy: 0.8112
# Epoch 45/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3648 - accuracy: 0.8196
# Epoch 45: val_loss did not improve from 0.38494
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3648 - accuracy: 0.8196 - val_loss: 0.3870 - val_accuracy: 0.8099
# Epoch 46/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3646 - accuracy: 0.8205
# Epoch 46: val_loss did not improve from 0.38494
# 799/799 [==============================] - 225s 282ms/step - loss: 0.3646 - accuracy: 0.8205 - val_loss: 0.3964 - val_accuracy: 0.8090
# Epoch 47/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3631 - accuracy: 0.8222
# Epoch 47: val_loss improved from 0.38494 to 0.37768, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3631 - accuracy: 0.8222 - val_loss: 0.3777 - val_accuracy: 0.8160
# Epoch 48/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3532 - accuracy: 0.8260
# Epoch 48: val_loss improved from 0.37768 to 0.37051, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 225s 282ms/step - loss: 0.3532 - accuracy: 0.8260 - val_loss: 0.3705 - val_accuracy: 0.8202
# Epoch 49/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3520 - accuracy: 0.8270
# Epoch 49: val_loss improved from 0.37051 to 0.36836, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3520 - accuracy: 0.8270 - val_loss: 0.3684 - val_accuracy: 0.8205
# Epoch 50/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3516 - accuracy: 0.8288
# Epoch 50: val_loss did not improve from 0.36836
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3516 - accuracy: 0.8288 - val_loss: 0.3699 - val_accuracy: 0.8221
# Epoch 51/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 0.8316
# Epoch 51: val_loss improved from 0.36836 to 0.36401, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3446 - accuracy: 0.8316 - val_loss: 0.3640 - val_accuracy: 0.8229
# Epoch 52/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3420 - accuracy: 0.8330
# Epoch 52: val_loss did not improve from 0.36401
# 799/799 [==============================] - 225s 282ms/step - loss: 0.3420 - accuracy: 0.8330 - val_loss: 0.3677 - val_accuracy: 0.8217
# Epoch 53/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3387 - accuracy: 0.8351
# Epoch 53: val_loss did not improve from 0.36401
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3387 - accuracy: 0.8351 - val_loss: 0.3658 - val_accuracy: 0.8246
# Epoch 54/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8361
# Epoch 54: val_loss improved from 0.36401 to 0.35833, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3369 - accuracy: 0.8361 - val_loss: 0.3583 - val_accuracy: 0.8282
# Epoch 55/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3339 - accuracy: 0.8377
# Epoch 55: val_loss did not improve from 0.35833
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3339 - accuracy: 0.8377 - val_loss: 0.3600 - val_accuracy: 0.8269
# Epoch 56/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3339 - accuracy: 0.8385
# Epoch 56: val_loss improved from 0.35833 to 0.35797, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3339 - accuracy: 0.8385 - val_loss: 0.3580 - val_accuracy: 0.8295
# Epoch 57/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.8409
# Epoch 57: val_loss did not improve from 0.35797
# 799/799 [==============================] - 225s 282ms/step - loss: 0.3294 - accuracy: 0.8409 - val_loss: 0.3592 - val_accuracy: 0.8293
# Epoch 58/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3254 - accuracy: 0.8427
# Epoch 58: val_loss improved from 0.35797 to 0.35403, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3254 - accuracy: 0.8427 - val_loss: 0.3540 - val_accuracy: 0.8309
# Epoch 59/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3224 - accuracy: 0.8445
# Epoch 59: val_loss improved from 0.35403 to 0.35105, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.3224 - accuracy: 0.8445 - val_loss: 0.3510 - val_accuracy: 0.8327
# Epoch 60/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3212 - accuracy: 0.8453
# Epoch 60: val_loss did not improve from 0.35105
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3212 - accuracy: 0.8453 - val_loss: 0.3515 - val_accuracy: 0.8341
# Epoch 61/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3189 - accuracy: 0.8464
# Epoch 61: val_loss improved from 0.35105 to 0.34777, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3189 - accuracy: 0.8464 - val_loss: 0.3478 - val_accuracy: 0.8368
# Epoch 62/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3177 - accuracy: 0.8474
# Epoch 62: val_loss improved from 0.34777 to 0.34704, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3177 - accuracy: 0.8474 - val_loss: 0.3470 - val_accuracy: 0.8360
# Epoch 63/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3141 - accuracy: 0.8491
# Epoch 63: val_loss improved from 0.34704 to 0.34508, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3141 - accuracy: 0.8491 - val_loss: 0.3451 - val_accuracy: 0.8370
# Epoch 64/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.8510
# Epoch 64: val_loss improved from 0.34508 to 0.34399, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3099 - accuracy: 0.8510 - val_loss: 0.3440 - val_accuracy: 0.8388
# Epoch 65/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3093 - accuracy: 0.8522
# Epoch 65: val_loss improved from 0.34399 to 0.34299, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3093 - accuracy: 0.8522 - val_loss: 0.3430 - val_accuracy: 0.8390
# Epoch 66/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.8534
# Epoch 66: val_loss did not improve from 0.34299
# 799/799 [==============================] - 225s 282ms/step - loss: 0.3069 - accuracy: 0.8534 - val_loss: 0.3448 - val_accuracy: 0.8401
# Epoch 67/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.8543
# Epoch 67: val_loss improved from 0.34299 to 0.33745, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.3053 - accuracy: 0.8543 - val_loss: 0.3375 - val_accuracy: 0.8417
# Epoch 68/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.8561
# Epoch 68: val_loss improved from 0.33745 to 0.33619, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 225s 282ms/step - loss: 0.3034 - accuracy: 0.8561 - val_loss: 0.3362 - val_accuracy: 0.8426
# Epoch 69/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3017 - accuracy: 0.8569
# Epoch 69: val_loss did not improve from 0.33619
# 799/799 [==============================] - 225s 282ms/step - loss: 0.3017 - accuracy: 0.8569 - val_loss: 0.3406 - val_accuracy: 0.8422
# Epoch 70/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2983 - accuracy: 0.8583
# Epoch 70: val_loss improved from 0.33619 to 0.33439, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2983 - accuracy: 0.8583 - val_loss: 0.3344 - val_accuracy: 0.8448
# Epoch 71/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2971 - accuracy: 0.8589
# Epoch 71: val_loss did not improve from 0.33439
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2971 - accuracy: 0.8589 - val_loss: 0.3362 - val_accuracy: 0.8424
# Epoch 72/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2970 - accuracy: 0.8596
# Epoch 72: val_loss did not improve from 0.33439
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2970 - accuracy: 0.8596 - val_loss: 0.3358 - val_accuracy: 0.8443
# Epoch 73/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2926 - accuracy: 0.8618
# Epoch 73: val_loss improved from 0.33439 to 0.33302, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2926 - accuracy: 0.8618 - val_loss: 0.3330 - val_accuracy: 0.8462
# Epoch 74/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2897 - accuracy: 0.8631
# Epoch 74: val_loss improved from 0.33302 to 0.33233, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.2897 - accuracy: 0.8631 - val_loss: 0.3323 - val_accuracy: 0.8469
# Epoch 75/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.8649
# Epoch 75: val_loss improved from 0.33233 to 0.33018, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2867 - accuracy: 0.8649 - val_loss: 0.3302 - val_accuracy: 0.8464
# Epoch 76/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2855 - accuracy: 0.8656
# Epoch 76: val_loss improved from 0.33018 to 0.32889, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.2855 - accuracy: 0.8656 - val_loss: 0.3289 - val_accuracy: 0.8490
# Epoch 77/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2852 - accuracy: 0.8653
# Epoch 77: val_loss improved from 0.32889 to 0.32763, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.2852 - accuracy: 0.8653 - val_loss: 0.3276 - val_accuracy: 0.8490
# Epoch 78/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2822 - accuracy: 0.8673
# Epoch 78: val_loss improved from 0.32763 to 0.32744, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.2822 - accuracy: 0.8673 - val_loss: 0.3274 - val_accuracy: 0.8505
# Epoch 79/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.8676
# Epoch 79: val_loss improved from 0.32744 to 0.32439, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.2810 - accuracy: 0.8676 - val_loss: 0.3244 - val_accuracy: 0.8522
# Epoch 80/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.8690
# Epoch 80: val_loss did not improve from 0.32439
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2788 - accuracy: 0.8690 - val_loss: 0.3286 - val_accuracy: 0.8510
# Epoch 81/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2906 - accuracy: 0.8660
# Epoch 81: val_loss did not improve from 0.32439
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2906 - accuracy: 0.8660 - val_loss: 0.3287 - val_accuracy: 0.8502
# Epoch 82/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.8696
# Epoch 82: val_loss did not improve from 0.32439
# 799/799 [==============================] - 226s 283ms/step - loss: 0.2823 - accuracy: 0.8696 - val_loss: 0.3296 - val_accuracy: 0.8510
# Epoch 83/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.8717
# Epoch 83: val_loss improved from 0.32439 to 0.32308, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 283ms/step - loss: 0.2760 - accuracy: 0.8717 - val_loss: 0.3231 - val_accuracy: 0.8526
# Epoch 84/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.8725
# Epoch 84: val_loss did not improve from 0.32308
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2735 - accuracy: 0.8725 - val_loss: 0.3280 - val_accuracy: 0.8535
# Epoch 85/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2752 - accuracy: 0.8723
# Epoch 85: val_loss improved from 0.32308 to 0.31951, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2752 - accuracy: 0.8723 - val_loss: 0.3195 - val_accuracy: 0.8556
# Epoch 86/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2703 - accuracy: 0.8740
# Epoch 86: val_loss did not improve from 0.31951
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2703 - accuracy: 0.8740 - val_loss: 0.3202 - val_accuracy: 0.8558
# Epoch 87/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2686 - accuracy: 0.8748
# Epoch 87: val_loss did not improve from 0.31951
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2686 - accuracy: 0.8748 - val_loss: 0.3220 - val_accuracy: 0.8550
# Epoch 88/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.8759
# Epoch 88: val_loss improved from 0.31951 to 0.31844, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2667 - accuracy: 0.8759 - val_loss: 0.3184 - val_accuracy: 0.8571
# Epoch 89/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2642 - accuracy: 0.8774
# Epoch 89: val_loss did not improve from 0.31844
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2642 - accuracy: 0.8774 - val_loss: 0.3196 - val_accuracy: 0.8572
# Epoch 90/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.8780
# Epoch 90: val_loss improved from 0.31844 to 0.31548, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2632 - accuracy: 0.8780 - val_loss: 0.3155 - val_accuracy: 0.8584
# Epoch 91/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2647 - accuracy: 0.8776
# Epoch 91: val_loss did not improve from 0.31548
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2647 - accuracy: 0.8776 - val_loss: 0.3165 - val_accuracy: 0.8562
# Epoch 92/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2625 - accuracy: 0.8790
# Epoch 92: val_loss did not improve from 0.31548
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2625 - accuracy: 0.8790 - val_loss: 0.3208 - val_accuracy: 0.8577
# Epoch 93/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.8798
# Epoch 93: val_loss improved from 0.31548 to 0.31538, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2588 - accuracy: 0.8798 - val_loss: 0.3154 - val_accuracy: 0.8610
# Epoch 94/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.8816
# Epoch 94: val_loss did not improve from 0.31538
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2565 - accuracy: 0.8816 - val_loss: 0.3165 - val_accuracy: 0.8580
# Epoch 95/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2557 - accuracy: 0.8820
# Epoch 95: val_loss improved from 0.31538 to 0.31499, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2557 - accuracy: 0.8820 - val_loss: 0.3150 - val_accuracy: 0.8591
# Epoch 96/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2587 - accuracy: 0.8815
# Epoch 96: val_loss did not improve from 0.31499
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2587 - accuracy: 0.8815 - val_loss: 0.3182 - val_accuracy: 0.8607
# Epoch 97/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2550 - accuracy: 0.8830
# Epoch 97: val_loss improved from 0.31499 to 0.31314, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2550 - accuracy: 0.8830 - val_loss: 0.3131 - val_accuracy: 0.8622
# Epoch 98/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2499 - accuracy: 0.8852
# Epoch 98: val_loss did not improve from 0.31314
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2499 - accuracy: 0.8852 - val_loss: 0.3141 - val_accuracy: 0.8622
# Epoch 99/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2512 - accuracy: 0.8850
# Epoch 99: val_loss did not improve from 0.31314
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2512 - accuracy: 0.8850 - val_loss: 0.3181 - val_accuracy: 0.8583
# Epoch 100/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2512 - accuracy: 0.8848
# Epoch 100: val_loss improved from 0.31314 to 0.31266, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2512 - accuracy: 0.8848 - val_loss: 0.3127 - val_accuracy: 0.8634
# Epoch 101/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2472 - accuracy: 0.8865
# Epoch 101: val_loss improved from 0.31266 to 0.30892, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2472 - accuracy: 0.8865 - val_loss: 0.3089 - val_accuracy: 0.8645
# Epoch 102/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2460 - accuracy: 0.8878
# Epoch 102: val_loss did not improve from 0.30892
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2460 - accuracy: 0.8878 - val_loss: 0.3143 - val_accuracy: 0.8617
# Epoch 103/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.8815
# Epoch 103: val_loss did not improve from 0.30892
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2749 - accuracy: 0.8815 - val_loss: 0.3175 - val_accuracy: 0.8604
# Epoch 104/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2504 - accuracy: 0.8857
# Epoch 104: val_loss did not improve from 0.30892
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2504 - accuracy: 0.8857 - val_loss: 0.3130 - val_accuracy: 0.8627
# Epoch 105/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.8882
# Epoch 105: val_loss did not improve from 0.30892
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2450 - accuracy: 0.8882 - val_loss: 0.3103 - val_accuracy: 0.8646
# Epoch 106/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.8891
# Epoch 106: val_loss improved from 0.30892 to 0.30785, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2424 - accuracy: 0.8891 - val_loss: 0.3079 - val_accuracy: 0.8650
# Epoch 107/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.8892
# Epoch 107: val_loss improved from 0.30785 to 0.30721, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2444 - accuracy: 0.8892 - val_loss: 0.3072 - val_accuracy: 0.8666
# Epoch 108/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.8895
# Epoch 108: val_loss improved from 0.30721 to 0.30611, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2423 - accuracy: 0.8895 - val_loss: 0.3061 - val_accuracy: 0.8678
# Epoch 109/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2435 - accuracy: 0.8893
# Epoch 109: val_loss did not improve from 0.30611
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2435 - accuracy: 0.8893 - val_loss: 0.3155 - val_accuracy: 0.8658
# Epoch 110/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.8909
# Epoch 110: val_loss did not improve from 0.30611
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2414 - accuracy: 0.8909 - val_loss: 0.3089 - val_accuracy: 0.8661
# Epoch 111/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2368 - accuracy: 0.8924
# Epoch 111: val_loss did not improve from 0.30611
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2368 - accuracy: 0.8924 - val_loss: 0.3088 - val_accuracy: 0.8657
# Epoch 112/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.8935
# Epoch 112: val_loss did not improve from 0.30611
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2346 - accuracy: 0.8935 - val_loss: 0.3088 - val_accuracy: 0.8676
# Epoch 113/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.8935
# Epoch 113: val_loss did not improve from 0.30611
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2338 - accuracy: 0.8935 - val_loss: 0.3090 - val_accuracy: 0.8676
# Epoch 114/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.8940
# Epoch 114: val_loss improved from 0.30611 to 0.30441, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2330 - accuracy: 0.8940 - val_loss: 0.3044 - val_accuracy: 0.8683
# Epoch 115/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.8946
# Epoch 115: val_loss improved from 0.30441 to 0.30310, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2337 - accuracy: 0.8946 - val_loss: 0.3031 - val_accuracy: 0.8694
# Epoch 116/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2320 - accuracy: 0.8951
# Epoch 116: val_loss did not improve from 0.30310
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2320 - accuracy: 0.8951 - val_loss: 0.3083 - val_accuracy: 0.8669
# Epoch 117/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.8952
# Epoch 117: val_loss did not improve from 0.30310
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2330 - accuracy: 0.8952 - val_loss: 0.3056 - val_accuracy: 0.8701
# Epoch 118/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.8963
# Epoch 118: val_loss improved from 0.30310 to 0.30234, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2293 - accuracy: 0.8963 - val_loss: 0.3023 - val_accuracy: 0.8715
# Epoch 119/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.8969
# Epoch 119: val_loss did not improve from 0.30234
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2272 - accuracy: 0.8969 - val_loss: 0.3104 - val_accuracy: 0.8687
# Epoch 120/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.8985
# Epoch 120: val_loss did not improve from 0.30234
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2247 - accuracy: 0.8985 - val_loss: 0.3032 - val_accuracy: 0.8706
# Epoch 121/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2254 - accuracy: 0.8981
# Epoch 121: val_loss did not improve from 0.30234
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2254 - accuracy: 0.8981 - val_loss: 0.3072 - val_accuracy: 0.8702
# Epoch 122/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.8995
# Epoch 122: val_loss did not improve from 0.30234
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2241 - accuracy: 0.8995 - val_loss: 0.3048 - val_accuracy: 0.8722
# Epoch 123/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.8972
# Epoch 123: val_loss did not improve from 0.30234
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2322 - accuracy: 0.8972 - val_loss: 0.3068 - val_accuracy: 0.8705
# Epoch 124/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2225 - accuracy: 0.9002
# Epoch 124: val_loss did not improve from 0.30234
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2225 - accuracy: 0.9002 - val_loss: 0.3048 - val_accuracy: 0.8704
# Epoch 125/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2197 - accuracy: 0.9010
# Epoch 125: val_loss did not improve from 0.30234
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2197 - accuracy: 0.9010 - val_loss: 0.3030 - val_accuracy: 0.8719
# Epoch 126/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2188 - accuracy: 0.9016
# Epoch 126: val_loss improved from 0.30234 to 0.29996, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2188 - accuracy: 0.9016 - val_loss: 0.3000 - val_accuracy: 0.8739
# Epoch 127/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2190 - accuracy: 0.9013
# Epoch 127: val_loss did not improve from 0.29996
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2190 - accuracy: 0.9013 - val_loss: 0.3042 - val_accuracy: 0.8721
# Epoch 128/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2172 - accuracy: 0.9027
# Epoch 128: val_loss did not improve from 0.29996
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2172 - accuracy: 0.9027 - val_loss: 0.3040 - val_accuracy: 0.8727
# Epoch 129/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2181 - accuracy: 0.9023
# Epoch 129: val_loss did not improve from 0.29996
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2181 - accuracy: 0.9023 - val_loss: 0.3000 - val_accuracy: 0.8758
# Epoch 130/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2163 - accuracy: 0.9027
# Epoch 130: val_loss did not improve from 0.29996
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2163 - accuracy: 0.9027 - val_loss: 0.3014 - val_accuracy: 0.8726
# Epoch 131/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2160 - accuracy: 0.9032
# Epoch 131: val_loss improved from 0.29996 to 0.29910, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2160 - accuracy: 0.9032 - val_loss: 0.2991 - val_accuracy: 0.8749
# Epoch 132/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.9041
# Epoch 132: val_loss did not improve from 0.29910
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2144 - accuracy: 0.9041 - val_loss: 0.3008 - val_accuracy: 0.8738
# Epoch 133/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2130 - accuracy: 0.9044
# Epoch 133: val_loss did not improve from 0.29910
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2130 - accuracy: 0.9044 - val_loss: 0.3014 - val_accuracy: 0.8737
# Epoch 134/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9059
# Epoch 134: val_loss did not improve from 0.29910
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2109 - accuracy: 0.9059 - val_loss: 0.3005 - val_accuracy: 0.8733
# Epoch 135/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2116 - accuracy: 0.9051
# Epoch 135: val_loss did not improve from 0.29910
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2116 - accuracy: 0.9051 - val_loss: 0.3029 - val_accuracy: 0.8754
# Epoch 136/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2132 - accuracy: 0.9052
# Epoch 136: val_loss did not improve from 0.29910
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2132 - accuracy: 0.9052 - val_loss: 0.3225 - val_accuracy: 0.8665
# Epoch 137/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.9050
# Epoch 137: val_loss improved from 0.29910 to 0.29708, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2144 - accuracy: 0.9050 - val_loss: 0.2971 - val_accuracy: 0.8760
# Epoch 138/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2096 - accuracy: 0.9067
# Epoch 138: val_loss did not improve from 0.29708
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2096 - accuracy: 0.9067 - val_loss: 0.2984 - val_accuracy: 0.8764
# Epoch 139/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2091 - accuracy: 0.9072
# Epoch 139: val_loss did not improve from 0.29708
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2091 - accuracy: 0.9072 - val_loss: 0.2984 - val_accuracy: 0.8762
# Epoch 140/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2066 - accuracy: 0.9079
# Epoch 140: val_loss did not improve from 0.29708
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2066 - accuracy: 0.9079 - val_loss: 0.2980 - val_accuracy: 0.8775
# Epoch 141/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2087 - accuracy: 0.9076
# Epoch 141: val_loss did not improve from 0.29708
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2087 - accuracy: 0.9076 - val_loss: 0.3023 - val_accuracy: 0.8748
# Epoch 142/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9079
# Epoch 142: val_loss did not improve from 0.29708
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2079 - accuracy: 0.9079 - val_loss: 0.2999 - val_accuracy: 0.8744
# Epoch 143/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2039 - accuracy: 0.9090
# Epoch 143: val_loss improved from 0.29708 to 0.29689, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2039 - accuracy: 0.9090 - val_loss: 0.2969 - val_accuracy: 0.8776
# Epoch 144/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9102
# Epoch 144: val_loss did not improve from 0.29689
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2025 - accuracy: 0.9102 - val_loss: 0.2987 - val_accuracy: 0.8769
# Epoch 145/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2041 - accuracy: 0.9096
# Epoch 145: val_loss did not improve from 0.29689
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2041 - accuracy: 0.9096 - val_loss: 0.2980 - val_accuracy: 0.8789
# Epoch 146/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2017 - accuracy: 0.9103
# Epoch 146: val_loss improved from 0.29689 to 0.29550, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2017 - accuracy: 0.9103 - val_loss: 0.2955 - val_accuracy: 0.8791
# Epoch 147/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2011 - accuracy: 0.9109
# Epoch 147: val_loss did not improve from 0.29550
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2011 - accuracy: 0.9109 - val_loss: 0.2984 - val_accuracy: 0.8786
# Epoch 148/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2013 - accuracy: 0.9112
# Epoch 148: val_loss improved from 0.29550 to 0.29194, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2013 - accuracy: 0.9112 - val_loss: 0.2919 - val_accuracy: 0.8809
# Epoch 149/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9065
# Epoch 149: val_loss did not improve from 0.29194
# 799/799 [==============================] - 225s 282ms/step - loss: 0.2165 - accuracy: 0.9065 - val_loss: 0.3032 - val_accuracy: 0.8778
# Epoch 150/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9096
# Epoch 150: val_loss did not improve from 0.29194
# 799/799 [==============================] - 226s 282ms/step - loss: 0.2104 - accuracy: 0.9096 - val_loss: 0.3003 - val_accuracy: 0.8778
# Epoch 151/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9128
# ...
# Epoch 177/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1824 - accuracy: 0.9211
# Epoch 177: val_loss did not improve from 0.29194
# 799/799 [==============================] - 226s 283ms/step - loss: 0.1824 - accuracy: 0.9211 - val_loss: 0.2951 - val_accuracy: 0.8834
# Epoch 178/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1809 - accuracy: 0.9212
# Epoch 178: val_loss did not improve from 0.29194
# 799/799 [==============================] - 226s 283ms/step - loss: 0.1809 - accuracy: 0.9212 - val_loss: 0.2953 - val_accuracy: 0.8837
# Training Time:  40215.39717578888 seconds
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2429 - accuracy: 0.8900 - val_loss: 0.2995 - val_accuracy: 0.8672
# Epoch 114/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2357 - accuracy: 0.8931 - val_loss: 0.2999 - val_accuracy: 0.8692
# Epoch 115/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2377 - accuracy: 0.8920 - val_loss: 0.3015 - val_accuracy: 0.8681
# Epoch 116/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.2346 - accuracy: 0.8937 - val_loss: 0.3017 - val_accuracy: 0.8690
# Epoch 117/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2327 - accuracy: 0.8942 - val_loss: 0.3020 - val_accuracy: 0.8677
# Epoch 118/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2327 - accuracy: 0.8948 - val_loss: 0.3028 - val_accuracy: 0.8695
# Epoch 119/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2351 - accuracy: 0.8941 - val_loss: 0.2987 - val_accuracy: 0.8696
# Epoch 120/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2340 - accuracy: 0.8946 - val_loss: 0.3028 - val_accuracy: 0.8679
# Epoch 121/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2349 - accuracy: 0.8945 - val_loss: 0.3002 - val_accuracy: 0.8712
# Epoch 122/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2267 - accuracy: 0.8976 - val_loss: 0.3007 - val_accuracy: 0.8688
# Epoch 123/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2279 - accuracy: 0.8967 - val_loss: 0.2998 - val_accuracy: 0.8701
# Epoch 124/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2339 - accuracy: 0.8958 - val_loss: 0.3002 - val_accuracy: 0.8715
# Epoch 125/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2267 - accuracy: 0.8975 - val_loss: 0.2954 - val_accuracy: 0.8719
# Epoch 126/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2236 - accuracy: 0.8994 - val_loss: 0.2999 - val_accuracy: 0.8708
# Epoch 127/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2243 - accuracy: 0.8995 - val_loss: 0.3017 - val_accuracy: 0.8710
# Epoch 128/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2272 - accuracy: 0.8984 - val_loss: 0.2992 - val_accuracy: 0.8712
# Epoch 129/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.2222 - accuracy: 0.9004 - val_loss: 0.2982 - val_accuracy: 0.8716
# Epoch 130/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.2211 - accuracy: 0.9002 - val_loss: 0.2979 - val_accuracy: 0.8730
# Epoch 131/500
# 799/799 [==============================] - 20s 24ms/step - loss: 0.2198 - accuracy: 0.9011 - val_loss: 0.2968 - val_accuracy: 0.8723
# Epoch 132/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2197 - accuracy: 0.9010 - val_loss: 0.2992 - val_accuracy: 0.8722
# Epoch 133/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2232 - accuracy: 0.9011 - val_loss: 0.2961 - val_accuracy: 0.8734
# Epoch 134/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2168 - accuracy: 0.9025 - val_loss: 0.3089 - val_accuracy: 0.8700
# Epoch 135/500
# 799/799 [==============================] - 21s 26ms/step - loss: 0.2193 - accuracy: 0.9025 - val_loss: 0.2949 - val_accuracy: 0.8737
# Epoch 136/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2135 - accuracy: 0.9041 - val_loss: 0.2980 - val_accuracy: 0.8737
# Epoch 137/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2170 - accuracy: 0.9034 - val_loss: 0.3174 - val_accuracy: 0.8702
# Epoch 138/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2290 - accuracy: 0.8993 - val_loss: 0.2977 - val_accuracy: 0.8735
# Epoch 139/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2159 - accuracy: 0.9035 - val_loss: 0.2988 - val_accuracy: 0.8742
# Epoch 140/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2118 - accuracy: 0.9058 - val_loss: 0.2936 - val_accuracy: 0.8763
# Epoch 141/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2268 - accuracy: 0.9027 - val_loss: 0.3564 - val_accuracy: 0.8664
# Epoch 142/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2820 - accuracy: 0.8914 - val_loss: 0.3034 - val_accuracy: 0.8721
# Epoch 143/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.2217 - accuracy: 0.9037 - val_loss: 0.2956 - val_accuracy: 0.8759
# Epoch 144/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.2156 - accuracy: 0.9051 - val_loss: 0.2939 - val_accuracy: 0.8760
# Epoch 145/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2223 - accuracy: 0.9040 - val_loss: 0.2958 - val_accuracy: 0.8752
# Epoch 146/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.2141 - accuracy: 0.9059 - val_loss: 0.2936 - val_accuracy: 0.8753
# Epoch 147/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2074 - accuracy: 0.9076 - val_loss: 0.2922 - val_accuracy: 0.8762
# Epoch 148/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2077 - accuracy: 0.9076 - val_loss: 0.2918 - val_accuracy: 0.8786
# Epoch 149/500
# 799/799 [==============================] - 20s 24ms/step - loss: 0.2076 - accuracy: 0.9075 - val_loss: 0.2934 - val_accuracy: 0.8784
# Epoch 150/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2066 - accuracy: 0.9084 - val_loss: 0.2922 - val_accuracy: 0.8785
# Epoch 151/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.2097 - accuracy: 0.9075 - val_loss: 0.3028 - val_accuracy: 0.8739
# Epoch 152/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.2088 - accuracy: 0.9079 - val_loss: 0.2949 - val_accuracy: 0.8781
# Epoch 153/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2566 - accuracy: 0.8932 - val_loss: 0.3143 - val_accuracy: 0.8664
# Epoch 154/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.2193 - accuracy: 0.9029 - val_loss: 0.3029 - val_accuracy: 0.8729
# Epoch 155/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2160 - accuracy: 0.9062 - val_loss: 0.3026 - val_accuracy: 0.8740
# Epoch 156/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2085 - accuracy: 0.9078 - val_loss: 0.2959 - val_accuracy: 0.8742
# Epoch 157/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2060 - accuracy: 0.9091 - val_loss: 0.2967 - val_accuracy: 0.8754
# Epoch 158/500
# 799/799 [==============================] - 20s 24ms/step - loss: 0.2069 - accuracy: 0.9089 - val_loss: 0.2951 - val_accuracy: 0.8772
# Epoch 159/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2039 - accuracy: 0.9103 - val_loss: 0.2981 - val_accuracy: 0.8763
# Epoch 160/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2021 - accuracy: 0.9109 - val_loss: 0.2956 - val_accuracy: 0.8783
# Epoch 161/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2015 - accuracy: 0.9105 - val_loss: 0.2974 - val_accuracy: 0.8777
# Epoch 162/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.2022 - accuracy: 0.9112 - val_loss: 0.2994 - val_accuracy: 0.8772
# Epoch 163/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.2017 - accuracy: 0.9118 - val_loss: 0.2954 - val_accuracy: 0.8776
# Epoch 164/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.2035 - accuracy: 0.9109 - val_loss: 0.2974 - val_accuracy: 0.8768
# Epoch 165/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1998 - accuracy: 0.9120 - val_loss: 0.2933 - val_accuracy: 0.8792
# Epoch 166/500
# 799/799 [==============================] - 19s 23ms/step - loss: 0.1990 - accuracy: 0.9123 - val_loss: 0.3056 - val_accuracy: 0.8746
# Epoch 167/500
# 799/799 [==============================] - 19s 23ms/step - loss: 0.2000 - accuracy: 0.9119 - val_loss: 0.2964 - val_accuracy: 0.8790
# Epoch 168/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.2003 - accuracy: 0.9120 - val_loss: 0.2965 - val_accuracy: 0.8783
# Epoch 169/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.2236 - accuracy: 0.9093 - val_loss: 0.2991 - val_accuracy: 0.8778
# Epoch 170/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.2149 - accuracy: 0.9119 - val_loss: 0.3086 - val_accuracy: 0.8750
# Epoch 171/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1998 - accuracy: 0.9132 - val_loss: 0.2951 - val_accuracy: 0.8799
# Epoch 172/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1963 - accuracy: 0.9145 - val_loss: 0.2963 - val_accuracy: 0.8793
# Epoch 173/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1937 - accuracy: 0.9150 - val_loss: 0.2983 - val_accuracy: 0.8796
# Epoch 174/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1903 - accuracy: 0.9164 - val_loss: 0.2913 - val_accuracy: 0.8816
# Epoch 175/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1911 - accuracy: 0.9163 - val_loss: 0.2920 - val_accuracy: 0.8823
# Epoch 176/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1896 - accuracy: 0.9170 - val_loss: 0.2981 - val_accuracy: 0.8809
# Epoch 177/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1900 - accuracy: 0.9169 - val_loss: 0.2995 - val_accuracy: 0.8801
# Epoch 178/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1926 - accuracy: 0.9161 - val_loss: 0.2909 - val_accuracy: 0.8814
# Epoch 179/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1893 - accuracy: 0.9171 - val_loss: 0.2903 - val_accuracy: 0.8836
# Epoch 180/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1890 - accuracy: 0.9176 - val_loss: 0.2945 - val_accuracy: 0.8804
# Epoch 181/500
# 799/799 [==============================] - 19s 23ms/step - loss: 0.1863 - accuracy: 0.9182 - val_loss: 0.2940 - val_accuracy: 0.8822
# Epoch 182/500
# 799/799 [==============================] - 19s 23ms/step - loss: 0.1854 - accuracy: 0.9193 - val_loss: 0.2916 - val_accuracy: 0.8834
# Epoch 183/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1882 - accuracy: 0.9184 - val_loss: 0.2903 - val_accuracy: 0.8833
# Epoch 184/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1861 - accuracy: 0.9190 - val_loss: 0.2956 - val_accuracy: 0.8821
# Epoch 185/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1893 - accuracy: 0.9179 - val_loss: 0.2924 - val_accuracy: 0.8835
# Epoch 186/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1838 - accuracy: 0.9199 - val_loss: 0.2878 - val_accuracy: 0.8853
# Epoch 187/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1812 - accuracy: 0.9208 - val_loss: 0.2940 - val_accuracy: 0.8836
# Epoch 188/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1869 - accuracy: 0.9198 - val_loss: 0.2979 - val_accuracy: 0.8839
# Epoch 189/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1834 - accuracy: 0.9208 - val_loss: 0.2930 - val_accuracy: 0.8846
# Epoch 190/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1828 - accuracy: 0.9208 - val_loss: 0.2951 - val_accuracy: 0.8848
# Epoch 191/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1797 - accuracy: 0.9222 - val_loss: 0.2952 - val_accuracy: 0.8854
# Epoch 192/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1780 - accuracy: 0.9225 - val_loss: 0.2902 - val_accuracy: 0.8839
# Epoch 193/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1794 - accuracy: 0.9224 - val_loss: 0.2954 - val_accuracy: 0.8856
# Epoch 194/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1793 - accuracy: 0.9225 - val_loss: 0.2906 - val_accuracy: 0.8865
# Epoch 195/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1768 - accuracy: 0.9229 - val_loss: 0.2956 - val_accuracy: 0.8845
# Epoch 196/500
# 799/799 [==============================] - 20s 24ms/step - loss: 0.1769 - accuracy: 0.9230 - val_loss: 0.2912 - val_accuracy: 0.8844
# Epoch 197/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1763 - accuracy: 0.9237 - val_loss: 0.2936 - val_accuracy: 0.8861
# Epoch 198/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1786 - accuracy: 0.9231 - val_loss: 0.2919 - val_accuracy: 0.8853
# Epoch 199/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1774 - accuracy: 0.9237 - val_loss: 0.2957 - val_accuracy: 0.8851
# Epoch 200/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1752 - accuracy: 0.9244 - val_loss: 0.2915 - val_accuracy: 0.8866
# Epoch 201/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1738 - accuracy: 0.9248 - val_loss: 0.2927 - val_accuracy: 0.8861
# Epoch 202/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1747 - accuracy: 0.9247 - val_loss: 0.3182 - val_accuracy: 0.8753
# Epoch 203/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1775 - accuracy: 0.9237 - val_loss: 0.2931 - val_accuracy: 0.8860
# Epoch 204/500
# 799/799 [==============================] - 20s 26ms/step - loss: 0.1723 - accuracy: 0.9253 - val_loss: 0.2937 - val_accuracy: 0.8868
# Epoch 205/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1786 - accuracy: 0.9234 - val_loss: 0.2929 - val_accuracy: 0.8866
# Epoch 206/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1742 - accuracy: 0.9256 - val_loss: 0.2946 - val_accuracy: 0.8869
# Epoch 207/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1756 - accuracy: 0.9249 - val_loss: 0.2977 - val_accuracy: 0.8857
# Epoch 208/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1711 - accuracy: 0.9267 - val_loss: 0.2894 - val_accuracy: 0.8877
# Epoch 209/500
# 799/799 [==============================] - 21s 26ms/step - loss: 0.1708 - accuracy: 0.9267 - val_loss: 0.2937 - val_accuracy: 0.8863
# Epoch 210/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1713 - accuracy: 0.9264 - val_loss: 0.2966 - val_accuracy: 0.8860
# Epoch 211/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1714 - accuracy: 0.9263 - val_loss: 0.2967 - val_accuracy: 0.8865
# Epoch 212/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1699 - accuracy: 0.9269 - val_loss: 0.2942 - val_accuracy: 0.8876
# Epoch 213/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1672 - accuracy: 0.9282 - val_loss: 0.2923 - val_accuracy: 0.8882
# Epoch 214/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1701 - accuracy: 0.9270 - val_loss: 0.2963 - val_accuracy: 0.8871
# Epoch 215/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1683 - accuracy: 0.9277 - val_loss: 0.2918 - val_accuracy: 0.8879
# Epoch 216/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1680 - accuracy: 0.9278 - val_loss: 0.2916 - val_accuracy: 0.8880
# Training Time:  4259.20539855957 seconds

# %% [markdown]
# # Saving the model and training history

# %%
lstm_model.save('LSTM_Architecture_5_Features.h5')
np.save('LSTM_history_5_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of LSTM Neural Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of LSTM Neural Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for LSTM Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ 0.46349357],
#         [ 0.36358773],
#         [ 3.37428511],
#         [ 2.21070338],
#         [-0.53335855]],
#
#        [[-3.12902325],
#         [-2.41096786],
#         [-4.83420457],
#         [-4.38417685],
#         [ 1.45759665]],
#
#        [[ 1.56338732],
#         [ 1.49249955],
#         [ 1.91877559],
#         [ 1.81817072],
#         [ 1.62761275]],
#
#        ...,
#
#        [[ 0.69592067],
#         [ 0.84838968],
#         [-0.60272074],
#         [-0.04577766],
#         [-0.3113151 ]],
#
#        [[ 2.17107007],
#         [ 2.96016373],
#         [ 3.46610892],
#         [ 2.54044544],
#         [ 0.99792245]],
#
#        [[ 0.16525652],
#         [-0.05828783],
#         [-0.23818711],
#         [-0.50661368],
#         [-0.80537552]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = lstm_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 53s 11ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = lstm_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.88, Test loss: 0.30

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88     77676
#            1       0.89      0.86      0.88     77614
#
#     accuracy                           0.88    155290
#    macro avg       0.88      0.88      0.88    155290
# weighted avg       0.88      0.88      0.88    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix LSTM - 5 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.8782471504926267
# Precision: 0.8935787935265014
# Recall: 0.8586595201896565
# F1-score: 0.8757712145602681
# AUC-ROC: 0.9516722522835144

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['LSTM - 5'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()
