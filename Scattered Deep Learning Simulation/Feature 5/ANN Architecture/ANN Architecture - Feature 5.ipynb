# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 5/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 5/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 5/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 5/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - ANN</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# # 1. Network Initialization

# %%
input_dim = X_train.shape[1]  

batch_size = 1024 
epochs = 500  
learning_rate = 0.0001  
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# # 2. Define Architecture

# %%
ann_model = Sequential([
    
    Dense(2048, input_dim=input_dim, activation='relu'),
    Dense(1024, activation='relu'),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid') 
    
])

# %%
ann_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2048)              12288
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,807,809
# Trainable params: 2,807,809
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
ann_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# # Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/ANN_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Checkpoint not found. Initializing new model...

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = ann_model.fit(X_train, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6448 - accuracy: 0.6213
# Epoch 1: val_loss improved from inf to 0.63212, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 38s 65ms/step - loss: 0.6448 - accuracy: 0.6213 - val_loss: 0.6321 - val_accuracy: 0.6340
# Epoch 2/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6227 - accuracy: 0.6434
# Epoch 2: val_loss improved from 0.63212 to 0.61907, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.6227 - accuracy: 0.6434 - val_loss: 0.6191 - val_accuracy: 0.6461
# Epoch 3/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6122 - accuracy: 0.6518
# Epoch 3: val_loss improved from 0.61907 to 0.61150, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 65ms/step - loss: 0.6122 - accuracy: 0.6518 - val_loss: 0.6115 - val_accuracy: 0.6515
# Epoch 4/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6039 - accuracy: 0.6588
# Epoch 4: val_loss improved from 0.61150 to 0.60400, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6039 - accuracy: 0.6588 - val_loss: 0.6040 - val_accuracy: 0.6583
# Epoch 5/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5955 - accuracy: 0.6648
# Epoch 5: val_loss improved from 0.60400 to 0.59178, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5955 - accuracy: 0.6648 - val_loss: 0.5918 - val_accuracy: 0.6692
# Epoch 6/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5873 - accuracy: 0.6719
# Epoch 6: val_loss improved from 0.59178 to 0.58614, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 36s 65ms/step - loss: 0.5873 - accuracy: 0.6719 - val_loss: 0.5861 - val_accuracy: 0.6731
# Epoch 7/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5804 - accuracy: 0.6778
# Epoch 7: val_loss improved from 0.58614 to 0.58028, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.5804 - accuracy: 0.6778 - val_loss: 0.5803 - val_accuracy: 0.6786
# Epoch 8/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5721 - accuracy: 0.6844
# Epoch 8: val_loss improved from 0.58028 to 0.57176, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5721 - accuracy: 0.6844 - val_loss: 0.5718 - val_accuracy: 0.6851
# Epoch 9/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.5652 - accuracy: 0.6905
# Epoch 9: val_loss improved from 0.57176 to 0.56679, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5652 - accuracy: 0.6904 - val_loss: 0.5668 - val_accuracy: 0.6892
# Epoch 10/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5580 - accuracy: 0.6958
# Epoch 10: val_loss improved from 0.56679 to 0.55545, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5580 - accuracy: 0.6958 - val_loss: 0.5555 - val_accuracy: 0.6970
# Epoch 11/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5504 - accuracy: 0.7016
# Epoch 11: val_loss did not improve from 0.55545
# 546/546 [==============================] - 34s 62ms/step - loss: 0.5504 - accuracy: 0.7016 - val_loss: 0.5598 - val_accuracy: 0.6977
# Epoch 12/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5445 - accuracy: 0.7067
# Epoch 12: val_loss improved from 0.55545 to 0.55476, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5445 - accuracy: 0.7067 - val_loss: 0.5548 - val_accuracy: 0.6993
# Epoch 13/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5368 - accuracy: 0.7115
# Epoch 13: val_loss improved from 0.55476 to 0.54337, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5368 - accuracy: 0.7115 - val_loss: 0.5434 - val_accuracy: 0.7105
# Epoch 14/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.5307 - accuracy: 0.7163
# Epoch 14: val_loss improved from 0.54337 to 0.53749, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5308 - accuracy: 0.7162 - val_loss: 0.5375 - val_accuracy: 0.7131
# Epoch 15/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5254 - accuracy: 0.7208
# Epoch 15: val_loss improved from 0.53749 to 0.53353, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5254 - accuracy: 0.7208 - val_loss: 0.5335 - val_accuracy: 0.7152
# Epoch 16/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5185 - accuracy: 0.7259
# Epoch 16: val_loss improved from 0.53353 to 0.52608, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 62ms/step - loss: 0.5185 - accuracy: 0.7259 - val_loss: 0.5261 - val_accuracy: 0.7206
# Epoch 17/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5139 - accuracy: 0.7280
# Epoch 17: val_loss improved from 0.52608 to 0.52194, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5139 - accuracy: 0.7280 - val_loss: 0.5219 - val_accuracy: 0.7244
# Epoch 18/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5079 - accuracy: 0.7324
# Epoch 18: val_loss did not improve from 0.52194
# 546/546 [==============================] - 34s 62ms/step - loss: 0.5079 - accuracy: 0.7324 - val_loss: 0.5310 - val_accuracy: 0.7171
# Epoch 19/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5027 - accuracy: 0.7374
# Epoch 19: val_loss improved from 0.52194 to 0.51611, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.5027 - accuracy: 0.7374 - val_loss: 0.5161 - val_accuracy: 0.7276
# Epoch 20/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.4981 - accuracy: 0.7398
# Epoch 20: val_loss improved from 0.51611 to 0.51054, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4981 - accuracy: 0.7399 - val_loss: 0.5105 - val_accuracy: 0.7328
# Epoch 21/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.4922 - accuracy: 0.7437
# Epoch 21: val_loss improved from 0.51054 to 0.50815, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4921 - accuracy: 0.7438 - val_loss: 0.5082 - val_accuracy: 0.7326
# Epoch 22/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4873 - accuracy: 0.7481
# Epoch 22: val_loss improved from 0.50815 to 0.49680, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4873 - accuracy: 0.7481 - val_loss: 0.4968 - val_accuracy: 0.7417
# Epoch 23/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4831 - accuracy: 0.7504
# Epoch 23: val_loss did not improve from 0.49680
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4831 - accuracy: 0.7504 - val_loss: 0.4969 - val_accuracy: 0.7417
# Epoch 24/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4789 - accuracy: 0.7537
# Epoch 24: val_loss did not improve from 0.49680
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4789 - accuracy: 0.7537 - val_loss: 0.4987 - val_accuracy: 0.7436
# Epoch 25/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.4747 - accuracy: 0.7565
# Epoch 25: val_loss improved from 0.49680 to 0.49117, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4748 - accuracy: 0.7565 - val_loss: 0.4912 - val_accuracy: 0.7458
# Epoch 26/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.4706 - accuracy: 0.7592
# Epoch 26: val_loss improved from 0.49117 to 0.48388, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4706 - accuracy: 0.7592 - val_loss: 0.4839 - val_accuracy: 0.7512
# Epoch 27/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4657 - accuracy: 0.7621
# Epoch 27: val_loss did not improve from 0.48388
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4657 - accuracy: 0.7621 - val_loss: 0.4844 - val_accuracy: 0.7512
# Epoch 28/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7648
# Epoch 28: val_loss did not improve from 0.48388
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4622 - accuracy: 0.7648 - val_loss: 0.4866 - val_accuracy: 0.7493
# Epoch 29/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4586 - accuracy: 0.7672
# Epoch 29: val_loss improved from 0.48388 to 0.47643, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4586 - accuracy: 0.7672 - val_loss: 0.4764 - val_accuracy: 0.7567
# Epoch 30/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.4541 - accuracy: 0.7703
# Epoch 30: val_loss did not improve from 0.47643
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4541 - accuracy: 0.7703 - val_loss: 0.4812 - val_accuracy: 0.7524
# Epoch 31/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.4488 - accuracy: 0.7737
# Epoch 31: val_loss did not improve from 0.47643
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4488 - accuracy: 0.7737 - val_loss: 0.4766 - val_accuracy: 0.7557
# Epoch 32/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4471 - accuracy: 0.7751
# Epoch 32: val_loss improved from 0.47643 to 0.47321, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4471 - accuracy: 0.7751 - val_loss: 0.4732 - val_accuracy: 0.7573
# Epoch 33/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4433 - accuracy: 0.7774
# Epoch 33: val_loss did not improve from 0.47321
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4433 - accuracy: 0.7774 - val_loss: 0.4766 - val_accuracy: 0.7576
# Epoch 34/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4391 - accuracy: 0.7793
# Epoch 34: val_loss improved from 0.47321 to 0.46022, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4391 - accuracy: 0.7793 - val_loss: 0.4602 - val_accuracy: 0.7673
# Epoch 35/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4381 - accuracy: 0.7808
# Epoch 35: val_loss did not improve from 0.46022
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4381 - accuracy: 0.7808 - val_loss: 0.4746 - val_accuracy: 0.7566
# Epoch 36/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4340 - accuracy: 0.7834
# Epoch 36: val_loss improved from 0.46022 to 0.45870, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4340 - accuracy: 0.7834 - val_loss: 0.4587 - val_accuracy: 0.7699
# Epoch 37/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4296 - accuracy: 0.7862
# Epoch 37: val_loss did not improve from 0.45870
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4296 - accuracy: 0.7862 - val_loss: 0.4758 - val_accuracy: 0.7554
# Epoch 38/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4255 - accuracy: 0.7880
# Epoch 38: val_loss improved from 0.45870 to 0.45658, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4255 - accuracy: 0.7880 - val_loss: 0.4566 - val_accuracy: 0.7685
# Epoch 39/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4234 - accuracy: 0.7895
# Epoch 39: val_loss improved from 0.45658 to 0.44704, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4234 - accuracy: 0.7895 - val_loss: 0.4470 - val_accuracy: 0.7749
# Epoch 40/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4211 - accuracy: 0.7906
# Epoch 40: val_loss improved from 0.44704 to 0.44239, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.4211 - accuracy: 0.7906 - val_loss: 0.4424 - val_accuracy: 0.7812
# Epoch 41/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4178 - accuracy: 0.7932
# Epoch 41: val_loss did not improve from 0.44239
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4178 - accuracy: 0.7932 - val_loss: 0.4579 - val_accuracy: 0.7698
# Epoch 42/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.4157 - accuracy: 0.7945
# Epoch 42: val_loss did not improve from 0.44239
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4157 - accuracy: 0.7945 - val_loss: 0.4594 - val_accuracy: 0.7709
# Epoch 43/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4108 - accuracy: 0.7973
# Epoch 43: val_loss improved from 0.44239 to 0.43744, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4108 - accuracy: 0.7973 - val_loss: 0.4374 - val_accuracy: 0.7822
# Epoch 44/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4103 - accuracy: 0.7976
# Epoch 44: val_loss improved from 0.43744 to 0.43348, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4103 - accuracy: 0.7976 - val_loss: 0.4335 - val_accuracy: 0.7856
# Epoch 45/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4064 - accuracy: 0.8005
# Epoch 45: val_loss did not improve from 0.43348
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4064 - accuracy: 0.8005 - val_loss: 0.4442 - val_accuracy: 0.7780
# Epoch 46/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4036 - accuracy: 0.8020
# Epoch 46: val_loss did not improve from 0.43348
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4036 - accuracy: 0.8020 - val_loss: 0.4356 - val_accuracy: 0.7856
# Epoch 47/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4000 - accuracy: 0.8043
# Epoch 47: val_loss improved from 0.43348 to 0.43277, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4000 - accuracy: 0.8043 - val_loss: 0.4328 - val_accuracy: 0.7852
# Epoch 48/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3996 - accuracy: 0.8041
# Epoch 48: val_loss improved from 0.43277 to 0.43194, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.3996 - accuracy: 0.8041 - val_loss: 0.4319 - val_accuracy: 0.7862
# Epoch 49/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.8066
# Epoch 49: val_loss improved from 0.43194 to 0.43046, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.3957 - accuracy: 0.8066 - val_loss: 0.4305 - val_accuracy: 0.7852
# Epoch 50/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3935 - accuracy: 0.8076
# Epoch 50: val_loss did not improve from 0.43046
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3935 - accuracy: 0.8076 - val_loss: 0.4370 - val_accuracy: 0.7826
# Epoch 51/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3917 - accuracy: 0.8093
# Epoch 51: val_loss improved from 0.43046 to 0.42689, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.3917 - accuracy: 0.8093 - val_loss: 0.4269 - val_accuracy: 0.7890
# Epoch 52/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3891 - accuracy: 0.8105
# Epoch 52: val_loss did not improve from 0.42689
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3891 - accuracy: 0.8105 - val_loss: 0.4276 - val_accuracy: 0.7902
# Epoch 53/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3849 - accuracy: 0.8139
# Epoch 53: val_loss did not improve from 0.42689
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3849 - accuracy: 0.8139 - val_loss: 0.4396 - val_accuracy: 0.7841
# Epoch 54/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3837 - accuracy: 0.8143
# Epoch 54: val_loss did not improve from 0.42689
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3837 - accuracy: 0.8143 - val_loss: 0.4293 - val_accuracy: 0.7874
# Epoch 55/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3830 - accuracy: 0.8150
# Epoch 55: val_loss improved from 0.42689 to 0.42392, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.3830 - accuracy: 0.8150 - val_loss: 0.4239 - val_accuracy: 0.7927
# Epoch 56/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3780 - accuracy: 0.8176
# Epoch 56: val_loss did not improve from 0.42392
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3780 - accuracy: 0.8176 - val_loss: 0.4254 - val_accuracy: 0.7881
# Epoch 57/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.3761 - accuracy: 0.8184
# Epoch 57: val_loss improved from 0.42392 to 0.42263, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.3762 - accuracy: 0.8184 - val_loss: 0.4226 - val_accuracy: 0.7959
# Epoch 58/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3754 - accuracy: 0.8191
# Epoch 58: val_loss improved from 0.42263 to 0.42233, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.3754 - accuracy: 0.8191 - val_loss: 0.4223 - val_accuracy: 0.7950
# Epoch 59/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3741 - accuracy: 0.8194
# Epoch 59: val_loss improved from 0.42233 to 0.42119, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.3741 - accuracy: 0.8194 - val_loss: 0.4212 - val_accuracy: 0.7950
# Epoch 60/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3701 - accuracy: 0.8226
# Epoch 60: val_loss improved from 0.42119 to 0.41102, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.3701 - accuracy: 0.8226 - val_loss: 0.4110 - val_accuracy: 0.8015
# Epoch 61/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3687 - accuracy: 0.8237
# Epoch 61: val_loss did not improve from 0.41102
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3687 - accuracy: 0.8237 - val_loss: 0.4174 - val_accuracy: 0.7982
# Epoch 62/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3655 - accuracy: 0.8250
# Epoch 62: val_loss improved from 0.41102 to 0.40288, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3655 - accuracy: 0.8250 - val_loss: 0.4029 - val_accuracy: 0.8051
# Epoch 63/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.3656 - accuracy: 0.8255
# Epoch 63: val_loss did not improve from 0.40288
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3656 - accuracy: 0.8255 - val_loss: 0.4130 - val_accuracy: 0.8000
# Epoch 64/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3622 - accuracy: 0.8271
# Epoch 64: val_loss did not improve from 0.40288
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3622 - accuracy: 0.8271 - val_loss: 0.4105 - val_accuracy: 0.8009
# Epoch 65/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.3598 - accuracy: 0.8284
# Epoch 65: val_loss did not improve from 0.40288
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3598 - accuracy: 0.8284 - val_loss: 0.4058 - val_accuracy: 0.8033
# Epoch 66/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.3564 - accuracy: 0.8302
# Epoch 66: val_loss improved from 0.40288 to 0.40090, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3563 - accuracy: 0.8302 - val_loss: 0.4009 - val_accuracy: 0.8085
# Epoch 67/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3581 - accuracy: 0.8298
# Epoch 67: val_loss improved from 0.40090 to 0.39600, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.3581 - accuracy: 0.8298 - val_loss: 0.3960 - val_accuracy: 0.8081
# Epoch 68/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3545 - accuracy: 0.8313
# Epoch 68: val_loss did not improve from 0.39600
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3545 - accuracy: 0.8313 - val_loss: 0.4022 - val_accuracy: 0.8047
# Epoch 69/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3518 - accuracy: 0.8334
# Epoch 69: val_loss did not improve from 0.39600
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3518 - accuracy: 0.8334 - val_loss: 0.4054 - val_accuracy: 0.8050
# Epoch 70/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3500 - accuracy: 0.8343
# Epoch 70: val_loss did not improve from 0.39600
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3500 - accuracy: 0.8343 - val_loss: 0.4230 - val_accuracy: 0.7971
# Epoch 71/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8348
# Epoch 71: val_loss did not improve from 0.39600
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3499 - accuracy: 0.8348 - val_loss: 0.4036 - val_accuracy: 0.8054
# Epoch 72/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.8364
# Epoch 72: val_loss did not improve from 0.39600
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3451 - accuracy: 0.8364 - val_loss: 0.4209 - val_accuracy: 0.8006
# Epoch 73/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.8363
# Epoch 73: val_loss did not improve from 0.39600
# 546/546 [==============================] - 35s 63ms/step - loss: 0.3464 - accuracy: 0.8363 - val_loss: 0.4087 - val_accuracy: 0.8017
# Epoch 74/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3411 - accuracy: 0.8391
# Epoch 74: val_loss improved from 0.39600 to 0.39090, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 65ms/step - loss: 0.3411 - accuracy: 0.8391 - val_loss: 0.3909 - val_accuracy: 0.8144
# Epoch 75/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3432 - accuracy: 0.8378
# Epoch 75: val_loss improved from 0.39090 to 0.38554, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3432 - accuracy: 0.8378 - val_loss: 0.3855 - val_accuracy: 0.8176
# Epoch 76/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3374 - accuracy: 0.8414
# Epoch 76: val_loss did not improve from 0.38554
# 546/546 [==============================] - 35s 63ms/step - loss: 0.3374 - accuracy: 0.8414 - val_loss: 0.3959 - val_accuracy: 0.8138
# Epoch 77/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3377 - accuracy: 0.8408
# Epoch 77: val_loss did not improve from 0.38554
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3377 - accuracy: 0.8408 - val_loss: 0.4078 - val_accuracy: 0.8040
# Epoch 78/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3368 - accuracy: 0.8419
# Epoch 78: val_loss did not improve from 0.38554
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3368 - accuracy: 0.8419 - val_loss: 0.4125 - val_accuracy: 0.8071
# Epoch 79/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3355 - accuracy: 0.8424
# Epoch 79: val_loss did not improve from 0.38554
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3355 - accuracy: 0.8424 - val_loss: 0.4001 - val_accuracy: 0.8093
# Epoch 80/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3336 - accuracy: 0.8433
# Epoch 80: val_loss improved from 0.38554 to 0.38483, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 65ms/step - loss: 0.3336 - accuracy: 0.8433 - val_loss: 0.3848 - val_accuracy: 0.8167
# Epoch 81/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3310 - accuracy: 0.8449
# Epoch 81: val_loss did not improve from 0.38483
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3310 - accuracy: 0.8449 - val_loss: 0.3904 - val_accuracy: 0.8150
# Epoch 82/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3289 - accuracy: 0.8458
# Epoch 82: val_loss did not improve from 0.38483
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3289 - accuracy: 0.8458 - val_loss: 0.3970 - val_accuracy: 0.8100
# Epoch 83/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.8475
# Epoch 83: val_loss did not improve from 0.38483
# 546/546 [==============================] - 35s 63ms/step - loss: 0.3266 - accuracy: 0.8475 - val_loss: 0.4125 - val_accuracy: 0.8094
# Epoch 84/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3278 - accuracy: 0.8465
# Epoch 84: val_loss did not improve from 0.38483
# 546/546 [==============================] - 35s 63ms/step - loss: 0.3278 - accuracy: 0.8465 - val_loss: 0.3876 - val_accuracy: 0.8178
# Epoch 85/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.8482
# Epoch 85: val_loss improved from 0.38483 to 0.38456, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3247 - accuracy: 0.8482 - val_loss: 0.3846 - val_accuracy: 0.8208
# Epoch 86/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3210 - accuracy: 0.8504
# Epoch 86: val_loss did not improve from 0.38456
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3210 - accuracy: 0.8504 - val_loss: 0.4080 - val_accuracy: 0.8104
# Epoch 87/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3238 - accuracy: 0.8488
# Epoch 87: val_loss improved from 0.38456 to 0.38281, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3238 - accuracy: 0.8488 - val_loss: 0.3828 - val_accuracy: 0.8210
# Epoch 88/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.8525
# Epoch 88: val_loss improved from 0.38281 to 0.38276, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 65ms/step - loss: 0.3176 - accuracy: 0.8525 - val_loss: 0.3828 - val_accuracy: 0.8208
# Epoch 89/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.8520
# Epoch 89: val_loss did not improve from 0.38276
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3178 - accuracy: 0.8520 - val_loss: 0.3920 - val_accuracy: 0.8165
# Epoch 90/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3190 - accuracy: 0.8513
# Epoch 90: val_loss did not improve from 0.38276
# 546/546 [==============================] - 35s 63ms/step - loss: 0.3190 - accuracy: 0.8513 - val_loss: 0.3895 - val_accuracy: 0.8178
# Epoch 91/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.8536
# Epoch 91: val_loss did not improve from 0.38276
# 546/546 [==============================] - 35s 63ms/step - loss: 0.3152 - accuracy: 0.8536 - val_loss: 0.3849 - val_accuracy: 0.8209
# Epoch 92/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3127 - accuracy: 0.8553
# Epoch 92: val_loss did not improve from 0.38276
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3127 - accuracy: 0.8553 - val_loss: 0.3974 - val_accuracy: 0.8116
# Epoch 93/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3116 - accuracy: 0.8560
# Epoch 93: val_loss improved from 0.38276 to 0.37937, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3116 - accuracy: 0.8560 - val_loss: 0.3794 - val_accuracy: 0.8204
# Epoch 94/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3096 - accuracy: 0.8567
# Epoch 94: val_loss did not improve from 0.37937
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3096 - accuracy: 0.8567 - val_loss: 0.3803 - val_accuracy: 0.8216
# Epoch 95/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3129 - accuracy: 0.8555
# Epoch 95: val_loss improved from 0.37937 to 0.37669, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3129 - accuracy: 0.8555 - val_loss: 0.3767 - val_accuracy: 0.8248
# Epoch 96/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3070 - accuracy: 0.8584
# Epoch 96: val_loss improved from 0.37669 to 0.37511, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3070 - accuracy: 0.8584 - val_loss: 0.3751 - val_accuracy: 0.8243
# Epoch 97/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3093 - accuracy: 0.8568
# Epoch 97: val_loss did not improve from 0.37511
# 546/546 [==============================] - 35s 63ms/step - loss: 0.3093 - accuracy: 0.8568 - val_loss: 0.3835 - val_accuracy: 0.8213
# Epoch 98/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.8593
# Epoch 98: val_loss improved from 0.37511 to 0.36830, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.3052 - accuracy: 0.8593 - val_loss: 0.3683 - val_accuracy: 0.8288
# Epoch 99/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3039 - accuracy: 0.8597
# Epoch 99: val_loss did not improve from 0.36830
# 546/546 [==============================] - 35s 63ms/step - loss: 0.3039 - accuracy: 0.8597 - val_loss: 0.4219 - val_accuracy: 0.8088
# Epoch 100/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3050 - accuracy: 0.8591
# Epoch 100: val_loss did not improve from 0.36830
# 546/546 [==============================] - 34s 63ms/step - loss: 0.3050 - accuracy: 0.8591 - val_loss: 0.3753 - val_accuracy: 0.8241
# Epoch 101/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2989 - accuracy: 0.8627
# Epoch 101: val_loss did not improve from 0.36830
# 546/546 [==============================] - 35s 64ms/step - loss: 0.2989 - accuracy: 0.8627 - val_loss: 0.3792 - val_accuracy: 0.8257
# Epoch 102/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.8622
# Epoch 102: val_loss improved from 0.36830 to 0.36175, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.3003 - accuracy: 0.8622 - val_loss: 0.3618 - val_accuracy: 0.8316
# Epoch 103/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.8628
# Epoch 103: val_loss did not improve from 0.36175
# 546/546 [==============================] - 35s 64ms/step - loss: 0.2988 - accuracy: 0.8628 - val_loss: 0.3687 - val_accuracy: 0.8283
# Epoch 104/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2966 - accuracy: 0.8640
# Epoch 104: val_loss did not improve from 0.36175
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2966 - accuracy: 0.8640 - val_loss: 0.3645 - val_accuracy: 0.8305
# Epoch 105/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8628
# Epoch 105: val_loss did not improve from 0.36175
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2985 - accuracy: 0.8628 - val_loss: 0.3739 - val_accuracy: 0.8288
# Epoch 106/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2930 - accuracy: 0.8662
# Epoch 106: val_loss did not improve from 0.36175
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2930 - accuracy: 0.8662 - val_loss: 0.3755 - val_accuracy: 0.8269
# Epoch 107/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2911 - accuracy: 0.8668
# Epoch 107: val_loss did not improve from 0.36175
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2911 - accuracy: 0.8668 - val_loss: 0.3743 - val_accuracy: 0.8298
# Epoch 108/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2925 - accuracy: 0.8661
# Epoch 108: val_loss improved from 0.36175 to 0.36108, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.2925 - accuracy: 0.8661 - val_loss: 0.3611 - val_accuracy: 0.8332
# Epoch 109/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.8675
# Epoch 109: val_loss did not improve from 0.36108
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2898 - accuracy: 0.8675 - val_loss: 0.3778 - val_accuracy: 0.8204
# Epoch 110/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2917 - accuracy: 0.8667
# Epoch 110: val_loss did not improve from 0.36108
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2917 - accuracy: 0.8667 - val_loss: 0.3778 - val_accuracy: 0.8267
# Epoch 111/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.8679
# Epoch 111: val_loss improved from 0.36108 to 0.36098, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.2896 - accuracy: 0.8679 - val_loss: 0.3610 - val_accuracy: 0.8351
# Epoch 112/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2863 - accuracy: 0.8691
# Epoch 112: val_loss did not improve from 0.36098
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2863 - accuracy: 0.8691 - val_loss: 0.3687 - val_accuracy: 0.8325
# Epoch 113/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2864 - accuracy: 0.8696
# Epoch 113: val_loss did not improve from 0.36098
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2864 - accuracy: 0.8696 - val_loss: 0.3661 - val_accuracy: 0.8338
# Epoch 114/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.8690
# Epoch 114: val_loss did not improve from 0.36098
# 546/546 [==============================] - 35s 63ms/step - loss: 0.2889 - accuracy: 0.8690 - val_loss: 0.3613 - val_accuracy: 0.8315
# Epoch 115/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2833 - accuracy: 0.8711
# Epoch 115: val_loss improved from 0.36098 to 0.35509, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.2833 - accuracy: 0.8711 - val_loss: 0.3551 - val_accuracy: 0.8391
# Epoch 116/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.8707
# Epoch 116: val_loss did not improve from 0.35509
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2842 - accuracy: 0.8707 - val_loss: 0.3774 - val_accuracy: 0.8215
# Epoch 117/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2805 - accuracy: 0.8727
# Epoch 117: val_loss did not improve from 0.35509
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2805 - accuracy: 0.8727 - val_loss: 0.3729 - val_accuracy: 0.8267
# Epoch 118/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.8738
# Epoch 118: val_loss did not improve from 0.35509
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2781 - accuracy: 0.8738 - val_loss: 0.3798 - val_accuracy: 0.8309
# Epoch 119/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.8739
# Epoch 119: val_loss did not improve from 0.35509
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2782 - accuracy: 0.8739 - val_loss: 0.3698 - val_accuracy: 0.8267
# Epoch 120/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.8736
# Epoch 120: val_loss improved from 0.35509 to 0.35341, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.2792 - accuracy: 0.8736 - val_loss: 0.3534 - val_accuracy: 0.8387
# Epoch 121/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2784 - accuracy: 0.8738
# Epoch 121: val_loss did not improve from 0.35341
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2784 - accuracy: 0.8738 - val_loss: 0.3695 - val_accuracy: 0.8360
# Epoch 122/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2740 - accuracy: 0.8767
# Epoch 122: val_loss did not improve from 0.35341
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2740 - accuracy: 0.8767 - val_loss: 0.3677 - val_accuracy: 0.8336
# Epoch 123/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.8761
# Epoch 123: val_loss did not improve from 0.35341
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2745 - accuracy: 0.8761 - val_loss: 0.3699 - val_accuracy: 0.8332
# Epoch 124/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2771 - accuracy: 0.8749
# Epoch 124: val_loss improved from 0.35341 to 0.35093, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2771 - accuracy: 0.8749 - val_loss: 0.3509 - val_accuracy: 0.8410
# Epoch 125/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.8788
# Epoch 125: val_loss did not improve from 0.35093
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2701 - accuracy: 0.8788 - val_loss: 0.3578 - val_accuracy: 0.8356
# Epoch 126/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.8782
# Epoch 126: val_loss improved from 0.35093 to 0.34802, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.2701 - accuracy: 0.8782 - val_loss: 0.3480 - val_accuracy: 0.8433
# Epoch 127/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2702 - accuracy: 0.8782
# Epoch 127: val_loss did not improve from 0.34802
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2702 - accuracy: 0.8782 - val_loss: 0.3521 - val_accuracy: 0.8422
# Epoch 128/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2690 - accuracy: 0.8788
# Epoch 128: val_loss did not improve from 0.34802
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2690 - accuracy: 0.8788 - val_loss: 0.3739 - val_accuracy: 0.8275
# Epoch 129/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2695 - accuracy: 0.8783
# Epoch 129: val_loss improved from 0.34802 to 0.34633, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.2695 - accuracy: 0.8783 - val_loss: 0.3463 - val_accuracy: 0.8445
# Epoch 130/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2671 - accuracy: 0.8796
# Epoch 130: val_loss did not improve from 0.34633
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2671 - accuracy: 0.8796 - val_loss: 0.3590 - val_accuracy: 0.8377
# Epoch 131/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2683 - accuracy: 0.8791
# Epoch 131: val_loss did not improve from 0.34633
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2683 - accuracy: 0.8791 - val_loss: 0.3618 - val_accuracy: 0.8369
# Epoch 132/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2636 - accuracy: 0.8813
# Epoch 132: val_loss did not improve from 0.34633
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2636 - accuracy: 0.8813 - val_loss: 0.3510 - val_accuracy: 0.8432
# Epoch 133/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.8819
# Epoch 133: val_loss did not improve from 0.34633
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2632 - accuracy: 0.8819 - val_loss: 0.3575 - val_accuracy: 0.8406
# Epoch 134/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2624 - accuracy: 0.8818
# Epoch 134: val_loss improved from 0.34633 to 0.34531, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.2624 - accuracy: 0.8818 - val_loss: 0.3453 - val_accuracy: 0.8458
# Epoch 135/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2595 - accuracy: 0.8837
# Epoch 135: val_loss did not improve from 0.34531
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2595 - accuracy: 0.8837 - val_loss: 0.3580 - val_accuracy: 0.8394
# Epoch 136/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.8824
# Epoch 136: val_loss did not improve from 0.34531
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2627 - accuracy: 0.8824 - val_loss: 0.3536 - val_accuracy: 0.8426
# Epoch 137/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.8838
# Epoch 137: val_loss did not improve from 0.34531
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2594 - accuracy: 0.8838 - val_loss: 0.3642 - val_accuracy: 0.8385
# Epoch 138/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.8843
# Epoch 138: val_loss improved from 0.34531 to 0.34341, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2588 - accuracy: 0.8843 - val_loss: 0.3434 - val_accuracy: 0.8458
# Epoch 139/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.8845
# Epoch 139: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2588 - accuracy: 0.8845 - val_loss: 0.3487 - val_accuracy: 0.8414
# Epoch 140/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2591 - accuracy: 0.8843
# Epoch 140: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2591 - accuracy: 0.8843 - val_loss: 0.3462 - val_accuracy: 0.8461
# Epoch 141/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2548 - accuracy: 0.8865
# Epoch 141: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2548 - accuracy: 0.8865 - val_loss: 0.3540 - val_accuracy: 0.8397
# Epoch 142/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.8871
# Epoch 142: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2531 - accuracy: 0.8871 - val_loss: 0.3609 - val_accuracy: 0.8419
# Epoch 143/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.2512 - accuracy: 0.8882
# Epoch 143: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2512 - accuracy: 0.8882 - val_loss: 0.3532 - val_accuracy: 0.8399
# Epoch 144/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2537 - accuracy: 0.8865
# Epoch 144: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2537 - accuracy: 0.8865 - val_loss: 0.3570 - val_accuracy: 0.8450
# Epoch 145/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.8878
# Epoch 145: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2525 - accuracy: 0.8878 - val_loss: 0.3517 - val_accuracy: 0.8423
# Epoch 146/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2510 - accuracy: 0.8881
# Epoch 146: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2510 - accuracy: 0.8881 - val_loss: 0.3507 - val_accuracy: 0.8454
# Epoch 147/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2506 - accuracy: 0.8885
# Epoch 147: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2506 - accuracy: 0.8885 - val_loss: 0.3527 - val_accuracy: 0.8436
# Epoch 148/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 0.8896
# Epoch 148: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2485 - accuracy: 0.8896 - val_loss: 0.3440 - val_accuracy: 0.8459
# Epoch 149/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2483 - accuracy: 0.8887
# Epoch 149: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2483 - accuracy: 0.8887 - val_loss: 0.3536 - val_accuracy: 0.8433
# Epoch 150/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2456 - accuracy: 0.8905
# Epoch 150: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2456 - accuracy: 0.8905 - val_loss: 0.3464 - val_accuracy: 0.8467
# Epoch 151/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.8919
# Epoch 151: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2444 - accuracy: 0.8919 - val_loss: 0.3732 - val_accuracy: 0.8360
# Epoch 152/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2472 - accuracy: 0.8903
# Epoch 152: val_loss did not improve from 0.34341
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2472 - accuracy: 0.8903 - val_loss: 0.3577 - val_accuracy: 0.8446
# Epoch 153/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2425 - accuracy: 0.8927
# Epoch 153: val_loss improved from 0.34341 to 0.34199, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.2425 - accuracy: 0.8927 - val_loss: 0.3420 - val_accuracy: 0.8491
# Epoch 154/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.8913
# Epoch 154: val_loss did not improve from 0.34199
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2445 - accuracy: 0.8913 - val_loss: 0.3593 - val_accuracy: 0.8428
# Epoch 155/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2453 - accuracy: 0.8909
# Epoch 155: val_loss improved from 0.34199 to 0.34103, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2453 - accuracy: 0.8909 - val_loss: 0.3410 - val_accuracy: 0.8528
# Epoch 156/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.8945
# Epoch 156: val_loss improved from 0.34103 to 0.33136, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.2384 - accuracy: 0.8945 - val_loss: 0.3314 - val_accuracy: 0.8548
# Epoch 157/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.8947
# Epoch 157: val_loss did not improve from 0.33136
# ...
# Epoch 164/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2338 - accuracy: 0.8970 - val_loss: 0.3523 - val_accuracy: 0.8478
# Epoch 165/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2323 - accuracy: 0.8975 - val_loss: 0.3449 - val_accuracy: 0.8492
# Epoch 166/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2333 - accuracy: 0.8965 - val_loss: 0.3529 - val_accuracy: 0.8487
# Epoch 167/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2329 - accuracy: 0.8968 - val_loss: 0.3392 - val_accuracy: 0.8548
# Epoch 168/500
# 546/546 [==============================] - 2s 4ms/step - loss: 0.2331 - accuracy: 0.8967 - val_loss: 0.3486 - val_accuracy: 0.8469
# Epoch 169/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2338 - accuracy: 0.8969 - val_loss: 0.3380 - val_accuracy: 0.8525
# Epoch 170/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2277 - accuracy: 0.8999 - val_loss: 0.3385 - val_accuracy: 0.8544
# Epoch 171/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2294 - accuracy: 0.8992 - val_loss: 0.3498 - val_accuracy: 0.8500
# Epoch 172/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2320 - accuracy: 0.8974 - val_loss: 0.3431 - val_accuracy: 0.8541
# Epoch 173/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2299 - accuracy: 0.8986 - val_loss: 0.3470 - val_accuracy: 0.8517
# Epoch 174/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2261 - accuracy: 0.9005 - val_loss: 0.3436 - val_accuracy: 0.8545
# Epoch 175/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2243 - accuracy: 0.9015 - val_loss: 0.3429 - val_accuracy: 0.8559
# Epoch 176/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2274 - accuracy: 0.9000 - val_loss: 0.3438 - val_accuracy: 0.8523
# Epoch 177/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2250 - accuracy: 0.9012 - val_loss: 0.3489 - val_accuracy: 0.8524
# Epoch 178/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2264 - accuracy: 0.9010 - val_loss: 0.3247 - val_accuracy: 0.8600
# Epoch 179/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2227 - accuracy: 0.9023 - val_loss: 0.3299 - val_accuracy: 0.8587
# Epoch 180/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2228 - accuracy: 0.9023 - val_loss: 0.3341 - val_accuracy: 0.8560
# Epoch 181/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2216 - accuracy: 0.9034 - val_loss: 0.3569 - val_accuracy: 0.8495
# Epoch 182/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2267 - accuracy: 0.9003 - val_loss: 0.3481 - val_accuracy: 0.8520
# Epoch 183/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2150 - accuracy: 0.9059 - val_loss: 0.3411 - val_accuracy: 0.8532
# Epoch 184/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2170 - accuracy: 0.9058 - val_loss: 0.3354 - val_accuracy: 0.8567
# Epoch 185/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2204 - accuracy: 0.9033 - val_loss: 0.3583 - val_accuracy: 0.8495
# Epoch 186/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2169 - accuracy: 0.9050 - val_loss: 0.3391 - val_accuracy: 0.8576
# Epoch 187/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2179 - accuracy: 0.9045 - val_loss: 0.3454 - val_accuracy: 0.8541
# Epoch 188/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2167 - accuracy: 0.9055 - val_loss: 0.3566 - val_accuracy: 0.8504
# Epoch 189/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2145 - accuracy: 0.9066 - val_loss: 0.3299 - val_accuracy: 0.8591
# Epoch 190/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2161 - accuracy: 0.9058 - val_loss: 0.3644 - val_accuracy: 0.8465
# Epoch 191/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2174 - accuracy: 0.9052 - val_loss: 0.3444 - val_accuracy: 0.8561
# Epoch 192/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2141 - accuracy: 0.9074 - val_loss: 0.3429 - val_accuracy: 0.8564
# Epoch 193/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2154 - accuracy: 0.9063 - val_loss: 0.4258 - val_accuracy: 0.8288
# Epoch 194/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2121 - accuracy: 0.9081 - val_loss: 0.3417 - val_accuracy: 0.8588
# Epoch 195/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2104 - accuracy: 0.9083 - val_loss: 0.3510 - val_accuracy: 0.8502
# Epoch 196/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2098 - accuracy: 0.9087 - val_loss: 0.3458 - val_accuracy: 0.8537
# Epoch 197/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2115 - accuracy: 0.9084 - val_loss: 0.3613 - val_accuracy: 0.8542
# Epoch 198/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2105 - accuracy: 0.9084 - val_loss: 0.3449 - val_accuracy: 0.8540
# Epoch 199/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.3484 - val_accuracy: 0.8523
# Epoch 200/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2091 - accuracy: 0.9091 - val_loss: 0.3327 - val_accuracy: 0.8607
# Epoch 201/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2097 - accuracy: 0.9091 - val_loss: 0.3247 - val_accuracy: 0.8642
# Epoch 202/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2064 - accuracy: 0.9105 - val_loss: 0.3462 - val_accuracy: 0.8546
# Epoch 203/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2042 - accuracy: 0.9115 - val_loss: 0.3460 - val_accuracy: 0.8576
# Epoch 204/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2058 - accuracy: 0.9106 - val_loss: 0.3629 - val_accuracy: 0.8533
# Epoch 205/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2039 - accuracy: 0.9117 - val_loss: 0.3302 - val_accuracy: 0.8626
# Epoch 206/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2030 - accuracy: 0.9122 - val_loss: 0.3508 - val_accuracy: 0.8573
# Epoch 207/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2072 - accuracy: 0.9105 - val_loss: 0.3381 - val_accuracy: 0.8586
# Epoch 208/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2011 - accuracy: 0.9132 - val_loss: 0.3285 - val_accuracy: 0.8644
# Epoch 209/500
# 546/546 [==============================] - 2s 5ms/step - loss: 0.1990 - accuracy: 0.9140 - val_loss: 0.3392 - val_accuracy: 0.8584
# Epoch 210/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2018 - accuracy: 0.9128 - val_loss: 0.3411 - val_accuracy: 0.8610
# Epoch 211/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2014 - accuracy: 0.9135 - val_loss: 0.3310 - val_accuracy: 0.8619
# Epoch 212/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2015 - accuracy: 0.9133 - val_loss: 0.3612 - val_accuracy: 0.8469
# Epoch 213/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1966 - accuracy: 0.9153 - val_loss: 0.3378 - val_accuracy: 0.8650
# Epoch 214/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2009 - accuracy: 0.9131 - val_loss: 0.3392 - val_accuracy: 0.8652
# Epoch 215/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1976 - accuracy: 0.9146 - val_loss: 0.3993 - val_accuracy: 0.8365
# Epoch 216/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1954 - accuracy: 0.9159 - val_loss: 0.3228 - val_accuracy: 0.8677
# Epoch 217/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1963 - accuracy: 0.9153 - val_loss: 0.3737 - val_accuracy: 0.8525
# Epoch 218/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1982 - accuracy: 0.9146 - val_loss: 0.3523 - val_accuracy: 0.8586
# Epoch 219/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1935 - accuracy: 0.9168 - val_loss: 0.3493 - val_accuracy: 0.8598
# Epoch 220/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1946 - accuracy: 0.9165 - val_loss: 0.3330 - val_accuracy: 0.8645
# Epoch 221/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1942 - accuracy: 0.9164 - val_loss: 0.3452 - val_accuracy: 0.8630
# Epoch 222/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1922 - accuracy: 0.9177 - val_loss: 0.3623 - val_accuracy: 0.8537
# Epoch 223/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1918 - accuracy: 0.9178 - val_loss: 0.3378 - val_accuracy: 0.8625
# Epoch 224/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1955 - accuracy: 0.9159 - val_loss: 0.3390 - val_accuracy: 0.8600
# Epoch 225/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1918 - accuracy: 0.9182 - val_loss: 0.3366 - val_accuracy: 0.8639
# Epoch 226/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1905 - accuracy: 0.9186 - val_loss: 0.3275 - val_accuracy: 0.8659
# Epoch 227/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1864 - accuracy: 0.9200 - val_loss: 0.3305 - val_accuracy: 0.8679
# Epoch 228/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1934 - accuracy: 0.9172 - val_loss: 0.3532 - val_accuracy: 0.8596
# Epoch 229/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1867 - accuracy: 0.9202 - val_loss: 0.3328 - val_accuracy: 0.8678
# Epoch 230/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1886 - accuracy: 0.9196 - val_loss: 0.3467 - val_accuracy: 0.8617
# Epoch 231/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1894 - accuracy: 0.9189 - val_loss: 0.3211 - val_accuracy: 0.8689
# Epoch 232/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1872 - accuracy: 0.9202 - val_loss: 0.3354 - val_accuracy: 0.8650
# Epoch 233/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1871 - accuracy: 0.9203 - val_loss: 0.3182 - val_accuracy: 0.8708
# Epoch 234/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1841 - accuracy: 0.9218 - val_loss: 0.3282 - val_accuracy: 0.8709
# Epoch 235/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1872 - accuracy: 0.9198 - val_loss: 0.3261 - val_accuracy: 0.8672
# Epoch 236/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1854 - accuracy: 0.9209 - val_loss: 0.3394 - val_accuracy: 0.8625
# Epoch 237/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1860 - accuracy: 0.9204 - val_loss: 0.3268 - val_accuracy: 0.8672
# Epoch 238/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1830 - accuracy: 0.9219 - val_loss: 0.3293 - val_accuracy: 0.8678
# Epoch 239/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1833 - accuracy: 0.9218 - val_loss: 0.3397 - val_accuracy: 0.8660
# Epoch 240/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1853 - accuracy: 0.9209 - val_loss: 0.3232 - val_accuracy: 0.8697
# Epoch 241/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1783 - accuracy: 0.9243 - val_loss: 0.3255 - val_accuracy: 0.8699
# Epoch 242/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1819 - accuracy: 0.9229 - val_loss: 0.3451 - val_accuracy: 0.8632
# Epoch 243/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1842 - accuracy: 0.9217 - val_loss: 0.3144 - val_accuracy: 0.8731
# Epoch 244/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1773 - accuracy: 0.9245 - val_loss: 0.3858 - val_accuracy: 0.8429
# Epoch 245/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1808 - accuracy: 0.9229 - val_loss: 0.3246 - val_accuracy: 0.8723
# Epoch 246/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1785 - accuracy: 0.9238 - val_loss: 0.3262 - val_accuracy: 0.8674
# Epoch 247/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1788 - accuracy: 0.9234 - val_loss: 0.3720 - val_accuracy: 0.8535
# Epoch 248/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1759 - accuracy: 0.9249 - val_loss: 0.3378 - val_accuracy: 0.8681
# Epoch 249/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1788 - accuracy: 0.9239 - val_loss: 0.3381 - val_accuracy: 0.8682
# Epoch 250/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1795 - accuracy: 0.9239 - val_loss: 0.3342 - val_accuracy: 0.8722
# Epoch 251/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1750 - accuracy: 0.9255 - val_loss: 0.3352 - val_accuracy: 0.8665
# Epoch 252/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1749 - accuracy: 0.9260 - val_loss: 0.3190 - val_accuracy: 0.8745
# Epoch 253/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1748 - accuracy: 0.9256 - val_loss: 0.3325 - val_accuracy: 0.8696
# Epoch 254/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1791 - accuracy: 0.9238 - val_loss: 0.3406 - val_accuracy: 0.8687
# Epoch 255/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1718 - accuracy: 0.9271 - val_loss: 0.3298 - val_accuracy: 0.8721
# Epoch 256/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1756 - accuracy: 0.9252 - val_loss: 0.3222 - val_accuracy: 0.8732
# Epoch 257/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1712 - accuracy: 0.9276 - val_loss: 0.3265 - val_accuracy: 0.8700
# Epoch 258/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1729 - accuracy: 0.9267 - val_loss: 0.3294 - val_accuracy: 0.8732
# Epoch 259/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1744 - accuracy: 0.9261 - val_loss: 0.3287 - val_accuracy: 0.8741
# Epoch 260/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1725 - accuracy: 0.9271 - val_loss: 0.3487 - val_accuracy: 0.8630
# Epoch 261/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1714 - accuracy: 0.9275 - val_loss: 0.3245 - val_accuracy: 0.8749
# Epoch 262/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1706 - accuracy: 0.9281 - val_loss: 0.3973 - val_accuracy: 0.8461
# Epoch 263/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1697 - accuracy: 0.9284 - val_loss: 0.3364 - val_accuracy: 0.8715
# Epoch 264/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1714 - accuracy: 0.9277 - val_loss: 0.3192 - val_accuracy: 0.8755
# Epoch 265/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1711 - accuracy: 0.9275 - val_loss: 0.3301 - val_accuracy: 0.8727
# Epoch 266/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1666 - accuracy: 0.9294 - val_loss: 0.3204 - val_accuracy: 0.8775
# Epoch 267/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1698 - accuracy: 0.9285 - val_loss: 0.3312 - val_accuracy: 0.8697
# Epoch 268/500
# 546/546 [==============================] - 2s 4ms/step - loss: 0.1665 - accuracy: 0.9297 - val_loss: 0.3205 - val_accuracy: 0.8756
# Epoch 269/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1638 - accuracy: 0.9309 - val_loss: 0.3713 - val_accuracy: 0.8570
# Epoch 270/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1681 - accuracy: 0.9288 - val_loss: 0.3258 - val_accuracy: 0.8737
# Epoch 271/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1647 - accuracy: 0.9305 - val_loss: 0.3240 - val_accuracy: 0.8768
# Epoch 272/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1701 - accuracy: 0.9281 - val_loss: 0.3347 - val_accuracy: 0.8694
# Epoch 273/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1639 - accuracy: 0.9308 - val_loss: 0.3219 - val_accuracy: 0.8762
# Training Time:  741.1256296634674 seconds

# %% [markdown]
# # Saving the model and training history

# %%
ann_model.save('ANN_Architecture_5_Features.h5')
np.save('ANN_history_5_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of Artificial Neural Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of Artificial Neural Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred = ann_model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 19s 4ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = ann_model.evaluate(X_test, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.87, Test loss: 0.32

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.87     77676
#            1       0.87      0.86      0.87     77614
#
#     accuracy                           0.87    155290
#    macro avg       0.87      0.87      0.87    155290
# weighted avg       0.87      0.87      0.87    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix ANN - 5 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.8685813638998003
# Precision: 0.8729107454825168
# Recall: 0.8626536449609606
# F1-score: 0.8677518857409472
# AUC-ROC: 0.8685789981846874

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
roc_data['ANN - 5'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()
