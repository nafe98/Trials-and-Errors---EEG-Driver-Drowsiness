# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 5/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 5/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 5/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 5/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - GRU</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for GRU

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (5, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
gru_model = Sequential([
    
    GRU(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1),
    GRU(256, activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 5, 512)            791040
#
#  dropout (Dropout)           (None, 5, 512)            0
#
#  gru_1 (GRU)                 (None, 256)               591360
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,382,657
# Trainable params: 1,382,657
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
gru_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Integrating Callbacks</h2>
#
# </div>

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/GRU_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = gru_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping], 
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6459 - accuracy: 0.6211
# Epoch 1: val_loss improved from inf to 0.62992, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 244s 298ms/step - loss: 0.6459 - accuracy: 0.6211 - val_loss: 0.6299 - val_accuracy: 0.6377
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6240 - accuracy: 0.6406
# Epoch 2: val_loss improved from 0.62992 to 0.61496, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.6240 - accuracy: 0.6406 - val_loss: 0.6150 - val_accuracy: 0.6488
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6107 - accuracy: 0.6506
# Epoch 3: val_loss improved from 0.61496 to 0.60487, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.6107 - accuracy: 0.6506 - val_loss: 0.6049 - val_accuracy: 0.6549
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5989 - accuracy: 0.6591
# Epoch 4: val_loss improved from 0.60487 to 0.59364, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 238s 297ms/step - loss: 0.5989 - accuracy: 0.6591 - val_loss: 0.5936 - val_accuracy: 0.6630
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5871 - accuracy: 0.6677
# Epoch 5: val_loss improved from 0.59364 to 0.58040, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.5871 - accuracy: 0.6677 - val_loss: 0.5804 - val_accuracy: 0.6710
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5744 - accuracy: 0.6772
# Epoch 6: val_loss improved from 0.58040 to 0.56634, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.5744 - accuracy: 0.6772 - val_loss: 0.5663 - val_accuracy: 0.6830
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5622 - accuracy: 0.6861
# Epoch 7: val_loss improved from 0.56634 to 0.55394, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 238s 297ms/step - loss: 0.5622 - accuracy: 0.6861 - val_loss: 0.5539 - val_accuracy: 0.6929
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5503 - accuracy: 0.6948
# Epoch 8: val_loss improved from 0.55394 to 0.54206, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.5503 - accuracy: 0.6948 - val_loss: 0.5421 - val_accuracy: 0.7007
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5385 - accuracy: 0.7036
# Epoch 9: val_loss improved from 0.54206 to 0.53148, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.5385 - accuracy: 0.7036 - val_loss: 0.5315 - val_accuracy: 0.7094
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5291 - accuracy: 0.7103
# Epoch 10: val_loss improved from 0.53148 to 0.52252, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.5291 - accuracy: 0.7103 - val_loss: 0.5225 - val_accuracy: 0.7162
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5184 - accuracy: 0.7180
# Epoch 11: val_loss improved from 0.52252 to 0.51579, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] -
saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.3800 - accuracy: 0.8115 - val_loss: 0.3912 - val_accuracy: 0.8057
# Epoch 35/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3761 - accuracy: 0.8127
# Epoch 35: val_loss improved from 0.39124 to 0.38861, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.3761 - accuracy: 0.8127 - val_loss: 0.3886 - val_accuracy: 0.8080
# Epoch 36/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3722 - accuracy: 0.8150
# Epoch 36: val_loss did not improve from 0.38861
# 799/799 [==============================] - 237s 296ms/step - loss: 0.3722 - accuracy: 0.8150 - val_loss: 0.3893 - val_accuracy: 0.8074
# Epoch 37/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3687 - accuracy: 0.8177
# Epoch 37: val_loss improved from 0.38861 to 0.38432, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.3687 - accuracy: 0.8177 - val_loss: 0.3843 - val_accuracy: 0.8109
# Epoch 38/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3659 - accuracy: 0.8198
# Epoch 38: val_loss did not improve from 0.38432
# 799/799 [==============================] - 237s 297ms/step - loss: 0.3659 - accuracy: 0.8198 - val_loss: 0.3855 - val_accuracy: 0.8117
# Epoch 39/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3612 - accuracy: 0.8227
# Epoch 39: val_loss improved from 0.38432 to 0.38027, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.3612 - accuracy: 0.8227 - val_loss: 0.3803 - val_accuracy: 0.8141
# Epoch 40/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3599 - accuracy: 0.8235
# Epoch 40: val_loss did not improve from 0.38027
# 799/799 [==============================] - 237s 297ms/step - loss: 0.3599 - accuracy: 0.8235 - val_loss: 0.3805 - val_accuracy: 0.8143
# Epoch 41/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.8263
# Epoch 41: val_loss improved from 0.38027 to 0.37454, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 296ms/step - loss: 0.3547 - accuracy: 0.8263 - val_loss: 0.3745 - val_accuracy: 0.8176
# Epoch 42/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3520 - accuracy: 0.8277
# Epoch 42: val_loss did not improve from 0.37454
# 799/799 [==============================] - 237s 296ms/step - loss: 0.3520 - accuracy: 0.8277 - val_loss: 0.3773 - val_accuracy: 0.8170
# Epoch 43/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8292
# Epoch 43: val_loss improved from 0.37454 to 0.36937, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.3499 - accuracy: 0.8292 - val_loss: 0.3694 - val_accuracy: 0.8209
# Epoch 44/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3470 - accuracy: 0.8314
# Epoch 44: val_loss did not improve from 0.36937
# 799/799 [==============================] - 237s 296ms/step - loss: 0.3470 - accuracy: 0.8314 - val_loss: 0.3707 - val_accuracy: 0.8205
# Epoch 45/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3445 - accuracy: 0.8323
# Epoch 45: val_loss did not improve from 0.36937
# 799/799 [==============================] - 237s 296ms/step - loss: 0.3445 - accuracy: 0.8323 - val_loss: 0.3697 - val_accuracy: 0.8209
# Epoch 46/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3458 - accuracy: 0.8324
# Epoch 46: val_loss improved from 0.36937 to 0.36424, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] -
500
# 799/799 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.8750
# Epoch 82: val_loss did not improve from 0.32711
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2700 - accuracy: 0.8750 - val_loss: 0.3289 - val_accuracy: 0.8522
# Epoch 83/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.8752
# Epoch 83: val_loss improved from 0.32711 to 0.32632, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2708 - accuracy: 0.8752 - val_loss: 0.3263 - val_accuracy: 0.8542
# Epoch 84/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.8762
# Epoch 84: val_loss improved from 0.32632 to 0.32581, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2679 - accuracy: 0.8762 - val_loss: 0.3258 - val_accuracy: 0.8530
# Epoch 85/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.8769
# Epoch 85: val_loss improved from 0.32581 to 0.32386, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2668 - accuracy: 0.8769 - val_loss: 0.3239 - val_accuracy: 0.8561
# Epoch 86/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.8775
# Epoch 86: val_loss did not improve from 0.32386
# 799/799 [==============================] - 237s 296ms/step - loss: 0.2657 - accuracy: 0.8775 - val_loss: 0.3251 - val_accuracy: 0.8546
# Epoch 87/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.8782
# Epoch 87: val_loss improved from 0.32386 to 0.32346, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 296ms/step - loss: 0.2650 - accuracy: 0.8782 - val_loss: 0.3235 - val_accuracy: 0.8564
# Epoch 88/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2616 - accuracy: 0.8795
# Epoch 88: val_loss improved from 0.32346 to 0.32344, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2616 - accuracy: 0.8795 - val_loss: 0.3234 - val_accuracy: 0.8568
# Epoch 89/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2624 - accuracy: 0.8795
# Epoch 89: val_loss did not improve from 0.32344
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2624 - accuracy: 0.8795 - val_loss: 0.3252 - val_accuracy: 0.8563
# Epoch 90/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2608 - accuracy: 0.8805
# Epoch 90: val_loss improved from 0.32344 to 0.32140, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2608 - accuracy: 0.8805 - val_loss: 0.3214 - val_accuracy: 0.8577
# Epoch 91/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.8805
# Epoch 91: val_loss did not improve from 0.32140
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2607 - accuracy: 0.8805 - val_loss: 0.3240 - val_accuracy: 0.8571
# Epoch 92/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.8819
# Epoch 92: val_loss did not improve from 0.32140
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2593 - accuracy: 0.8819 - val_loss: 0.3234 - val_accuracy: 0.8575
# Epoch 93/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2571 - accuracy: 0.8827
# Epoch 93: val_loss improved from 0.32140 to 0.31955, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2571 - accuracy: 0.8827 - val_loss: 0.3196 - val_accuracy: 0.8595
# Epoch 94/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2550 - accuracy: 0.8835
# Epoch 94: val_loss improved from 0.31955 to 0.31942, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2550 - accuracy: 0.8835 - val_loss: 0.3194 - val_accuracy: 0.8595
# Epoch 95/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2537 - accuracy: 0.8841
# Epoch 95: val_loss did not improve from 0.31942
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2537 - accuracy: 0.8841 - val_loss: 0.3194 - val_accuracy: 0.8588
# Epoch 96/500
# 799/799 [==============================] - ETA: 0s - loss: 0.
500
# 799/799 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.8919
# Epoch 109: val_loss did not improve from 0.31190
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2395 - accuracy: 0.8919 - val_loss: 0.3144 - val_accuracy: 0.8648
# Epoch 110/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2401 - accuracy: 0.8918
# Epoch 110: val_loss did not improve from 0.31190
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2401 - accuracy: 0.8918 - val_loss: 0.3186 - val_accuracy: 0.8628
# Epoch 111/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2376 - accuracy: 0.8931
# Epoch 111: val_loss did not improve from 0.31190
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2376 - accuracy: 0.8931 - val_loss: 0.3121 - val_accuracy: 0.8663
# Epoch 112/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2349 - accuracy: 0.8946
# Epoch 112: val_loss did not improve from 0.31190
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2349 - accuracy: 0.8946 - val_loss: 0.3132 - val_accuracy: 0.8642
# Epoch 113/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2366 - accuracy: 0.8935
# Epoch 113: val_loss did not improve from 0.31190
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2366 - accuracy: 0.8935 - val_loss: 0.3172 - val_accuracy: 0.8635
# Epoch 114/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2339 - accuracy: 0.8947
# Epoch 114: val_loss did not improve from 0.31190
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2339 - accuracy: 0.8947 - val_loss: 0.3148 - val_accuracy: 0.8661
# Epoch 115/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.8950
# Epoch 115: val_loss did not improve from 0.31190
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2338 - accuracy: 0.8950 - val_loss: 0.3137 - val_accuracy: 0.8656
# Epoch 116/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.8961
# Epoch 116: val_loss improved from 0.31190 to 0.31140, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2316 - accuracy: 0.8961 - val_loss: 0.3114 - val_accuracy: 0.8653
# Epoch 117/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2325 - accuracy: 0.8957
# Epoch 117: val_loss improved from 0.31140 to 0.31112, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 238s 298ms/step - loss: 0.2325 - accuracy: 0.8957 - val_loss: 0.3111 - val_accuracy: 0.8674
# Epoch 118/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2332 - accuracy: 0.8955
# Epoch 118: val_loss did not improve from 0.31112
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2332 - accuracy: 0.8955 - val_loss: 0.3149 - val_accuracy: 0.8649
# Epoch 119/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2315 - accuracy: 0.8962
# Epoch 119: val_loss improved from 0.31112 to 0.30948, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 238s 298ms/step - loss: 0.2315 - accuracy: 0.8962 - val_loss: 0.3095 - val_accuracy: 0.8673
# Epoch 120/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2273 - accuracy: 0.8982
# Epoch 120: val_loss improved from 0.30948 to 0.30799, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2273 - accuracy: 0.8982 - val_loss: 0.3080 - val_accuracy: 0.8692
# Epoch 121/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2265 - accuracy: 0.8980
# Epoch 121: val_loss did not improve from 0.30799
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2265 - accuracy: 0.8980 - val_loss: 0.3130 - val_accuracy: 0.8667
# Epoch 122/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2263 - accuracy: 0.8985
# Epoch 122: val_loss did not improve from 0.30799
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2263 - accuracy: 0.8985 - val_loss: 0.3109 - val_accuracy: 0.8686
# Epoch 123/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.8972
# Epoch 123: val_loss did not improve from 0.30799
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2305 - accuracy: 0.8972 - val_loss: 0.3102 - val_accuracy: 0.8674
# Epoch 124/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2285 - accuracy: 0.8984
# Epoch 124: val_loss did not improve from 0.30799
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2285 - accuracy: 0.8984 - val_loss: 0.3084 - val_accuracy: 0.8696
# Epoch 125/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2231 - accuracy: 0.9000
# Epoch 125: val_loss did not improve from 0.30799
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2231 - accuracy: 0.9000 - val_loss: 0.3101 - val_accuracy: 0.8700
# Epoch 126/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2214 - accuracy: 0.9007
# Epoch 126: val_loss did not improve from 0.30799
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2214 - accuracy: 0.9007 - val_loss: 0.3089 - val_accuracy: 0.8695
# Epoch 127/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.8996
# Epoch 127: val_loss improved from 0.30799 to 0.30515, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 238s 298ms/step - loss: 0.2257 - accuracy: 0.8996 - val_loss: 0.3051 - val_accuracy: 0.8708
# Epoch 128/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2201 - accuracy: 0.9018
# Epoch 128: val_loss did not improve from 0.30515
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2201 - accuracy: 0.9018 - val_loss: 0.3076 - val_accuracy: 0.8698
# Epoch 129/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2188 - accuracy: 0.9023
# Epoch 129: val_loss did not improve from 0.30515
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2188 - accuracy: 0.9023 - val_loss: 0.3146 - val_accuracy: 0.8676
# Epoch 130/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2203 - accuracy: 0.9019
# Epoch 130: val_loss did not improve from 0.30515
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2203 - accuracy: 0.9019 - val_loss: 0.3137 - val_accuracy: 0.8674
# Epoch 131/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9009
# Epoch 131: val_loss did not improve from 0.30515
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2224 - accuracy: 0.9009 - val_loss: 0.3106 - val_accuracy: 0.8686
# Epoch 132/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2181 - accuracy: 0.9031
# Epoch 132: val_loss did not improve from 0.30515
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2181 - accuracy: 0.9031 - val_loss: 0.3072 - val_accuracy: 0.8700
# Epoch 133/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2221 - accuracy: 0.9023
# Epoch 133: val_loss did not improve from 0.30515
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2221 - accuracy: 0.9023 - val_loss: 0.3074 - val_accuracy: 0.8695
# Epoch 134/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2168 - accuracy: 0.9033
# Epoch 134: val_loss did not improve from 0.30515
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2168 - accuracy: 0.9033 - val_loss: 0.3073 - val_accuracy: 0.8716
# Epoch 135/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9045
# Epoch 135: val_loss did not improve from 0.30515
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2153 - accuracy: 0.9045 - val_loss: 0.3067 - val_accuracy: 0.8716
# Epoch 136/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2194 - accuracy: 0.9031
# Epoch 136: val_loss did not improve from 0.30515
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2194 - accuracy: 0.9031 - val_loss: 0.3089 - val_accuracy: 0.8706
# Epoch 137/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2182 - accuracy: 0.9043
# Epoch 137: val_loss did not improve from 0.30515
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2182 - accuracy: 0.9043 - val_loss: 0.3087 - val_accuracy: 0.8726
# Epoch 138/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.9054
# Epoch 138: val_loss did not improve from 0.30515
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2138 - accuracy: 0.9054 - val_loss: 0.3093 - val_accuracy: 0.8727
# Epoch 139/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2133 - accuracy: 0.9065
# Epoch 139: val_loss did not improve from 0.30515
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2133 - accuracy: 0.9065 - val_loss: 0.3095 - val_accuracy: 0.8709
# Epoch 140/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.9063
# Epoch 140: val_loss did not improve from 0.30515
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2118 - accuracy: 0.9063 - val_loss: 0.3072 - val_accuracy: 0.8713
# Epoch 141/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2116 - accuracy: 0.9064
# Epoch 141: val_loss did not improve from 0.30515
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2116 - accuracy: 0.9064 - val_loss: 0.3072 - val_accuracy: 0.8710
# Epoch 142/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2100 - accuracy: 0.9072
# Epoch 142: val_loss did not improve from 0.30515
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2100 - accuracy: 0.9072 - val_loss: 0.3075 - val_accuracy: 0.8720
# Epoch 143/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9079
# Epoch 143: val_loss improved from 0.30515 to 0.30394, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2084 - accuracy: 0.9079 - val_loss: 0.3039 - val_accuracy: 0.8731
# Epoch 144/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2096 - accuracy: 0.9072
# Epoch 144: val_loss did not improve from 0.30394
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2096 - accuracy: 0.9072 - val_loss: 0.3111 - val_accuracy: 0.8699
# Epoch 145/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9071
# Epoch 145: val_loss did not improve from 0.30394
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2098 - accuracy: 0.9071 - val_loss: 0.3054 - val_accuracy: 0.8742
# Epoch 146/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2083 - accuracy: 0.9081
# Epoch 146: val_loss did not improve from 0.30394
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2083 - accuracy: 0.9081 - val_loss: 0.3117 - val_accuracy: 0.8708
# Epoch 147/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2065 - accuracy: 0.9095
# Epoch 147: val_loss did not improve from 0.30394
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2065 - accuracy: 0.9095 - val_loss: 0.3057 - val_accuracy: 0.8750
# Epoch 148/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.9085
# Epoch 148: val_loss did not improve from 0.30394
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2088 - accuracy: 0.9085 - val_loss: 0.3153 - val_accuracy: 0.8703
# Epoch 149/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9084
# Epoch 149: val_loss did not improve from 0.30394
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2086 - accuracy: 0.9084 - val_loss: 0.3041 - val_accuracy: 0.8727
# Epoch 150/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2038 - accuracy: 0.9103
# Epoch 150: val_loss did not improve from 0.30394
# 799/799 [==============================] - 237s 297ms/step - loss: 0.2038 - accuracy: 0.9103 - val_loss: 0.3095 - val_accuracy: 0.8736
# Epoch 151/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2056 - accuracy: 0.9100
# Epoch 151: val_loss did not improve from 0.30394
# 799/799 [==============================] - 238s 297ms/step - loss: 0.2056 - accuracy: 0.9100 - val_loss: 0.3083 - val_accuracy: 0.8744
# Epoch 152/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2036 - accuracy: 0.9101
# Epoch 152: val_loss did not improve from 0.30394
# 799/799 [==============================] - 238s 298ms/step - loss: 0.2036 - accuracy: 0.9101 - val_loss: 0.3062 - val_accuracy: 0.8739
# Epoch 153/500
# 799/799 [==============================] - ETA: 0s - loss: 0.2042 - accuracy: 0.9107
# Epoch 153: val_loss did not improve from 0.30394
# ...
# Epoch 175: val_loss did not improve from 0.30389
# 799/799 [==============================] - 238s 297ms/step - loss: 0.1908 - accuracy: 0.9171 - val_loss: 0.3039 - val_accuracy: 0.8789
# Epoch 176/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1879 - accuracy: 0.9185
# Epoch 176: val_loss did not improve from 0.30389
# 799/799 [==============================] - 238s 297ms/step - loss: 0.1879 - accuracy: 0.9185 - val_loss: 0.3082 - val_accuracy: 0.8788
# Epoch 177/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.9186
# Epoch 177: val_loss did not improve from 0.30389
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1872 - accuracy: 0.9186 - val_loss: 0.3106 - val_accuracy: 0.8772
# Epoch 178/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.9184
# Epoch 178: val_loss did not improve from 0.30389
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1872 - accuracy: 0.9184 - val_loss: 0.3039 - val_accuracy: 0.8798
# Epoch 179/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9185
# Epoch 179: val_loss improved from 0.30389 to 0.30284, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1881 - accuracy: 0.9185 - val_loss: 0.3028 - val_accuracy: 0.8792
# Epoch 180/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.9180
# Epoch 180: val_loss did not improve from 0.30284
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1902 - accuracy: 0.9180 - val_loss: 0.3035 - val_accuracy: 0.8799
# Epoch 181/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9205
# Epoch 181: val_loss did not improve from 0.30284
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1845 - accuracy: 0.9205 - val_loss: 0.3041 - val_accuracy: 0.8804
# Epoch 182/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1859 - accuracy: 0.9197
# Epoch 182: val_loss improved from 0.30284 to 0.30264, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1859 - accuracy: 0.9197 - val_loss: 0.3026 - val_accuracy: 0.8798
# Epoch 183/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9189
# Epoch 183: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1880 - accuracy: 0.9189 - val_loss: 0.3056 - val_accuracy: 0.8784
# Epoch 184/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1906 - accuracy: 0.9183
# Epoch 184: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 297ms/step - loss: 0.1906 - accuracy: 0.9183 - val_loss: 0.3045 - val_accuracy: 0.8787
# Epoch 185/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1832 - accuracy: 0.9207
# Epoch 185: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1832 - accuracy: 0.9207 - val_loss: 0.3064 - val_accuracy: 0.8793
# Epoch 186/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1867 - accuracy: 0.9200
# Epoch 186: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1867 - accuracy: 0.9200 - val_loss: 0.3072 - val_accuracy: 0.8781
# Epoch 187/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1835 - accuracy: 0.9208
# Epoch 187: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1835 - accuracy: 0.9208 - val_loss: 0.3062 - val_accuracy: 0.8778
# Epoch 188/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9201
# Epoch 188: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1845 - accuracy: 0.9201 - val_loss: 0.3075 - val_accuracy: 0.8797
# Epoch 189/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1828 - accuracy: 0.9212
# Epoch 189: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1828 - accuracy: 0.9212 - val_loss: 0.3058 - val_accuracy: 0.8805
# Epoch 190/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9217
# Epoch 190: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1820 - accuracy: 0.9217 - val_loss: 0.3043 - val_accuracy: 0.8799
# Epoch 191/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1808 - accuracy: 0.9217
# Epoch 191: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1808 - accuracy: 0.9217 - val_loss: 0.3058 - val_accuracy: 0.8812
# Epoch 192/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1822 - accuracy: 0.9217
# Epoch 192: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1822 - accuracy: 0.9217 - val_loss: 0.3157 - val_accuracy: 0.8779
# Epoch 193/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1797 - accuracy: 0.9226
# Epoch 193: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1797 - accuracy: 0.9226 - val_loss: 0.3068 - val_accuracy: 0.8806
# Epoch 194/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.9232
# Epoch 194: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1780 - accuracy: 0.9232 - val_loss: 0.3064 - val_accuracy: 0.8812
# Epoch 195/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9218
# Epoch 195: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1821 - accuracy: 0.9218 - val_loss: 0.3044 - val_accuracy: 0.8802
# Epoch 196/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9233
# Epoch 196: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1789 - accuracy: 0.9233 - val_loss: 0.3209 - val_accuracy: 0.8756
# Epoch 197/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1846 - accuracy: 0.9211
# Epoch 197: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1846 - accuracy: 0.9211 - val_loss: 0.3096 - val_accuracy: 0.8790
# Epoch 198/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1818 - accuracy: 0.9222
# Epoch 198: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1818 - accuracy: 0.9222 - val_loss: 0.3039 - val_accuracy: 0.8807
# Epoch 199/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9247
# Epoch 199: val_loss did not improve from 0.30264
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1746 - accuracy: 0.9247 - val_loss: 0.3058 - val_accuracy: 0.8809
# Epoch 200/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9249
# Epoch 200: val_loss improved from 0.30264 to 0.30115, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 239s 299ms/step - loss: 0.1748 - accuracy: 0.9249 - val_loss: 0.3012 - val_accuracy: 0.8831
# Epoch 201/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9233
# Epoch 201: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1789 - accuracy: 0.9233 - val_loss: 0.3075 - val_accuracy: 0.8803
# Epoch 202/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1766 - accuracy: 0.9241
# Epoch 202: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1766 - accuracy: 0.9241 - val_loss: 0.3078 - val_accuracy: 0.8821
# Epoch 203/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9246
# Epoch 203: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1753 - accuracy: 0.9246 - val_loss: 0.3086 - val_accuracy: 0.8798
# Epoch 204/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1771 - accuracy: 0.9243
# Epoch 204: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1771 - accuracy: 0.9243 - val_loss: 0.3056 - val_accuracy: 0.8811
# Epoch 205/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9239
# Epoch 205: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1778 - accuracy: 0.9239 - val_loss: 0.3049 - val_accuracy: 0.8825
# Epoch 206/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1735 - accuracy: 0.9251
# Epoch 206: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1735 - accuracy: 0.9251 - val_loss: 0.3055 - val_accuracy: 0.8816
# Epoch 207/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1726 - accuracy: 0.9260
# Epoch 207: val_loss did not improve from 0.30115
# 799/799 [==============================] - 239s 299ms/step - loss: 0.1726 - accuracy: 0.9260 - val_loss: 0.3080 - val_accuracy: 0.8819
# Epoch 208/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1729 - accuracy: 0.9261
# Epoch 208: val_loss did not improve from 0.30115
# 799/799 [==============================] - 239s 299ms/step - loss: 0.1729 - accuracy: 0.9261 - val_loss: 0.3054 - val_accuracy: 0.8816
# Epoch 209/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9265
# Epoch 209: val_loss did not improve from 0.30115
# 799/799 [==============================] - 239s 299ms/step - loss: 0.1720 - accuracy: 0.9265 - val_loss: 0.3079 - val_accuracy: 0.8814
# Epoch 210/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.9266
# Epoch 210: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1714 - accuracy: 0.9266 - val_loss: 0.3087 - val_accuracy: 0.8806
# Epoch 211/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9270
# Epoch 211: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1705 - accuracy: 0.9270 - val_loss: 0.3071 - val_accuracy: 0.8823
# Epoch 212/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1762 - accuracy: 0.9247
# Epoch 212: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1762 - accuracy: 0.9247 - val_loss: 0.3120 - val_accuracy: 0.8818
# Epoch 213/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.9272
# Epoch 213: val_loss did not improve from 0.30115
# 799/799 [==============================] - 239s 299ms/step - loss: 0.1714 - accuracy: 0.9272 - val_loss: 0.3089 - val_accuracy: 0.8813
# Epoch 214/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1712 - accuracy: 0.9265
# Epoch 214: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1712 - accuracy: 0.9265 - val_loss: 0.3123 - val_accuracy: 0.8804
# Epoch 215/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1702 - accuracy: 0.9271
# Epoch 215: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1702 - accuracy: 0.9271 - val_loss: 0.3078 - val_accuracy: 0.8823
# Epoch 216/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1695 - accuracy: 0.9275
# Epoch 216: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1695 - accuracy: 0.9275 - val_loss: 0.3069 - val_accuracy: 0.8833
# Epoch 217/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 0.9276
# Epoch 217: val_loss did not improve from 0.30115
# 799/799 [==============================] - 239s 299ms/step - loss: 0.1696 - accuracy: 0.9276 - val_loss: 0.3119 - val_accuracy: 0.8807
# Epoch 218/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1706 - accuracy: 0.9273
# Epoch 218: val_loss did not improve from 0.30115
# 799/799 [==============================] - 239s 299ms/step - loss: 0.1706 - accuracy: 0.9273 - val_loss: 0.3081 - val_accuracy: 0.8837
# Epoch 219/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1711 - accuracy: 0.9274
# Epoch 219: val_loss did not improve from 0.30115
# 799/799 [==============================] - 239s 299ms/step - loss: 0.1711 - accuracy: 0.9274 - val_loss: 0.3112 - val_accuracy: 0.8818
# Epoch 220/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1709 - accuracy: 0.9273
# Epoch 220: val_loss did not improve from 0.30115
# 799/799 [==============================] - 239s 299ms/step - loss: 0.1709 - accuracy: 0.9273 - val_loss: 0.3101 - val_accuracy: 0.8819
# Epoch 221/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 0.9283
# Epoch 221: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1696 - accuracy: 0.9283 - val_loss: 0.3130 - val_accuracy: 0.8816
# Epoch 222/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1716 - accuracy: 0.9274
# Epoch 222: val_loss did not improve from 0.30115
# 799/799 [==============================] - 239s 299ms/step - loss: 0.1716 - accuracy: 0.9274 - val_loss: 0.3135 - val_accuracy: 0.8822
# Epoch 223/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1675 - accuracy: 0.9289
# Epoch 223: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1675 - accuracy: 0.9289 - val_loss: 0.3299 - val_accuracy: 0.8754
# Epoch 224/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9277
# Epoch 224: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1700 - accuracy: 0.9277 - val_loss: 0.3137 - val_accuracy: 0.8821
# Epoch 225/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9296
# Epoch 225: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1650 - accuracy: 0.9296 - val_loss: 0.3050 - val_accuracy: 0.8854
# Epoch 226/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1637 - accuracy: 0.9305
# Epoch 226: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1637 - accuracy: 0.9305 - val_loss: 0.3074 - val_accuracy: 0.8831
# Epoch 227/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.9304
# Epoch 227: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1639 - accuracy: 0.9304 - val_loss: 0.3108 - val_accuracy: 0.8831
# Epoch 228/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1665 - accuracy: 0.9295
# Epoch 228: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1665 - accuracy: 0.9295 - val_loss: 0.3079 - val_accuracy: 0.8840
# Epoch 229/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1654 - accuracy: 0.9297
# Epoch 229: val_loss did not improve from 0.30115
# 799/799 [==============================] - 238s 298ms/step - loss: 0.1654 - accuracy: 0.9297 - val_loss: 0.3152 - val_accuracy: 0.8819
# Epoch 230/500
# 799/799 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9294
# Epoch 230: val_loss did not improve from 0.30115
# 799/799 [==============================] - 239s 299ms/step - loss: 0.1655 - accuracy: 0.9294 - val_loss: 0.3110 - val_accuracy: 0.8815
# Training Time:  54625.38853549957 seconds

# %% [markdown]
# # Saving the model and training history

# %%
gru_model.save('GRU_Architecture_5_Features.h5')
np.save('GRU_history_5_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of GRU Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of GRU Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for GRU Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ 0.46349357],
#         [ 0.36358773],
#         [ 3.37428511],
#         [ 2.21070338],
#         [-0.53335855]],
#
#        [[-3.12902325],
#         [-2.41096786],
#         [-4.83420457],
#         [-4.38417685],
#         [ 1.45759665]],
#
#        [[ 1.56338732],
#         [ 1.49249955],
#         [ 1.91877559],
#         [ 1.81817072],
#         [ 1.62761275]],
#
#        ...,
#
#        [[ 0.69592067],
#         [ 0.84838968],
#         [-0.60272074],
#         [-0.04577766],
#         [-0.3113151 ]],
#
#        [[ 2.17107007],
#         [ 2.96016373],
#         [ 3.46610892],
#         [ 2.54044544],
#         [ 0.99792245]],
#
#        [[ 0.16525652],
#         [-0.05828783],
#         [-0.23818711],
#         [-0.50661368],
#         [-0.80537552]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = gru_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 56s 12ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = gru_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.88, Test loss: 0.31

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88     77676
#            1       0.89      0.87      0.88     77614
#
#     accuracy                           0.88    155290
#    macro avg       0.88      0.88      0.88    155290
# weighted avg       0.88      0.88      0.88    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix GRU - 5 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.8817889110696117
# Precision: 0.8877111713055653
# Recall: 0.8740433426959053
# F1-score: 0.880824238961781
# AUC-ROC: 0.9529477536388327

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['GRU - 5'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()
