# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 16/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 16/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 16/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 16/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - LSTM</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
from keras.layers import LSTM
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for LSTM

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (16, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
lstm_model = Sequential([
    
    LSTM(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1), 
    LSTM(256, activation='relu'),
    Dropout(0.1),  
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 16, 512)           1052672
#
#  dropout (Dropout)           (None, 16, 512)           0
#
#  lstm_1 (LSTM)               (None, 256)               787456
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,840,385
# Trainable params: 1,840,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
lstm_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/LSTM_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = lstm_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6357 - accuracy: 0.6316
# Epoch 1: val_loss improved from inf to 0.61062, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 671s 836ms/step - loss: 0.6357 - accuracy: 0.6316 - val_loss: 0.6106 - val_accuracy: 0.6566
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5953 - accuracy: 0.6712
# Epoch 2: val_loss improved from 0.61062 to 0.57101, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 667s 835ms/step - loss: 0.5953 - accuracy: 0.6712 - val_loss: 0.5710 - val_accuracy: 0.6923
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5596 - accuracy: 0.6989
# Epoch 3: val_loss improved from 0.57101 to 0.53149, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 667s 835ms/step - loss: 0.5596 - accuracy: 0.6989 - val_loss: 0.5315 - val_accuracy: 0.7199
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5108 - accuracy: 0.7320
# Epoch 4: val_loss improved from 0.53149 to 0.48105, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 667s 835ms/step - loss: 0.5108 - accuracy: 0.7320 - val_loss: 0.4811 - val_accuracy: 0.7510
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5036 - accuracy: 0.7423
# Epoch 5: val_loss did not improve from 0.48105
# 799/799 [==============================] - 667s 834ms/step - loss: 0.5036 - accuracy: 0.7423 - val_loss: 0.5509 - val_accuracy: 0.7730
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 2.6261 - accuracy: 0.6079
# Epoch 6: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 2.6261 - accuracy: 0.6079 - val_loss: 82.2993 - val_accuracy: 0.5045
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 3.6660 - accuracy: 0.5996
# Epoch 7: val_loss did not improve from 0.48105
# 799/799 [==============================] - 667s 834ms/step - loss: 3.6660 - accuracy: 0.5996 - val_loss: 0.6564 - val_accuracy: 0.6124
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6660 - accuracy: 0.6119
# Epoch 8: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6660 - accuracy: 0.6119 - val_loss: 0.6517 - val_accuracy: 0.6164
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6530 - accuracy: 0.6167
# Epoch 9: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6530 - accuracy: 0.6167 - val_loss: 0.6482 - val_accuracy: 0.6221
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6496 - accuracy: 0.6204
# Epoch 10: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6496 - accuracy: 0.6204 - val_loss: 0.6442 - val_accuracy: 0.6256
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6495 - accuracy: 0.6220
# Epoch 11: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6495 - accuracy: 0.6220 - val_loss: 0.6422 - val_accuracy: 0.6260
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6484 - accuracy: 0.6215
# Epoch 12: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6484 - accuracy: 0.6215 - val_loss: 0.6489 - val_accuracy: 0.6211
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6502 - accuracy: 0.6199
# Epoch 13: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 833ms/step - loss: 0.6502 - accuracy: 0.6199 - val_loss: 0.6438 - val_accuracy: 0.6258
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6465 - accuracy: 0.6232
# Epoch 14: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6465 - accuracy: 0.6232 - val_loss: 0.6403 - val_accuracy: 0.6281
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6442 - accuracy: 0.6260
# Epoch 15: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6442 - accuracy: 0.6260 - val_loss: 0.6373 - val_accuracy: 0.6311
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6391 - accuracy: 0.6299
# Epoch 16: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 833ms/step - loss: 0.6391 - accuracy: 0.6299 - val_loss: 0.6359 - val_accuracy: 0.6327
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6359 - accuracy: 0.6324
# Epoch 17: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6359 - accuracy: 0.6324 - val_loss: 0.6302 - val_accuracy: 0.6391
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6351 - accuracy: 0.6351
# Epoch 18: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 833ms/step - loss: 0.6351 - accuracy: 0.6351 - val_loss: 0.6266 - val_accuracy: 0.6405
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6238 - accuracy: 0.6427
# Epoch 19: val_loss did not improve from 0.48105
# 799/799 [==============================] - 665s 833ms/step - loss: 0.6238 - accuracy: 0.6427 - val_loss: 0.6192 - val_accuracy: 0.6472
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6179 - accuracy: 0.6501
# Epoch 20: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 833ms/step - loss: 0.6179 - accuracy: 0.6501 - val_loss: 0.6093 - val_accuracy: 0.6541
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6150 - accuracy: 0.6514
# Epoch 21: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 833ms/step - loss: 0.6150 - accuracy: 0.6514 - val_loss: 0.5983 - val_accuracy: 0.6643
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6238 - accuracy: 0.6469
# Epoch 22: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 833ms/step - loss: 0.6238 - accuracy: 0.6469 - val_loss: 0.6148 - val_accuracy: 0.6514
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6064 - accuracy: 0.6601
# Epoch 23: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6064 - accuracy: 0.6601 - val_loss: 0.5827 - val_accuracy: 0.6791
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5876 - accuracy: 0.6784
# Epoch 24: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.5876 - accuracy: 0.6784 - val_loss: 0.5646 - val_accuracy: 0.6952
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.9682 - accuracy: 0.6073
# Epoch 25: val_loss did not improve from 0.48105
# 799/799 [==============================] - 667s 834ms/step - loss: 0.9682 - accuracy: 0.6073 - val_loss: 0.6580 - val_accuracy: 0.6084
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6650 - accuracy: 0.6146
# Epoch 26: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6650 - accuracy: 0.6146 - val_loss: 0.6517 - val_accuracy: 0.6208
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6545 - accuracy: 0.6195
# Epoch 27: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 833ms/step - loss: 0.6545 - accuracy: 0.6195 - val_loss: 0.6443 - val_accuracy: 0.6252
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6501 - accuracy: 0.6221
# Epoch 28: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 833ms/step - loss: 0.6501 - accuracy: 0.6221 - val_loss: 0.6412 - val_accuracy: 0.6298
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6446 - accuracy: 0.6255
# Epoch 29: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 833ms/step - loss: 0.6446 - accuracy: 0.6255 - val_loss: 0.6340 - val_accuracy: 0.6337
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6584 - accuracy: 0.6279
# Epoch 30: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 833ms/step - loss: 0.6584 - accuracy: 0.6279 - val_loss: 0.6389 - val_accuracy: 0.6311
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.8135 - accuracy: 0.6017
# Epoch 31: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.8135 - accuracy: 0.6017 - val_loss: 0.6512 - val_accuracy: 0.6176
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6550 - accuracy: 0.6156
# Epoch 32: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6550 - accuracy: 0.6156 - val_loss: 0.6490 - val_accuracy: 0.6219
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6497 - accuracy: 0.6200
# Epoch 33: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6497 - accuracy: 0.6200 - val_loss: 0.6441 - val_accuracy: 0.6265
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6463 - accuracy: 0.6225
# Epoch 34: val_loss did not improve from 0.48105
# 799/799 [==============================] - 666s 834ms/step - loss: 0.6463 - accuracy: 0.6225 - val_loss: 0.6396 - val_accuracy: 0.6296
# Training Time:  22654.002445459366 seconds

# %% [markdown]
# # Saving the model and training history

# %%
lstm_model.save('LSTM_Architecture_16_Features.h5')
np.save('LSTM_history_16_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of LSTM Neural Network - 16 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of LSTM Neural Network - 16 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for LSTM Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ 0.46349357],
#         [ 0.36358773],
#         [ 3.37428511],
#         ...,
#         [ 0.3136725 ],
#         [ 0.93505536],
#         [ 0.47221327]],
#
#        [[-3.12902325],
#         [-2.41096786],
#         [-4.83420457],
#         ...,
#         [-2.085794  ],
#         [-0.06868928],
#         [-0.48746147]],
#
#        [[ 1.56338732],
#         [ 1.49249955],
#         [ 1.91877559],
#         ...,
#         [ 1.47627508],
#         [-1.63669436],
#         [-0.50830284]],
#
#        ...,
#
#        [[ 0.69592067],
#         [ 0.84838968],
#         [-0.60272074],
#         ...,
#         [ 1.36267423],
#         [ 0.83525597],
#         [ 0.37978343]],
#
#        [[ 2.17107007],
#         [ 2.96016373],
#         [ 3.46610892],
#         ...,
#         [ 2.05461281],
#         [ 0.38902544],
#         [ 0.38288843]],
#
#        [[ 0.16525652],
#         [-0.05828783],
#         [-0.23818711],
#         ...,
#         [ 0.66144768],
#         [ 0.74483801],
#         [ 0.7998778 ]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = lstm_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 137s 28ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = lstm_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.75, Test loss: 0.48

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76     77676
#            1       0.78      0.70      0.74     77614
#
#     accuracy                           0.75    155290
#    macro avg       0.75      0.75      0.75    155290
# weighted avg       0.75      0.75      0.75    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix LSTM - 16 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.7511559018610342
# Precision: 0.7769675777863062
# Recall: 0.7042801556420234
# F1-score: 0.7388404171200336
# AUC-ROC: 0.8416056993018008

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['LSTM - 16'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()
