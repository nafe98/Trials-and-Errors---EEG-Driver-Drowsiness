# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 30/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 30/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 30/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 30/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - GRU</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for GRU

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (30, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
gru_model = Sequential([
    
    GRU(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1),
    GRU(256, activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 30, 512)           791040
#
#  dropout (Dropout)           (None, 30, 512)           0
#
#  gru_1 (GRU)                 (None, 256)               591360
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,382,657
# Trainable params: 1,382,657
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
gru_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Integrating Callbacks</h2>
#
# </div>

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/GRU_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = gru_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping], 
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6413 - accuracy: 0.6251
# Epoch 1: val_loss improved from inf to 0.62708, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1292s 2s/step - loss: 0.6413 - accuracy: 0.6251 - val_loss: 0.6271 - val_accuracy: 0.6393
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5966 - accuracy: 0.6675
# Epoch 2: val_loss improved from 0.62708 to 0.56361, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1287s 2s/step - loss: 0.5966 - accuracy: 0.6675 - val_loss: 0.5636 - val_accuracy: 0.6941
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5245 - accuracy: 0.7228
# Epoch 3: val_loss improved from 0.56361 to 0.47805, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1286s 2s/step - loss: 0.5245 - accuracy: 0.7228 - val_loss: 0.4781 - val_accuracy: 0.7532
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4426 - accuracy: 0.7774
# Epoch 4: val_loss improved from 0.47805 to 0.39045, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1287s 2s/step - loss: 0.4426 - accuracy: 0.7774 - val_loss: 0.3905 - val_accuracy: 0.8105
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5542 - accuracy: 0.6956
# Epoch 5: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.5542 - accuracy: 0.6956 - val_loss: 0.6510 - val_accuracy: 0.6192
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6461 - accuracy: 0.6256
# Epoch 6: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1287s 2s/step - loss: 0.6461 - accuracy: 0.6256 - val_loss: 0.6336 - val_accuracy: 0.6387
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6344 - accuracy: 0.6356
# Epoch 7: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.6344 - accuracy: 0.6356 - val_loss: 0.6242 - val_accuracy: 0.6445
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6275 - accuracy: 0.6415
# Epoch 8: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.6275 - accuracy: 0.6415 - val_loss: 0.6189 - val_accuracy: 0.6493
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6185 - accuracy: 0.6502
# Epoch 9: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1287s 2s/step - loss: 0.6185 - accuracy: 0.6502 - val_loss: 0.6048 - val_accuracy: 0.6607
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6138 - accuracy: 0.6540
# Epoch 10: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1287s 2s/step - loss: 0.6138 - accuracy: 0.6540 - val_loss: 0.6024 - val_accuracy: 0.6630
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6156 - accuracy: 0.6517
# Epoch 11: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1287s 2s/step - loss: 0.6156 - accuracy: 0.6517 - val_loss: 0.6156 - val_accuracy: 0.6509
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6144 - accuracy: 0.6521
# Epoch 12: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1287s 2s/step - loss: 0.6144 - accuracy: 0.6521 - val_loss: 0.6004 - val_accuracy: 0.6642
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5989 - accuracy: 0.6667
# Epoch 13: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1287s 2s/step - loss: 0.5989 - accuracy: 0.6667 - val_loss: 0.5913 - val_accuracy: 0.6751
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5896 - accuracy: 0.6756
# Epoch 14: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.5896 - accuracy: 0.6756 - val_loss: 0.5772 - val_accuracy: 0.6879
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5777 - accuracy: 0.6876
# Epoch 15: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.5777 - accuracy: 0.6876 - val_loss: 0.5595 - val_accuracy: 0.7041
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5622 - accuracy: 0.6988
# Epoch 16: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.5622 - accuracy: 0.6988 - val_loss: 0.5406 - val_accuracy: 0.7172
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5624 - accuracy: 0.7007
# Epoch 17: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.5624 - accuracy: 0.7007 - val_loss: 0.5493 - val_accuracy: 0.7138
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5529 - accuracy: 0.7096
# Epoch 18: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.5529 - accuracy: 0.7096 - val_loss: 0.5331 - val_accuracy: 0.7234
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5727 - accuracy: 0.6911
# Epoch 19: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.5727 - accuracy: 0.6911 - val_loss: 0.5410 - val_accuracy: 0.7186
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5441 - accuracy: 0.7161
# Epoch 20: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1287s 2s/step - loss: 0.5441 - accuracy: 0.7161 - val_loss: 0.5242 - val_accuracy: 0.7305
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6576 - accuracy: 0.6446
# Epoch 21: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1287s 2s/step - loss: 0.6576 - accuracy: 0.6446 - val_loss: 0.6629 - val_accuracy: 0.6088
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6640 - accuracy: 0.6056
# Epoch 22: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1287s 2s/step - loss: 0.6640 - accuracy: 0.6056 - val_loss: 0.6560 - val_accuracy: 0.6134
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6583 - accuracy: 0.6103
# Epoch 23: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.6583 - accuracy: 0.6103 - val_loss: 0.6536 - val_accuracy: 0.6140
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6556 - accuracy: 0.6138
# Epoch 24: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.6556 - accuracy: 0.6138 - val_loss: 0.6513 - val_accuracy: 0.6178
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6537 - accuracy: 0.6158
# Epoch 25: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.6537 - accuracy: 0.6158 - val_loss: 0.6506 - val_accuracy: 0.6196
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6520 - accuracy: 0.6176
# Epoch 26: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1287s 2s/step - loss: 0.6520 - accuracy: 0.6176 - val_loss: 0.6476 - val_accuracy: 0.6210
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6508 - accuracy: 0.6187
# Epoch 27: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1287s 2s/step - loss: 0.6508 - accuracy: 0.6187 - val_loss: 0.6476 - val_accuracy: 0.6205
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6499 - accuracy: 0.6192
# Epoch 28: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6499 - accuracy: 0.6192 - val_loss: 0.6460 - val_accuracy: 0.6219
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6492 - accuracy: 0.6199
# Epoch 29: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6492 - accuracy: 0.6199 - val_loss: 0.6448 - val_accuracy: 0.6233
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6487 - accuracy: 0.6206
# Epoch 30: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6487 - accuracy: 0.6206 - val_loss: 0.6460 - val_accuracy: 0.6236
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6477 - accuracy: 0.6219
# Epoch 31: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6477 - accuracy: 0.6219 - val_loss: 0.6433 - val_accuracy: 0.6240
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6465 - accuracy: 0.6229
# Epoch 32: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6465 - accuracy: 0.6229 - val_loss: 0.6427 - val_accuracy: 0.6267
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6461 - accuracy: 0.6236
# Epoch 33: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6461 - accuracy: 0.6236 - val_loss: 0.6413 - val_accuracy: 0.6265
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6439 - accuracy: 0.6251
# Epoch 34: val_loss did not improve from 0.39045
# 799/799 [==============================] - 1286s 2s/step - loss: 0.6439 - accuracy: 0.6251 - val_loss: 0.6392 - val_accuracy: 0.6279
# Training Time:  43740.788788318634 seconds

# %% [markdown]
# # Saving the model and training history

# %%
gru_model.save('GRU_Architecture_30_Features.h5')
np.save('GRU_history_30_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of GRU Network - 30 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of GRU Network - 30 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for GRU Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ 0.46349357],
#         [ 0.36358773],
#         [ 3.37428511],
#         ...,
#         [ 0.24695902],
#         [-0.22902202],
#         [ 0.7564941 ]],
#
#        [[-3.12902325],
#         [-2.41096786],
#         [-4.83420457],
#         ...,
#         [-1.65535766],
#         [-0.1401229 ],
#         [-1.60633927]],
#
#        [[ 1.56338732],
#         [ 1.49249955],
#         [ 1.91877559],
#         ...,
#         [ 1.6443935 ],
#         [ 1.04322205],
#         [ 1.66497241]],
#
#        ...,
#
#        [[ 0.69592067],
#         [ 0.84838968],
#         [-0.60272074],
#         ...,
#         [ 0.7658359 ],
#         [ 0.12488601],
#         [ 0.54554344]],
#
#        [[ 2.17107007],
#         [ 2.96016373],
#         [ 3.46610892],
#         ...,
#         [ 1.53530609],
#         [ 1.02276555],
#         [ 2.41863245]],
#
#        [[ 0.16525652],
#         [-0.05828783],
#         [-0.23818711],
#         ...,
#         [ 0.9879833 ],
#         [ 1.19448519],
#         [ 0.29219766]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = gru_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 249s 51ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = gru_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.81, Test loss: 0.39

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81     77676
#            1       0.81      0.81      0.81     77614
#
#     accuracy                           0.81    155290
#    macro avg       0.81      0.81      0.81    155290
# weighted avg       0.81      0.81      0.81    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix GRU - 30 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.809433962264151
# Precision: 0.8099768910004002
# Recall: 0.8083593166181359
# F1-score: 0.8091672954028103
# AUC-ROC: 0.9024103473020898

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['GRU - 30'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()
