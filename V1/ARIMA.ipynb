# %% [markdown]
# # Importing Libraries and Loading the file

# %%
import numpy as np
import pandas as pd

# %%
# Load the file
file_path = 'Unemployment Rate.xlsx'
data = pd.read_excel(file_path)

# %% [markdown]
# # Data Analysis and Preprocessing

# %%
# Clean the data by selecting relevant columns
cleaned_data = data[['Observation Date', 'Unemployment Rate']]

# Convert the 'Observation Date' column to datetime format using .loc to avoid the warning
cleaned_data.loc[:, 'Observation Date'] = pd.to_datetime(cleaned_data['Observation Date'])

# Set the 'Observation Date' column as the index
cleaned_data.set_index('Observation Date', inplace=True)

# %%
# Check for missing data
missing_data = cleaned_data.isnull().sum()

# Display the missing data information
missing_data.head()
# Out:
# Unemployment Rate    0
# dtype: int64

# %%
# Perform basic analysis: Summary statistics and plot
summary_stats = cleaned_data.describe()

# %%
summary_stats
# Out:
#        Unemployment Rate
# count         799.000000
# mean            5.865957
# std             1.685733
# min             3.400000
# 25%             4.600000
# 50%             5.600000
# 75%             6.900000
# max            14.800000

# %% [markdown]
# # Data Plotting

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

# Plot the unemployment rate over time with professional styling
plt.figure(figsize=(12, 6))

# Plot with a line and markers for better visibility
plt.plot(cleaned_data.index, cleaned_data['Unemployment Rate'], label='Unemployment Rate', color='b', marker='o', markersize=4, linestyle='-', linewidth=2)

# Add title 
plt.title('Unemployment Rate Over Time in the United States (1959-Present)', fontsize=16, fontweight='bold', family='Times New Roman')

# Add labels 
plt.xlabel('Year', fontsize=12, fontweight='bold', family='Times New Roman')
plt.ylabel('Unemployment Rate (%)', fontsize=12, fontweight='bold', family='Times New Roman')

# Add grid 
plt.grid(True, linestyle='--', color='gray', alpha=0.6)

# Customize tick marks and labels 
plt.xticks(fontsize=10, family='Times New Roman')
plt.yticks(fontsize=10, family='Times New Roman')

# Adding a legend 
plt.legend(loc='upper left', fontsize=10, prop={'family': 'Times New Roman'})

# Make layout tight to avoid overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Stochastic Properties and Pre-testing

# %% [markdown]
# # ACF, PACF, and ADF Test

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from matplotlib import rcParams

rcParams['font.family'] = 'Times New Roman'

# Plot ACF and PACF 
plt.figure(figsize=(14, 7))

# Plot ACF
plt.subplot(121)
plot_acf(cleaned_data['Unemployment Rate'], lags=40, ax=plt.gca(), color='b', alpha=0.6)
plt.title('Autocorrelation Function (ACF) of Unemployment Rate', fontsize=16, fontweight='bold')
plt.xlabel('Lags', fontsize=12, fontweight='bold')
plt.ylabel('Autocorrelation', fontsize=12, fontweight='bold')
plt.grid(True, linestyle='--', color='gray', alpha=0.6)

# Plot PACF
plt.subplot(122)
plot_pacf(cleaned_data['Unemployment Rate'], lags=40, ax=plt.gca(), color='g', alpha=0.6)
plt.title('Partial Autocorrelation Function (PACF) of Unemployment Rate', fontsize=16, fontweight='bold')
plt.xlabel('Lags', fontsize=12, fontweight='bold')
plt.ylabel('Partial Autocorrelation', fontsize=12, fontweight='bold')
plt.grid(True, linestyle='--', color='gray', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
df_cleaned = cleaned_data

# Perform the Augmented Dickey-Fuller test on the 'Unemployment Rate' series
adf_result = adfuller(df_cleaned['Unemployment Rate'])

# Extract the ADF results
adf_statistic = adf_result[0]
adf_p_value = adf_result[1]
adf_critical_values = adf_result[4]

# Display the ADF result 
print("Augmented Dickey-Fuller Test Results")
print("-" * 50)
print(f"ADF Statistic: {adf_statistic:.4f}")
print(f"P-value: {adf_p_value:.4f}")
print("\nCritical Values:")
for key, value in adf_critical_values.items():
    print(f"  {key}: {value:.4f}")
print("-" * 50)

# Interpret the result
if adf_p_value < 0.05:
    print("Conclusion: The series is likely stationary (reject the null hypothesis).")
else:
    print("Conclusion: The series is likely non-stationary (fail to reject the null hypothesis).")
# Out:
# Augmented Dickey-Fuller Test Results
# --------------------------------------------------
# ADF Statistic: -3.4190
# P-value: 0.0103
#
# Critical Values:
#   1%: -3.4386
#   5%: -2.8652
#   10%: -2.5687
# --------------------------------------------------
# Conclusion: The series is likely stationary (reject the null hypothesis).

# %% [markdown]
# # Differencing to make the Data Stationary

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from matplotlib import rcParams

# Set font to Times New Roman for all plots
rcParams['font.family'] = 'Times New Roman'

# Apply differencing to make the data stationary
df_cleaned['Unemployment Rate Diff'] = df_cleaned['Unemployment Rate'].diff()

# Drop the first row since it will be NaN due to the differencing
df_cleaned.dropna(inplace=True)

# Plot the differenced series
plt.figure(figsize=(12, 6))

plt.plot(df_cleaned.index, df_cleaned['Unemployment Rate Diff'], label='Differenced Unemployment Rate', color='b', marker='o', markersize=4, linestyle='-', linewidth=2)
plt.title('Differenced Unemployment Rate Over Time in the United States (1959-Present)', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=12, fontweight='bold')
plt.ylabel('Differenced Unemployment Rate (%)', fontsize=12, fontweight='bold')
plt.grid(True, linestyle='--', color='gray', alpha=0.6)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='upper left', fontsize=10)
plt.tight_layout()
plt.show()

# Re-run the Augmented Dickey-Fuller test to check if the differenced series is stationary
adf_result_diff = adfuller(df_cleaned['Unemployment Rate Diff'])

# Extract the ADF results
adf_statistic_diff = adf_result_diff[0]
adf_p_value_diff = adf_result_diff[1]
adf_critical_values_diff = adf_result_diff[4]

# Display the ADF result for differenced data
print("Augmented Dickey-Fuller Test Results for Differenced Data")
print("-" * 50)
print(f"ADF Statistic: {adf_statistic_diff:.4f}")
print(f"P-value: {adf_p_value_diff:.4f}")
print("\nCritical Values:")
for key, value in adf_critical_values_diff.items():
    print(f"  {key}: {value:.4f}")
print("-" * 50)

# Interpret the result
if adf_p_value_diff < 0.05:
    print("Conclusion: The differenced series is likely stationary (reject the null hypothesis).")
else:
    print("Conclusion: The differenced series is likely non-stationary (fail to reject the null hypothesis).")

# Plot ACF and PACF for differenced Unemployment Rate
plt.figure(figsize=(14, 7))

# Plot ACF
plt.subplot(121)
plot_acf(df_cleaned['Unemployment Rate Diff'], lags=40, ax=plt.gca(), color='b', alpha=0.6)
plt.title('Autocorrelation Function (ACF) of Differenced Unemployment Rate', fontsize=16, fontweight='bold')
plt.xlabel('Lags', fontsize=12, fontweight='bold')
plt.ylabel('Autocorrelation', fontsize=12, fontweight='bold')
plt.grid(True, linestyle='--', color='gray', alpha=0.6)

# Plot PACF
plt.subplot(122)
plot_pacf(df_cleaned['Unemployment Rate Diff'], lags=40, ax=plt.gca(), color='g', alpha=0.6)
plt.title('Partial Autocorrelation Function (PACF) of Differenced Unemployment Rate', fontsize=16, fontweight='bold')
plt.xlabel('Lags', fontsize=12, fontweight='bold')
plt.ylabel('Partial Autocorrelation', fontsize=12, fontweight='bold')
plt.grid(True, linestyle='--', color='gray', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# Augmented Dickey-Fuller Test Results for Differenced Data
# --------------------------------------------------
# ADF Statistic: -15.5277
# P-value: 0.0000
#
# Critical Values:
#   1%: -3.4386
#   5%: -2.8652
#   10%: -2.5687
# --------------------------------------------------
# Conclusion: The differenced series is likely stationary (reject the null hypothesis).

# %% [markdown]
# # Find Optimal AR Lag Using AIC and BIC

# %%
import numpy as np
from statsmodels.tsa.ar_model import AutoReg
import matplotlib.pyplot as plt

# Set the frequency to monthly (MS - Month Start) if the data is monthly
df_cleaned = df_cleaned.asfreq('MS')

# Max lag to check
max_lag = 20  

# Store the AIC and BIC values for each lag
aic_values = []
bic_values = []
lags = list(range(1, max_lag + 1))

# Loop over different lags and fit the AR model
for lag in lags:
    model = AutoReg(df_cleaned['Unemployment Rate Diff'], lags=lag)  # Use differenced series
    ar_model_fitted = model.fit()
    
    # Store the AIC and BIC values for each lag
    aic_values.append(ar_model_fitted.aic)
    bic_values.append(ar_model_fitted.bic)

# Find the lag with the lowest AIC and BIC
optimal_aic_lag = lags[np.argmin(aic_values)]
optimal_bic_lag = lags[np.argmin(bic_values)]

# Print AIC and BIC values for each lag
print("AIC and BIC Values for Different Lags")
print("-" * 50)
for lag, aic, bic in zip(lags, aic_values, bic_values):
    print(f"Lag {lag}: AIC = {aic:.4f}, BIC = {bic:.4f}")

# Print the optimal lags based on AIC and BIC
print("-" * 50)
print(f"Optimal lag based on AIC: {optimal_aic_lag}")
print(f"Optimal lag based on BIC: {optimal_bic_lag}")

# Plot the AIC and BIC values for each lag
plt.figure(figsize=(10, 6))
plt.plot(lags, aic_values, label='AIC', color='b', marker='o')
plt.plot(lags, bic_values, label='BIC', color='r', marker='o')
plt.xlabel('Lag', fontsize=12, fontweight='bold')
plt.ylabel('Value', fontsize=12, fontweight='bold')
plt.title('AIC and BIC for Different Lags', fontsize=16, fontweight='bold')
plt.legend()
plt.grid(True, linestyle='--', color='gray', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# AIC and BIC Values for Different Lags
# --------------------------------------------------
# Lag 1: AIC = 915.0290, BIC = 929.0716
# Lag 2: AIC = 911.7870, BIC = 930.5054
# Lag 3: AIC = 912.7465, BIC = 936.1383
# Lag 4: AIC = 910.2292, BIC = 938.2917
# Lag 5: AIC = 911.9947, BIC = 944.7254
# Lag 6: AIC = 912.7131, BIC = 950.1095
# Lag 7: AIC = 914.5608, BIC = 956.6205
# Lag 8: AIC = 915.9126, BIC = 962.6329
# Lag 9: AIC = 917.3386, BIC = 968.7170
# Lag 10: AIC = 919.0581, BIC = 975.0920
# Lag 11: AIC = 919.3587, BIC = 980.0457
# Lag 12: AIC = 921.1269, BIC = 986.4643
# Lag 13: AIC = 921.9603, BIC = 991.9456
# Lag 14: AIC = 921.6016, BIC = 996.2322
# Lag 15: AIC = 923.0053, BIC = 1002.2786
# Lag 16: AIC = 924.8610, BIC = 1008.7744
# Lag 17: AIC = 926.0114, BIC = 1014.5623
# Lag 18: AIC = 927.7845, BIC = 1020.9703
# Lag 19: AIC = 929.0473, BIC = 1026.8655
# Lag 20: AIC = 930.3470, BIC = 1032.7950
# --------------------------------------------------
# Optimal lag based on AIC: 4
# Optimal lag based on BIC: 1

# %% [markdown]
# # Auto Regressive Model

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.stats.diagnostic import acorr_ljungbox
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Use the optimal lag (e.g., optimal_aic_lag or optimal_bic_lag)
optimal_lag = optimal_aic_lag  # Or use optimal_bic_lag if you prefer

# Assuming 'df_cleaned' contains the original dataset with 'Unemployment Rate' and 'Observation Date'
df_cleaned = cleaned_data  # Replace with your actual cleaned data
df_cleaned = df_cleaned.asfreq('MS')  # Ensure the frequency is set to monthly

# Split the data into training and testing sets (assuming df_cleaned is your DataFrame)
train = df_cleaned['Unemployment Rate Diff'][:int(0.8 * len(df_cleaned))]
test = df_cleaned['Unemployment Rate Diff'][int(0.8 * len(df_cleaned)):]

# Fit the AR model with the optimal lag
ar_model = AutoReg(train, lags=optimal_lag).fit()

# Print AR model summary
print(f"\nAR-{optimal_lag} Model Summary")
print(ar_model.summary())

# One-step-ahead predictions for the test period
test_pred = ar_model.predict(
    start=test.index[0],
    end=test.index[-1],
    dynamic=False
)

# Plotting the results with professional settings
plt.figure(figsize=(12, 4))
plt.plot(train.index, train, label="Training data", color='b')
plt.plot(test.index, test, label="Actual (Test)", color='g')
plt.plot(test.index, test_pred, label="AR Prediction (Test)", linestyle="--", color='r')

# Add grid, labels, and title
plt.title("AR Model – Holding Period Performance", fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Unemployment Rate Diff', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)  # Add gridlines
plt.legend()
plt.tight_layout()  # Ensure everything fits nicely
plt.show()

# Refit the model on the full dataset (for forecasting)
ar_full = AutoReg(df_cleaned['Unemployment Rate Diff'], lags=optimal_lag).fit()

# Forecast for the next 10 years (120 months)
forecast_steps = 120  # 10 years * 12 months
forecast_120 = ar_full.predict(
    start=len(df_cleaned),
    end=len(df_cleaned) + forecast_steps - 1,
    dynamic=False
)

# Create a new time index for the forecasted period (next 10 years)
forecast_index = pd.date_range(df_cleaned.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='MS')

# Combine the original series and the forecasted values
forecast_series = pd.Series(forecast_120, index=forecast_index)

# Plot the original data and the forecasted values with professional settings
plt.figure(figsize=(12, 4))
plt.plot(df_cleaned.index, df_cleaned['Unemployment Rate Diff'], label="Observed", color='b')
plt.plot(forecast_series.index, forecast_series, label="10-Year Forecast", linestyle="--", color='r')

# Add grid, labels, and title
plt.title("AR Model – 10-Year Forecast", fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Unemployment Rate Diff', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)  # Add gridlines
plt.legend()
plt.tight_layout()  # Ensure everything fits nicely
plt.show()

# Step 7: Model Evaluation – Calculate MAE, MSE, RMSE, and MAPE
y_true = test.values
y_pred = test_pred.values

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_true, y_pred)
print(f'MAE (Mean Absolute Error): {mae:.4f}')

# Mean Squared Error (MSE)
mse = mean_squared_error(y_true, y_pred)
print(f'MSE (Mean Squared Error): {mse:.4f}')

# Root Mean Squared Error (RMSE)
rmse_value = np.sqrt(mse)
print(f'RMSE (Root Mean Squared Error): {rmse_value:.4f}')


# Model residuals (actual − fitted)
resid = ar_model.resid

# Step 8: Perform the Ljung-Box test for autocorrelation in residuals
lb = acorr_ljungbox(resid, lags=[12], return_df=True)
print("Ljung-Box Test for Residuals")
print(lb)

# Step 9: Create a table with MAE, MSE, RMSE, and MAPE metrics
accuracy_table = pd.DataFrame({
    "Metric": ["MAE", "MSE", "RMSE"],
    "Value": [mae, mse, rmse_value]
})

# Display the accuracy table
print(accuracy_table)
# Out:
# AR-4 Model Summary
#                               AutoReg Model Results
# ==================================================================================
# Dep. Variable:     Unemployment Rate Diff   No. Observations:                  638
# Model:                         AutoReg(4)   Log Likelihood                 223.988
# Method:                   Conditional MLE   S.D. of innovations              0.170
# Date:                    Tue, 30 Dec 2025   AIC                           -435.976
# Time:                            20:39:48   BIC                           -409.264
# Sample:                        06-01-1959   HQIC                          -425.604
#                              - 03-01-2012
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.0026      0.007      0.390      0.697      -0.011       0.016
# Unemployment Rate Diff.L1     0.0170      0.039      0.433      0.665      -0.060       0.094
# Unemployment Rate Diff.L2     0.2240      0.039      5.788      0.000       0.148       0.300
# Unemployment Rate Diff.L3     0.1601      0.039      4.141      0.000       0.084       0.236
# Unemployment Rate Diff.L4     0.1373      0.039      3.506      0.000       0.061       0.214
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.2420           -0.0000j            1.2420           -0.0000
# AR.2           -1.7102           -0.0000j            1.7102           -0.5000
# AR.3           -0.3487           -1.8185j            1.8516           -0.2802
# AR.4           -0.3487           +1.8185j            1.8516            0.2802
# -----------------------------------------------------------------------------
# MAE (Mean Absolute Error): 0.2292
# MSE (Mean Squared Error): 0.7798
# RMSE (Root Mean Squared Error): 0.8831
# Ljung-Box Test for Residuals
#       lb_stat  lb_pvalue
# 12  19.289776   0.081771
#   Metric     Value
# 0    MAE  0.229228
# 1    MSE  0.779839
# 2   RMSE  0.883085

# %% [markdown]
# # Conversion to Real Values

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.stats.diagnostic import acorr_ljungbox
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Assuming 'df_cleaned' contains the original dataset with 'Unemployment Rate' and 'Observation Date'
df_cleaned = cleaned_data  # Use the original cleaned data
df_cleaned = df_cleaned.asfreq('MS')  # Ensure the frequency is set to monthly

# Split the data into training and testing sets (assuming df_cleaned is your DataFrame)
train = df_cleaned['Unemployment Rate'][:int(0.8 * len(df_cleaned))]
test = df_cleaned['Unemployment Rate'][int(0.8 * len(df_cleaned)):]

# Fit the AR model with the optimal lag (you can choose optimal_aic_lag or optimal_bic_lag)
optimal_lag = optimal_aic_lag  # Or use optimal_bic_lag if you prefer
ar_model = AutoReg(train, lags=optimal_lag).fit()

# Print AR model summary
print(f"\nAR-{optimal_lag} Model Summary")
print(ar_model.summary())

# One-step-ahead predictions for the test period
test_pred = ar_model.predict(
    start=test.index[0],
    end=test.index[-1],
    dynamic=False
)

# Plotting the results with professional settings
plt.figure(figsize=(12, 4))
plt.plot(train.index, train, label="Training data", color='b')
plt.plot(test.index, test, label="Actual (Test)", color='g')
plt.plot(test.index, test_pred, label="AR Prediction (Test)", linestyle="--", color='r')

# Add grid, labels, and title
plt.title("AR Model – Holding Period Performance", fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Unemployment Rate', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)  # Add gridlines
plt.legend()
plt.tight_layout()  # Ensure everything fits nicely
plt.show()

# Refit the model on the full dataset (for forecasting)
ar_full = AutoReg(df_cleaned['Unemployment Rate'], lags=optimal_lag).fit()

# Forecast for the next 10 years (120 months)
forecast_steps = 120  # 10 years * 12 months
forecast_120 = ar_full.predict(
    start=len(df_cleaned),
    end=len(df_cleaned) + forecast_steps - 1,
    dynamic=False
)

# Create a new time index for the forecasted period (next 10 years)
forecast_index = pd.date_range(df_cleaned.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='MS')

# Combine the original series and the forecasted values
forecast_series = pd.Series(forecast_120, index=forecast_index)

# Plot the original data and the forecasted values with professional settings
plt.figure(figsize=(12, 4))
plt.plot(df_cleaned.index, df_cleaned['Unemployment Rate'], label="Observed", color='b')
plt.plot(forecast_series.index, forecast_series, label="10-Year Forecast", linestyle="--", color='r')

# Add grid, labels, and title
plt.title("AR Model – 10-Year Forecast", fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Unemployment Rate', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)  # Add gridlines
plt.legend()
plt.tight_layout()  # Ensure everything fits nicely
plt.show()

# Step 7: Model Evaluation – Calculate MAE, MSE, RMSE, and MAPE
y_true = test.values
y_pred = test_pred.values

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_true, y_pred)
print(f'MAE (Mean Absolute Error): {mae:.4f}')

# Mean Squared Error (MSE)
mse = mean_squared_error(y_true, y_pred)
print(f'MSE (Mean Squared Error): {mse:.4f}')

# Root Mean Squared Error (RMSE)
rmse_value = np.sqrt(mse)
print(f'RMSE (Root Mean Squared Error): {rmse_value:.4f}')

# Ljung-Box Test for Residuals
resid = ar_model.resid
lb = acorr_ljungbox(resid, lags=[12], return_df=True)
print("Ljung-Box Test for Residuals")
print(lb)

# Create a table with MAE, MSE, RMSE, and MAPE metrics
accuracy_table = pd.DataFrame({
    "Metric": ["MAE", "MSE", "RMSE"],
    "Value": [mae, mse, rmse_value]
})

# Display the accuracy table
print(accuracy_table)
# Out:
# AR-4 Model Summary
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:      Unemployment Rate   No. Observations:                  638
# Model:                     AutoReg(4)   Log Likelihood                 220.998
# Method:               Conditional MLE   S.D. of innovations              0.171
# Date:                Tue, 30 Dec 2025   AIC                           -429.997
# Time:                        20:39:49   BIC                           -403.285
# Sample:                    06-01-1959   HQIC                          -419.624
#                          - 03-01-2012
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0673      0.027      2.522      0.012       0.015       0.120
# Unemployment Rate.L1     1.0323      0.039     26.406      0.000       0.956       1.109
# Unemployment Rate.L2     0.2233      0.056      3.956      0.000       0.113       0.334
# Unemployment Rate.L3    -0.0903      0.056     -1.598      0.110      -0.201       0.020
# Unemployment Rate.L4    -0.1760      0.039     -4.513      0.000      -0.252      -0.100
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0223           -0.0000j            1.0223           -0.0000
# AR.2            1.3393           -0.0000j            1.3393           -0.0000
# AR.3           -1.4374           -1.4438j            2.0374           -0.3746
# AR.4           -1.4374           +1.4438j            2.0374            0.3746
# -----------------------------------------------------------------------------
# MAE (Mean Absolute Error): 1.9949
# MSE (Mean Squared Error): 5.3162
# RMSE (Root Mean Squared Error): 2.3057
# Ljung-Box Test for Residuals
#       lb_stat  lb_pvalue
# 12  32.666526   0.001091
#   Metric     Value
# 0    MAE  1.994947
# 1    MSE  5.316196
# 2   RMSE  2.305688

# %% [markdown]
# # ARIMA

# %%
# Import necessary libraries for ARIMA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Assuming 'df_cleaned' contains the original dataset with 'Unemployment Rate' and 'Observation Date'
df_cleaned = cleaned_data  # Use the original cleaned data
df_cleaned = df_cleaned.asfreq('MS')  # Ensure the frequency is set to monthly

# Step 1: Perform Augmented Dickey-Fuller test to check stationarity
adf_result = adfuller(df_cleaned['Unemployment Rate'])
adf_statistic = adf_result[0]
adf_p_value = adf_result[1]
adf_critical_values = adf_result[4]

# Display the ADF result
print("Augmented Dickey-Fuller Test Results")
print("-" * 50)
print(f"ADF Statistic: {adf_statistic:.4f}")
print(f"P-value: {adf_p_value:.4f}")
print("\nCritical Values:")
for key, value in adf_critical_values.items():
    print(f"  {key}: {value:.4f}")
print("-" * 50)

# If p-value > 0.05, the series is non-stationary. Differencing is applied to make it stationary.
if adf_p_value > 0.05:
    print("Series is non-stationary. Proceeding with differencing.")
    df_cleaned['Unemployment Rate Diff'] = df_cleaned['Unemployment Rate'].diff()
    df_cleaned.dropna(inplace=True)
    print("Differencing applied.")

# Step 2: Plot ACF and PACF to determine p, d, q for ARIMA
plt.figure(figsize=(14, 7))

# Plot ACF
plt.subplot(121)
plot_acf(df_cleaned['Unemployment Rate Diff'], lags=40, ax=plt.gca(), color='b', alpha=0.6)
plt.title('Autocorrelation Function (ACF) of Differenced Unemployment Rate', fontsize=16, fontweight='bold')
plt.xlabel('Lags', fontsize=12, fontweight='bold')
plt.ylabel('Autocorrelation', fontsize=12, fontweight='bold')
plt.grid(True, linestyle='--', color='gray', alpha=0.6)

# Plot PACF
plt.subplot(122)
plot_pacf(df_cleaned['Unemployment Rate Diff'], lags=40, ax=plt.gca(), color='g', alpha=0.6)
plt.title('Partial Autocorrelation Function (PACF) of Differenced Unemployment Rate', fontsize=16, fontweight='bold')
plt.xlabel('Lags', fontsize=12, fontweight='bold')
plt.ylabel('Partial Autocorrelation', fontsize=12, fontweight='bold')
plt.grid(True, linestyle='--', color='gray', alpha=0.6)

plt.tight_layout()
plt.show()

# Step 3: Fit ARIMA model (you can try different (p,d,q) orders based on ACF and PACF plots)
# Here, we are setting p=1, d=1, q=1 as an example, adjust based on ACF and PACF plots
model = ARIMA(df_cleaned['Unemployment Rate'], order=(1, 1, 1))  # (p, d, q)
arima_model = model.fit()

# Print ARIMA model summary
print(f"\nARIMA Model Summary")
print(arima_model.summary())

# Step 4: Forecast the next 10 years (120 months)
forecast_steps = 120  # 10 years * 12 months
forecast = arima_model.forecast(steps=forecast_steps)

# Create a new time index for the forecasted period (next 10 years)
forecast_index = pd.date_range(df_cleaned.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='MS')

# Combine the original series and the forecasted values
forecast_series = pd.Series(forecast, index=forecast_index)

# Step 5: Plot the original data and the forecasted values
plt.figure(figsize=(12, 4))
plt.plot(df_cleaned.index, df_cleaned['Unemployment Rate'], label="Observed", color='b')
plt.plot(forecast_series.index, forecast_series, label="10-Year Forecast", linestyle="--", color='r')

# Add grid, labels, and title
plt.title("ARIMA Model – 10-Year Forecast", fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Unemployment Rate', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)  # Add gridlines
plt.legend()
plt.tight_layout()  # Ensure everything fits nicely
plt.show()

# Step 6: Model Evaluation – Calculate MAE, MSE, RMSE, and MAPE for the forecast
y_true = df_cleaned['Unemployment Rate'][-len(forecast):].values
y_pred = forecast

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_true, y_pred)
print(f'MAE (Mean Absolute Error): {mae:.4f}')

# Mean Squared Error (MSE)
mse = mean_squared_error(y_true, y_pred)
print(f'MSE (Mean Squared Error): {mse:.4f}')

# Root Mean Squared Error (RMSE)
rmse_value = np.sqrt(mse)
print(f'RMSE (Root Mean Squared Error): {rmse_value:.4f}')

# Step 7: Ljung-Box Test for Residuals
resid = arima_model.resid
lb = acorr_ljungbox(resid, lags=[12], return_df=True)
print("Ljung-Box Test for Residuals")
print(lb)

# Step 8: Create a table with MAE, MSE, RMSE metrics
accuracy_table = pd.DataFrame({
    "Metric": ["MAE", "MSE", "RMSE"],
    "Value": [mae, mse, rmse_value]
})

# Display the accuracy table
print(accuracy_table)
# Out:
# Augmented Dickey-Fuller Test Results
# --------------------------------------------------
# ADF Statistic: -3.4201
# P-value: 0.0103
#
# Critical Values:
#   1%: -3.4386
#   5%: -2.8652
#   10%: -2.5687
# --------------------------------------------------
# ARIMA Model Summary
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:      Unemployment Rate   No. Observations:                  798
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -451.702
# Date:                Tue, 30 Dec 2025   AIC                            909.403
# Time:                        20:44:36   BIC                            923.446
# Sample:                    02-01-1959   HQIC                           914.799
#                          - 07-01-2025
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7571      0.084     -9.028      0.000      -0.921      -0.593
# ma.L1          0.8151      0.080     10.172      0.000       0.658       0.972
# sigma2         0.1819      0.001    274.676      0.000       0.181       0.183
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.39   Jarque-Bera (JB):           6273614.33
# Prob(Q):                              0.53   Prob(JB):                         0.00
# Heteroskedasticity (H):              11.44   Skew:                            17.63
# Prob(H) (two-sided):                  0.00   Kurtosis:                       436.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# MAE (Mean Absolute Error): 0.8697
# MSE (Mean Squared Error): 3.1151
# RMSE (Root Mean Squared Error): 1.7650
# Ljung-Box Test for Residuals
#      lb_stat  lb_pvalue
# 12  5.000973   0.957946
#   Metric     Value
# 0    MAE  0.869713
# 1    MSE  3.115090
# 2   RMSE  1.764962

# %% [markdown]
# # SARIMA

# %%
# Import Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Set the font for all plots to 'Times New Roman'
plt.rcParams['font.family'] = 'Times New Roman'

# Load the data
file_path = 'Unemployment Rate.xlsx'
data = pd.read_excel(file_path)

# Data Preprocessing: Select relevant columns
cleaned_data = data[['Observation Date', 'Unemployment Rate']]

# Convert 'Observation Date' to datetime format
cleaned_data['Observation Date'] = pd.to_datetime(cleaned_data['Observation Date'])

# Set 'Observation Date' as the index
cleaned_data.set_index('Observation Date', inplace=True)

# Ensure data has a monthly frequency (MS - Month Start)
cleaned_data = cleaned_data.asfreq('MS')

# Check if data is stationary using Augmented Dickey-Fuller (ADF) test
adf_result = adfuller(cleaned_data['Unemployment Rate'])
adf_statistic = adf_result[0]
adf_p_value = adf_result[1]
adf_critical_values = adf_result[4]

print("ADF Test Results")
print("-" * 50)
print(f"ADF Statistic: {adf_statistic:.4f}")
print(f"P-value: {adf_p_value:.4f}")
print("\nCritical Values:")
for key, value in adf_critical_values.items():
    print(f"  {key}: {value:.4f}")
print("-" * 50)

# If the p-value > 0.05, the series is non-stationary. Apply differencing
if adf_p_value > 0.05:
    print("Series is non-stationary. Proceeding with differencing.")
    cleaned_data['Unemployment Rate Diff'] = cleaned_data['Unemployment Rate'].diff()
    cleaned_data.dropna(inplace=True)
    print("Differencing applied.")

# SARIMA Model: Fit the SARIMA model (p, d, q)(P, D, Q, S)
sarima_model = SARIMAX(cleaned_data['Unemployment Rate'],
                       order=(1, 1, 1),  # Non-seasonal components (AR, I, MA)
                       seasonal_order=(1, 1, 1, 12),  # Seasonal components (P, D, Q, S)
                       enforce_stationarity=False,
                       enforce_invertibility=False)

sarima_fitted = sarima_model.fit(disp=False)

# Display the SARIMA model summary
print(sarima_fitted.summary())

# Forecast the next 10 years (120 months)
forecast_steps = 120  # 10 years * 12 months
forecast_sarima = sarima_fitted.get_forecast(steps=forecast_steps)

# Get the forecast values
forecast_values = forecast_sarima.predicted_mean

# Create a new time index for the forecasted period
forecast_index = pd.date_range(cleaned_data.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='MS')

# Combine the original series and the forecasted values
forecast_series = pd.Series(forecast_values, index=forecast_index)

# Plot the original data and forecasted values
plt.figure(figsize=(12, 4))
plt.plot(cleaned_data.index, cleaned_data['Unemployment Rate'], label="Observed", color='b')
plt.plot(forecast_series.index, forecast_series, label="10-Year Forecast", linestyle="--", color='r')

plt.title("SARIMA Model – 10-Year Forecast", fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Unemployment Rate', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# Calculate residuals
residuals = sarima_fitted.resid

# Calculate the forecast error metrics (MAE, MSE, RMSE)
y_true = cleaned_data['Unemployment Rate'][-len(forecast_values):].values  # Last values from the series
y_pred = forecast_values.values

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_true, y_pred)
print(f'MAE (Mean Absolute Error): {mae:.4f}')

# Mean Squared Error (MSE)
mse = mean_squared_error(y_true, y_pred)
print(f'MSE (Mean Squared Error): {mse:.4f}')

# Root Mean Squared Error (RMSE)
rmse_value = np.sqrt(mse)
print(f'RMSE (Root Mean Squared Error): {rmse_value:.4f}')

# Ljung-Box test for residuals
lb = acorr_ljungbox(residuals, lags=[12], return_df=True)
print("Ljung-Box Test for Residuals")
print(lb)

# Create a table with MAE, MSE, RMSE metrics
accuracy_table = pd.DataFrame({
    "Metric": ["MAE", "MSE", "RMSE"],
    "Value": [mae, mse, rmse_value]
})

# Display the accuracy table
print(accuracy_table)

# If you want to refit the model on the entire dataset and forecast for the next 10 years:
sarima_full_model = SARIMAX(cleaned_data['Unemployment Rate'],
                            order=(1, 1, 1),
                            seasonal_order=(1, 1, 1, 12),
                            enforce_stationarity=False,
                            enforce_invertibility=False)

sarima_full_fitted = sarima_full_model.fit(disp=False)

# Forecast for the next 10 years (120 months)
forecast_full = sarima_full_fitted.get_forecast(steps=forecast_steps)

# Get the forecast values
forecast_full_values = forecast_full.predicted_mean

# Create a new time index for the forecasted period
forecast_full_index = pd.date_range(cleaned_data.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='MS')

# Combine the original series and the forecasted values
forecast_full_series = pd.Series(forecast_full_values, index=forecast_full_index)

# Plot the original data and the forecasted values for the next 10 years
plt.figure(figsize=(12, 4))
plt.plot(cleaned_data.index, cleaned_data['Unemployment Rate'], label="Observed", color='b')
plt.plot(forecast_full_series.index, forecast_full_series, label="10-Year Forecast", linestyle="--", color='r')

plt.title("SARIMA Model – 10-Year Forecast (Refitted)", fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Unemployment Rate', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ADF Test Results
# --------------------------------------------------
# ADF Statistic: -3.4190
# P-value: 0.0103
#
# Critical Values:
#   1%: -3.4386
#   5%: -2.8652
#   10%: -2.5687
# --------------------------------------------------
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                  Unemployment Rate   No. Observations:                  799
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -460.583
# Date:                            Tue, 30 Dec 2025   AIC                            931.167
# Time:                                    20:46:04   BIC                            954.412
# Sample:                                01-01-1959   HQIC                           940.111
#                                      - 07-01-2025
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7627      0.077     -9.852      0.000      -0.914      -0.611
# ma.L1          0.8264      0.074     11.209      0.000       0.682       0.971
# ar.S.L12   -6.181e-06      0.030     -0.000      1.000      -0.060       0.060
# ma.S.L12      -0.9656      0.029    -32.806      0.000      -1.023      -0.908
# sigma2         0.1871      0.001    214.196      0.000       0.185       0.189
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.41   Jarque-Bera (JB):           5752782.11
# Prob(Q):                              0.52   Prob(JB):                         0.00
# Heteroskedasticity (H):              12.05   Skew:                            17.40
# Prob(H) (two-sided):                  0.00   Kurtosis:                       424.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# MAE (Mean Absolute Error): 0.8866
# MSE (Mean Squared Error): 3.3991
# RMSE (Root Mean Squared Error): 1.8437
# Ljung-Box Test for Residuals
#      lb_stat  lb_pvalue
# 12  36.95029   0.000228
#   Metric     Value
# 0    MAE  0.886623
# 1    MSE  3.399117
# 2   RMSE  1.843669

# %% [markdown]
# # Holt-Winters Model

# %%
# Import Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Set the font for all plots to 'Times New Roman'
plt.rcParams['font.family'] = 'Times New Roman'

# Load the data
file_path = 'Unemployment Rate.xlsx'
data = pd.read_excel(file_path)

# Data Preprocessing: Select relevant columns
cleaned_data = data[['Observation Date', 'Unemployment Rate']]

# Convert 'Observation Date' to datetime format
cleaned_data['Observation Date'] = pd.to_datetime(cleaned_data['Observation Date'])

# Set 'Observation Date' as the index
cleaned_data.set_index('Observation Date', inplace=True)

# Ensure data has a monthly frequency (MS - Month Start)
cleaned_data = cleaned_data.asfreq('MS')

# Check if data is stationary using Augmented Dickey-Fuller (ADF) test
adf_result = adfuller(cleaned_data['Unemployment Rate'])
adf_statistic = adf_result[0]
adf_p_value = adf_result[1]
adf_critical_values = adf_result[4]

print("ADF Test Results")
print("-" * 50)
print(f"ADF Statistic: {adf_statistic:.4f}")
print(f"P-value: {adf_p_value:.4f}")
print("\nCritical Values:")
for key, value in adf_critical_values.items():
    print(f"  {key}: {value:.4f}")
print("-" * 50)

# If the p-value > 0.05, the series is non-stationary. Apply differencing if needed
if adf_p_value > 0.05:
    print("Series is non-stationary. Proceeding with differencing.")
    cleaned_data['Unemployment Rate Diff'] = cleaned_data['Unemployment Rate'].diff()
    cleaned_data.dropna(inplace=True)
    print("Differencing applied.")

# Fit the Holt-Winters Model (Exponential Smoothing)
# Seasonal period S = 12 for monthly data with yearly seasonality
holt_winters_model = ExponentialSmoothing(cleaned_data['Unemployment Rate'],
                                          trend='add',  # 'add' for additive trend, 'mul' for multiplicative trend
                                          seasonal='add',  # 'add' for additive seasonality, 'mul' for multiplicative seasonality
                                          seasonal_periods=12)  # Seasonal period (monthly data, yearly seasonality)

# Fit the model
holt_winters_fitted = holt_winters_model.fit()

# Display the Holt-Winters model summary
print(holt_winters_fitted.summary())

# Forecast the next 10 years (120 months)
forecast_steps = 120  # 10 years * 12 months
forecast_hw = holt_winters_fitted.forecast(steps=forecast_steps)

# Create a new time index for the forecasted period
forecast_index = pd.date_range(cleaned_data.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='MS')

# Combine the original series and the forecasted values
forecast_series_hw = pd.Series(forecast_hw, index=forecast_index)

# Plot the original data and forecasted values
plt.figure(figsize=(12, 4))
plt.plot(cleaned_data.index, cleaned_data['Unemployment Rate'], label="Observed", color='b')
plt.plot(forecast_series_hw.index, forecast_series_hw, label="10-Year Forecast (Holt-Winters)", linestyle="--", color='r')

plt.title("Holt-Winters Model – 10-Year Forecast", fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Unemployment Rate', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# Calculate residuals
residuals = holt_winters_fitted.resid

# Calculate the forecast error metrics (MAE, MSE, RMSE)
y_true = cleaned_data['Unemployment Rate'][-len(forecast_hw):].values  # Last values from the series
y_pred = forecast_hw

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_true, y_pred)
print(f'MAE (Mean Absolute Error): {mae:.4f}')

# Mean Squared Error (MSE)
mse = mean_squared_error(y_true, y_pred)
print(f'MSE (Mean Squared Error): {mse:.4f}')

# Root Mean Squared Error (RMSE)
rmse_value = np.sqrt(mse)
print(f'RMSE (Root Mean Squared Error): {rmse_value:.4f}')

# Ljung-Box test for residuals
lb = acorr_ljungbox(residuals, lags=[12], return_df=True)
print("Ljung-Box Test for Residuals")
print(lb)

# Create a table with MAE, MSE, RMSE metrics
accuracy_table_hw = pd.DataFrame({
    "Metric": ["MAE", "MSE", "RMSE"],
    "Value": [mae, mse, rmse_value]
})

# Display the accuracy table
print(accuracy_table_hw)

# Refitting the model on the entire dataset and forecasting the next 10 years
holt_winters_full_model = ExponentialSmoothing(cleaned_data['Unemployment Rate'],
                                              trend='add',
                                              seasonal='add',
                                              seasonal_periods=12)

holt_winters_full_fitted = holt_winters_full_model.fit()

# Forecast for the next 10 years (120 months)
forecast_full_hw = holt_winters_full_fitted.forecast(steps=forecast_steps)

# Create a new time index for the forecasted period
forecast_full_index = pd.date_range(cleaned_data.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='MS')

# Combine the original series and the forecasted values for the next 10 years
forecast_full_series_hw = pd.Series(forecast_full_hw, index=forecast_full_index)

# Plot the original data and forecasted values for the next 10 years
plt.figure(figsize=(12, 4))
plt.plot(cleaned_data.index, cleaned_data['Unemployment Rate'], label="Observed", color='b')
plt.plot(forecast_full_series_hw.index, forecast_full_series_hw, label="10-Year Forecast (Refitted)", linestyle="--", color='r')

plt.title("Holt-Winters Model – 10-Year Forecast (Refitted)", fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Unemployment Rate', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ADF Test Results
# --------------------------------------------------
# ADF Statistic: -3.4190
# P-value: 0.0103
#
# Critical Values:
#   1%: -3.4386
#   5%: -2.8652
#   10%: -2.5687
# --------------------------------------------------
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:        Unemployment Rate   No. Observations:                  799
# Model:             ExponentialSmoothing   SSE                            144.337
# Optimized:                         True   AIC                          -1335.258
# Trend:                         Additive   BIC                          -1260.324
# Seasonal:                      Additive   AICC                         -1334.381
# Seasonal Periods:                    12   Date:                 Tue, 30 Dec 2025
# Box-Cox:                          False   Time:                         20:46:42
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               1.0000000                alpha                 True
# smoothing_trend                0.000000                 beta                 True
# smoothing_seasonal           5.7712e-09                gamma                 True
# initial_level                 5.9916278                  l.0                 True
# initial_trend                -0.0023501                  b.0                 True
# initial_seasons.0             0.0107852                  s.0                 True
# initial_seasons.1             0.0056492                  s.1                 True
# initial_seasons.2             0.0109570                  s.2                 True
# initial_seasons.3             0.1610472                  s.3                 True
# initial_seasons.4             0.1305595                  s.4                 True
# initial_seasons.5             0.1179915                  s.5                 True
# initial_seasons.6             0.0860282                  s.6                 True
# initial_seasons.7             0.0505176                  s.7                 True
# initial_seasons.8             0.0301520                  s.8                 True
# initial_seasons.9             0.0249425                  s.9                 True
# initial_seasons.10            0.0288174                 s.10                 True
# initial_seasons.11            0.0205607                 s.11                 True
# ---------------------------------------------------------------------------------
# MAE (Mean Absolute Error): 0.8477
# MSE (Mean Squared Error): 3.2265
# RMSE (Root Mean Squared Error): 1.7962
# Ljung-Box Test for Residuals
#      lb_stat  lb_pvalue
# 12  10.71688   0.553325
#   Metric     Value
# 0    MAE  0.847722
# 1    MSE  3.226455
# 2   RMSE  1.796234
